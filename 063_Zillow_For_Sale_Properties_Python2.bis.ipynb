# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python2.bis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'moraga'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: moraga, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Townhomes",
               "minPrice": "700000",
               "maxPrice": "1500000",
               "sqftMin": "1000",
               "bedsMin": "2"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1306.8,
#    'address': '118 Wallace Cir, Moraga, CA 94556',
#    'newConstructionType': 'NEW_CONSTRUCTION_TYPE_OTHER',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1379900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0127eb64122417f83b2f134249a97bff-p_e.jpg',
#    'price': 1345000,
#    'detailUrl': '/homedetails/118-Wallace-Cir-Moraga-CA-94556/333912391_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -122.13305,
#    'latitude': 37.835987,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '333912391',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': 5699,
#    'daysOnZillow': 3,
#    'bathrooms': 4,
#    'livingArea': 2309,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1742.4,
#    'address': '133 Miramonte Dr, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': -20000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1488ffdc60d4280f8cb92e1eb0f688d2-p_e.jpg',
#    'price': 948000,
#    'detailUrl': '/homedetails/133-Miramonte-Dr-Moraga-CA-94556/18471812_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.143005,
#    'latitude': 37.839252,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18471812',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4500,
#    'daysOnZillow': 12,
#    'bathrooms': 2,
#    'livingArea': 1514,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 4791.6,
#    'address': '824 Country Club Dr, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1385900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e1a39e44de2645b7dc5f2bb1a1e99adf-p_e.jpg',
#    'price': 1325000,
#    'detailUrl': '/homedetails/824-Country-Club-Dr-Moraga-CA-94556/18472073_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.13323,
#    'latitude': 37.834587,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18472073',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4798,
#    'daysOnZillow': 11,
#    'bathrooms': 3,
#    'livingArea': 1749,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1742.4,
#    'address': '20 Miramonte Dr, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f4548b313ea3645cd8d3e77d9ac9115b-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/20-Miramonte-Dr-Moraga-CA-94556/18471498_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.143555,
#    'latitude': 37.84095,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18471498',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4600,
#    'daysOnZillow': 46,
#    'bathrooms': 3,
#    'livingArea': 1762,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1742.4,
#    'address': '140 Miramonte Dr, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fe919e83b447d58feb327414f66d22d5-p_e.jpg',
#    'price': 1095000,
#    'detailUrl': '/homedetails/140-Miramonte-Dr-Moraga-CA-94556/18471819_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.14318,
#    'latitude': 37.838825,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18471819',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4600,
#    'daysOnZillow': 21,
#    'bathrooms': 3,
#    'livingArea': 1742,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 1,
#  'totalResultCount': 5,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 5
# Num of cols: 27
#   dateSold propertyType  lotAreaValue                                address  \
# 0     None    TOWNHOUSE        1306.8      118 Wallace Cir, Moraga, CA 94556
# 1     None    TOWNHOUSE        1742.4     133 Miramonte Dr, Moraga, CA 94556
# 2     None    TOWNHOUSE        4791.6  824 Country Club Dr, Moraga, CA 94556
# 3     None    TOWNHOUSE        1742.4      20 Miramonte Dr, Moraga, CA 94556
# 4     None    TOWNHOUSE        1742.4     140 Miramonte Dr, Moraga, CA 94556
#
#            newConstructionType variableData  priceChange  zestimate  \
# 0  NEW_CONSTRUCTION_TYPE_OTHER         None          NaN  1379900.0
# 1                          NaN         None     -20000.0        NaN
# 2                          NaN         None          NaN  1385900.0
# 3                          NaN         None          NaN        NaN
# 4                          NaN         None          NaN        NaN
#
#                                               imgSrc    price  \
# 0  https://photos.zillowstatic.com/fp/0127eb64122...  1345000
# 1  https://photos.zillowstatic.com/fp/1488ffdc60d...   948000
# 2  https://photos.zillowstatic.com/fp/e1a39e44de2...  1325000
# 3  https://photos.zillowstatic.com/fp/f4548b313ea...   899000
# 4  https://photos.zillowstatic.com/fp/fe919e83b44...  1095000
#
#                                            detailUrl  bedrooms  \
# 0  /homedetails/118-Wallace-Cir-Moraga-CA-94556/3...         5
# 1  /homedetails/133-Miramonte-Dr-Moraga-CA-94556/...         3
# 2  /homedetails/824-Country-Club-Dr-Moraga-CA-945...         3
# 3  /homedetails/20-Miramonte-Dr-Moraga-CA-94556/1...         3
# 4  /homedetails/140-Miramonte-Dr-Moraga-CA-94556/...         3
#
#   contingentListingType   longitude   latitude listingStatus       zpid  \
# 0                  None -122.133050  37.835987      FOR_SALE  333912391
# 1                  None -122.143005  37.839252      FOR_SALE   18471812
# 2                  None -122.133230  37.834587      FOR_SALE   18472073
# 3                  None -122.143555  37.840950      FOR_SALE   18471498
# 4                  None -122.143180  37.838825      FOR_SALE   18471819
#
#    rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0           5699             3          4        2309     USA      USD
# 1           4500            12          2        1514     USA      USD
# 2           4798            11          3        1749     USA      USD
# 3           4600            46          3        1762     USA      USD
# 4           4600            21          3        1742     USA      USD
#
#   lotAreaUnit  hasImage listingSubType.is_newHome listingSubType.is_FSBA
# 0        sqft      True                      True                    NaN
# 1        sqft      True                       NaN                   True
# 2        sqft      True                       NaN                   True
# 3        sqft      True                       NaN                   True
# 4        sqft      True                       NaN                   True

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['333912391', '18471812', '18472073', '18471498', '18471819']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 5
# Num of cols: 298
#   listingProvider       zpid buildingPermits  propertyTaxRate  \
# 0            None  333912391            None             1.16
# 1            None   18471812            None             1.16
#
#                                   contact_recipients zipcode   longitude  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   94556 -122.133050
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   94556 -122.143005
#
#   zestimateLowPercent  cityId timeOnZillow  \
# 0                   5   32942       3 days
# 1                None   32942      12 days
#
#                                                  url  zestimate  \
# 0  /homedetails/118-Wallace-Cir-Moraga-CA-94556/3...  1379900.0
# 1  /homedetails/133-Miramonte-Dr-Moraga-CA-94556/...        NaN
#
#                                               imgSrc  \
# 0  https://photos.zillowstatic.com/fp/0127eb64122...
# 1  https://photos.zillowstatic.com/fp/1488ffdc60d...
#
#                                          description    price  \
# 0  Welcome to an enchanting, contemporary communi...  1345000
# 1  Welcome to this charming townhouse nestled by ...   948000
#
#    livingAreaValue                                         taxHistory  \
# 0             2309  [{'time': 1686413116873, 'valueIncreaseRate': ...
# 1             1514  [{'time': 1686413119767, 'valueIncreaseRate': ...
#
#   brokerId  stateId     streetAddress solarPotential dateSold  countyId  \
# 0     None        9   118 Wallace Cir           None     None      3159
# 1     None        9  133 Miramonte Dr           None     None      3159
#
#               timeZone   homeType livingAreaUnits comingSoonOnMarketDate  \
# 0  America/Los_Angeles  TOWNHOUSE            sqft                   None
# 1  America/Los_Angeles  TOWNHOUSE            sqft                   None
#
#    rentZestimate  bathrooms  annualHomeownersInsurance state  \
# 0           5699          4                       5649    CA
# 1           4500          2                       3982    CA
#
#   propertyTypeDimension building  yearBuilt           brokerageName  \
# 0             Townhouse     None       2020  Coldwell Banker Realty
# 1             Townhouse     None       1965  Coldwell Banker Realty
#
#    pageViewCount               county  monthlyHoaFee homeStatus homeFacts  \
# 0            472  Contra Costa County            570   FOR_SALE      None
# 1            569  Contra Costa County            517   FOR_SALE      None
#
#     latitude  datePosted  bedrooms  \
# 0  37.835987  2024-06-07         5
# 1  37.839252  2024-05-29         3
#
#                                          nearbyHomes  livingArea  \
# 0  [{'livingArea': 2317, 'livingAreaValue': 2317,...        2309
# 1  [{'livingArea': 1514, 'livingAreaValue': 1514,...        1514
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0.10836423568191, 'date':...             30
# 1  [{'priceChangeRate': -0.020661157024793, 'date...             15
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/califo...                    5
# 1  [{'link': 'https://www.greatschools.org/califo...                 None
#
#       mlsid countyFIPS    city providerListingID country currency  \
# 0  41061166      06013  Moraga              None     USA      USD
# 1  41061377      06013  Moraga              None     USA      USD
#
#   isListedByOwner contingentListingType address.community address.city  \
# 0            None                  None              None       Moraga
# 1            None                  None              None       Moraga
#
#   address.state address.neighborhood address.subdivision  \
# 0            CA                 None                None
# 1            CA                 None                None
#
#   address.streetAddress address.zipcode  resoFacts.hasAttachedProperty  \
# 0       118 Wallace Cir           94556                          False
# 1      133 Miramonte Dr           94556                          False
#
#   resoFacts.frontageType resoFacts.poolFeatures  \
# 0                   None                 [None]
# 1                   None      [None, Community]
#
#                                   resoFacts.flooring resoFacts.builderModel  \
# 0                          [Laminate, Carpet, Other]                   None
# 1  [Hardwood, Hardwood Flrs Throughout, Engineere...                   None
#
#   resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0                            None                 True
# 1                            None                False
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     None               None                 None
# 1                     True               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
# 1                              None                           False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factValue': 'Townhouse', 'factLabel': 'Type...
# 1                 False  [{'factValue': 'Townhouse', 'factLabel': 'Type...
#
#   resoFacts.offerReviewDate resoFacts.horseYN  \
# 0                      None              None
# 1                      None              None
#
#   resoFacts.buyerAgencyCompensationType resoFacts.belowGradeFinishedArea  \
# 0                                     %                             None
# 1                                     %                             None
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': '925-355-2100', 'name': 'MORAGA TOW...               Moraga
# 1  [{'phone': '925-376-3727', 'name': 'MIRAMONTE ...               Moraga
#
#   resoFacts.subAgencyCompensation resoFacts.hasPrivatePool  \
# 0                            None                     None
# 1                            None                     None
#
#                     resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0  [Common Area Maint, Exterior Maintenance, Haza...              [Public]
# 1  [Common Area Maint, Exterior Maintenance, Haza...              [Public]
#
#   resoFacts.carportParkingCapacity  \
# 0                             None
# 1                             None
#
#   resoFacts.transactionBrokerCompensationType  resoFacts.hasFireplace  \
# 0                                        None                   False
# 1                                        None                    True
#
#   resoFacts.gas resoFacts.sewer resoFacts.elevationUnits  \
# 0          None            None                     None
# 1          None  [Public Sewer]                     None
#
#   resoFacts.roadSurfaceType resoFacts.mainLevelBedrooms  \
# 0                      None                        None
# 1                      None                        None
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView  \
# 0                          None                        None
# 1                          None                        None
#
#   resoFacts.bathroomsOneQuarter resoFacts.lotSize  \
# 0                          None        1,306 sqft
# 1                          None        1,742 sqft
#
#   resoFacts.subAgencyCompensationType resoFacts.entryLevel  \
# 0                                None                 None
# 1                                None                 None
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.greenWaterConservation  \
# 0                                 None                             None
# 1                                 None                             None
#
#    resoFacts.stories  resoFacts.bathrooms  resoFacts.numberOfUnitsInCommunity  \
# 0                  2                    4                                  36
# 1                  2                    2                                 225
#
#                               resoFacts.listingTerms resoFacts.otherParking  \
# 0  CalHFA,Cash,Conventional,FHA,VA,May Pay Close ...                   None
# 1                                  Cash,Conventional                   None
#
#   resoFacts.associationFee resoFacts.marketingType  \
# 0             $570 monthly                    None
# 1             $517 monthly                    None
#
#   resoFacts.greenEnergyEfficient resoFacts.greenSustainability  \
# 0                           None                          None
# 1                           None                          None
#
#   resoFacts.heating resoFacts.associationPhone  \
# 0           [Zoned]               925-355-2100
# 1      [Forced Air]               925-376-3727
#
#   resoFacts.greenBuildingVerificationType  resoFacts.hasAttachedGarage  \
# 0                                    None                         True
# 1                                    None                        False
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   5                 Contemporary                None
# 1                   3                      Cottage                None
#
#   resoFacts.structureType                         resoFacts.interiorFeatures  \
# 0                    None  [Bonus/Plus Room, In-Law Floorplan, Breakfast ...
# 1                    None  [Bonus/Plus Room, Dining Area, Storage, Breakf...
#
#   resoFacts.horseAmenities            resoFacts.electric  \
# 0                     None  [Photovoltaics Seller Owned]
# 1                     None                    [No Solar]
#
#   resoFacts.lotFeatures resoFacts.roofType resoFacts.compensationBasedOn  \
# 0               [Level]            Shingle                          None
# 1             [Regular]            Shingle                          None
#
#   resoFacts.greenEnergyGeneration  resoFacts.taxAnnualAmount  \
# 0                         [Solar]                      15602
# 1                            None                      10997
#
#    resoFacts.daysOnZillow resoFacts.listAOR  resoFacts.hasHeating  \
# 0                       3              None                  True
# 1                      12              None                  True
#
#   resoFacts.elementarySchool resoFacts.basementYN resoFacts.hoaFeeTotal  \
# 0                       None                 None          $570 monthly
# 1                       None                 None          $517 monthly
#
#                                 resoFacts.appliances  \
# 0      [Dishwasher, Disposal, Tankless Water Heater]
# 1  [Dishwasher, Disposal, Free-Standing Range, Re...
#
#           resoFacts.virtualTour resoFacts.bathroomsPartial resoFacts.fencing  \
# 0        http://118-wallace.com                       None            Fenced
# 1  https://youtu.be/3qvGb_TpJVo                       None            Fenced
#
#   resoFacts.yearBuiltEffective resoFacts.buildingName  \
# 0                         None                   None
# 1                         None                   None
#
#    resoFacts.hasAssociation resoFacts.isSeniorCommunity  \
# 0                      True                        None
# 1                      True                        None
#
#   resoFacts.propertySubType resoFacts.propertyCondition  resoFacts.hasCarport  \
# 0               [Townhouse]                    Existing                 False
# 1               [Townhouse]                    Existing                  True
#
#    resoFacts.canRaiseHorses  resoFacts.hasLandLease  \
# 0                     False                   False
# 1                     False                   False
#
#   resoFacts.communityFeatures resoFacts.parcelNumber resoFacts.elevation  \
# 0                        None             2576000042                None
# 1                        None             2573700552                None
#
#   resoFacts.lotSizeDimensions resoFacts.buildingAreaSource  \
# 0                        None                         None
# 1                        None                         None
#
#   resoFacts.contingency  resoFacts.yearBuilt resoFacts.otherStructures  \
# 0                  None                 2020                      None
# 1                  None                 1965                      None
#
#   resoFacts.livingArea  resoFacts.bathroomsFull  \
# 0           2,309 sqft                        3
# 1           1,514 sqft                        2
#
#   resoFacts.livingAreaRangeUnits resoFacts.incomeIncludes  \
# 0                           None                     None
# 1                           None                     None
#
#   resoFacts.highSchool resoFacts.aboveGradeFinishedArea  \
# 0                 None                             None
# 1                 None                             None
#
#    resoFacts.isNewConstruction resoFacts.inclusions  \
# 0                         True                 None
# 1                        False                 None
#
#    resoFacts.hasHomeWarranty resoFacts.additionalFeeInfo  \
# 0                      False                        None
# 1                      False                        None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0       [Window Coverings]                None                 None
# 1       [Window Coverings]                None                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                                   None                        None
# 1                                   None                        None
#
#             resoFacts.exteriorFeatures resoFacts.buildingFeatures  \
# 0  [Unit Faces Common Area, Side Yard]                       None
# 1             [Back Yard, Garden/Play]                       None
#
#   resoFacts.frontageLength resoFacts.buildingArea  \
# 0                     None                  2,309
# 1                     None                  1,514
#
#                       resoFacts.associationAmenities  resoFacts.bathroomsHalf  \
# 0                            [Greenbelt, Playground]                        1
# 1  [Clubhouse, Greenbelt, Pool, Barbecue, BBQ Are...                        0
#
#    resoFacts.hasCooling resoFacts.additionalParcelsDescription  \
# 0                  True                                   None
# 1                  True                                   None
#
#         resoFacts.parkingFeatures resoFacts.foundationArea resoFacts.zoning  \
# 0  [Attached, Garage Door Opener]                     None             None
# 1   [Carport, Garage Door Opener]                     None             None
#
#   resoFacts.hoaFee resoFacts.livingAreaRange resoFacts.zoningDescription  \
# 0     $570 monthly                      None                        None
# 1     $517 monthly                      None                        None
#
#   resoFacts.developmentStatus resoFacts.availabilityDate  \
# 0                        None                       None
# 1                        None                       None
#
#   resoFacts.waterfrontFeatures resoFacts.waterBodyName   resoFacts.utilities  \
# 0                         None                    None                  None
# 1                         None                    None  [Internet Available]
#
#                    resoFacts.entryLocation resoFacts.totalActualRent  \
# 0  Ground Floor Location,No Steps to Entry                      None
# 1                                     None                      None
#
#    resoFacts.hasView resoFacts.subdivisionName  \
# 0              False                      None
# 1               True                      None
#
#                           resoFacts.securityFeatures resoFacts.attic  \
# 0                      [Carbon Monoxide Detector(s)]            None
# 1  [Carbon Monoxide Detector(s), Double Strapped ...            None
#
#                 resoFacts.fireplaceFeatures resoFacts.mainLevelBathrooms  \
# 0                                    [None]                         None
# 1  [Gas Starter, Living Room, Wood Burning]                         None
#
#       resoFacts.doorFeatures resoFacts.ownershipType  \
# 0                       None                    None
# 1  [Mirrored Closet Door(s)]                    None
#
#   resoFacts.associationName  \
# 0        MORAGA TOWN CENTER
# 1             MIRAMONTE HOA
#
#                               resoFacts.associations resoFacts.waterView  \
# 0  [{'feeFrequency': '$570 monthly', 'name': 'MOR...                None
# 1  [{'feeFrequency': '$517 monthly', 'name': 'MIR...                None
#
#    resoFacts.garageParkingCapacity resoFacts.cropsIncludedYN  \
# 0                                2                      None
# 1                                0                      None
#
#                            resoFacts.laundryFeatures  \
# 0                                     [Laundry Room]
# 1  [220 Volt Outlet, Hookups Only, Laundry Room, ...
#
#   resoFacts.buyerAgencyCompensation resoFacts.greenIndoorAirQuality  \
# 0                               2.5                            None
# 1                               2.5                            None
#
#   resoFacts.homeType resoFacts.spaFeatures resoFacts.municipality  \
# 0          Townhouse                  None                   None
# 1          Townhouse                  None                   None
#
#   resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa resoFacts.basement  \
# 0                            None             False               None
# 1                            None             False        Crawl Space
#
#   resoFacts.associationFee2 resoFacts.cooling resoFacts.openParkingCapacity  \
# 0                      None           [Zoned]                          None
# 1                      None     [Central Air]                          None
#
#   resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                       None                     None
# 1                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                               None                     None
# 1                               None                     None
#
#   resoFacts.commonWalls resoFacts.specialListingConditions  \
# 0  Corner Unit,End Unit                           Standard
# 1                  None                           Standard
#
#    resoFacts.furnished resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                False                 None                            None
# 1                False                 None                            None
#
#    resoFacts.bathroomsFloat resoFacts.builderName  \
# 0                         4                  None
# 1                         2                  None
#
#   resoFacts.highSchoolDistrict resoFacts.transactionBrokerCompensation  \
# 0      Acalanes (925) 280-3900                                    None
# 1        Moraga (925) 376-5943                                    None
#
#   resoFacts.storiesTotal resoFacts.cumulativeDaysOnMarket  \
# 0                   None                             None
# 1                   None                             None
#
#    resoFacts.fireplaces resoFacts.irrigationWaterRightsYN  \
# 0                     0                              None
# 1                     1                              None
#
#   resoFacts.exclusions resoFacts.hasOpenParking resoFacts.landLeaseAmount  \
# 0                 None                     None                      None
# 1                 None                     None                      None
#
#    resoFacts.coveredParkingCapacity resoFacts.middleOrJuniorSchool  \
# 0                                 2                           None
# 1                                 0                           None
#
#   resoFacts.hasElectricOnProperty  resoFacts.onMarketDate  \
# 0                            None           1717718400000
# 1                            True           1716940800000
#
#    resoFacts.pricePerSquareFoot  resoFacts.parkingCapacity  \
# 0                           583                          2
# 1                           626                          0
#
#           resoFacts.levels  listingSubType.is_FSBA  \
# 0  Two Story,Three Or More                   False
# 1            Two Story,Two                    True
#
#    listingSubType.is_comingSoon  listingSubType.is_newHome  \
# 0                         False                       True
# 1                         False                      False
#
#    listingSubType.is_pending  listingSubType.is_forAuction  \
# 0                      False                         False
# 1                      False                         False
#
#    listingSubType.is_foreclosure  listingSubType.is_bankOwned  \
# 0                          False                        False
# 1                          False                        False
#
#    listingSubType.is_openHouse  listingSubType.is_FSBO  \
# 0                        False                   False
# 1                        False                   False
#
#    listed_by.agent_reason  listed_by.zpro  listed_by.recent_sales  \
# 0                       3           False                       0
# 1                       3           False                       1
#
#             listed_by.zuid  listed_by.review_count listed_by.display_name  \
# 0  X1-ZUyyf6lq8lxg5l_6ikyk                      11          Vanessa Klein
# 1  X1-ZUya8fgvymyd55_6frtm                     109               Jean Zhu
#
#                                listed_by.profile_url listed_by.business_name  \
# 0  https://www.zillow.com/profile/VanessaKleinRea...  Coldwell Banker Realty
# 1           https://www.zillow.com/profile/Jean-Zhu/  Coldwell Banker Realty
#
#    listed_by.rating_average listed_by.phone.prefix listed_by.phone.areacode  \
# 0                         5                    214                      510
# 1                         5                    800                      925
#
#   listed_by.phone.number listed_by.badge_type  \
# 0                   2184        Listing Agent
# 1                   9999        Listing Agent
#
#                                  listed_by.image_url  \
# 0  https://photos.zillowstatic.com/h_n/ISifjw30r3...
# 1  https://photos.zillowstatic.com/h_n/ISz7kwbt95...
#
#    mortgageRates.thirtyYearFixedRate attributionInfo.buyerAgentName  \
# 0                              6.598                           None
# 1                              6.598                           None
#
#        attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0  bridgeMLS/CCAR/Bay East AOR                                 None
# 1  bridgeMLS/CCAR/Bay East AOR                        DRE #01703380
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-06-07 16:00:05                                         None
# 1         2024-06-05 16:50:11                                         None
#
#   attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0     Coldwell Banker Realty                             None
# 1     Coldwell Banker Realty                             None
#
#                         attributionInfo.infoString10  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
# 1  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.trueStatus  \
# 0                       None
# 1                       None
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
# 1  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.agentEmail attributionInfo.agentName  \
# 0                       None             Vanessa Klein
# 1                       None                  Jean Zhu
#
#   attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                             None              41061166
# 1                             None              41061377
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1                     Jing Su                          None
#
#   attributionInfo.infoString5  \
# 0                510-258-2924
# 1                925-800-9999
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': 'DRE #01319331', 'memb...
# 1  [{'memberStateLicense': 'DRE #01884244', 'memb...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     510-258-2924                      DRE #01319331
# 1                     925-800-9999                      DRE #01884244
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
# 1  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.infoString16 attributionInfo.buyerBrokerageName  \
# 0                         None                               None
# 1                         None                               None
#
#                        attributionInfo.mlsDisclaimer  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
# 1  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      510-583-5400         2024-06-10 08:43:56
# 1                      925-837-4100         2024-06-10 08:43:56
#
#   resoFacts.view                    resoFacts.constructionMaterials  \
# 0            NaN                                                NaN
# 1    [Greenbelt]  [Aluminum Siding, Composition Shingles, Wood S...
#
#   listed_by.phone
# 0             NaN
# 1             NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#          streetAddress    city               county zipcode state    price  \
# 0      118 Wallace Cir  Moraga  Contra Costa County   94556    CA  1345000
# 1     133 Miramonte Dr  Moraga  Contra Costa County   94556    CA   948000
# 2  824 Country Club Dr  Moraga  Contra Costa County   94556    CA  1325000
# 3      20 Miramonte Dr  Moraga  Contra Costa County   94556    CA   899000
# 4     140 Miramonte Dr  Moraga  Contra Costa County   94556    CA  1095000
#
#     homeType timeOnZillow  zestimate  rentZestimate  livingArea  bedrooms  \
# 0  TOWNHOUSE       3 days  1379900.0           5699        2309         5
# 1  TOWNHOUSE      12 days        NaN           4500        1514         3
# 2  TOWNHOUSE      11 days  1385900.0           4798        1749         3
# 3  TOWNHOUSE      46 days        NaN           4600        1762         3
# 4  TOWNHOUSE      21 days        NaN           4600        1742         3
#
#    bathrooms  yearBuilt                                        description  \
# 0          4       2020  Welcome to an enchanting, contemporary communi...
# 1          2       1965  Welcome to this charming townhouse nestled by ...
# 2          3       1973  This wonderful Townhouse is situated in Moraga...
# 3          3       1964  Welcome home to a spacious nook in a charming,...
# 4          3       1965  Everything you could ask for in a Miramonte Ga...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': 0.10836423568191, 'date':...
# 1  [{'priceChangeRate': -0.020661157024793, 'date...
# 2  [{'priceChangeRate': 0.70967741935484, 'date':...
# 3  [{'priceChangeRate': -0.07319587628866, 'date'...
# 4  [{'priceChangeRate': 0.37735849056604, 'date':...
#
#                                           taxHistory       zpid
# 0  [{'time': 1686413116873, 'valueIncreaseRate': ...  333912391
# 1  [{'time': 1686413119767, 'valueIncreaseRate': ...   18471812
# 2  [{'time': 1686413124038, 'valueIncreaseRate': ...   18472073
# 3  [{'time': 1686413128198, 'valueIncreaseRate': ...   18471498
# 4  [{'time': 1686413131432, 'valueIncreaseRate': ...   18471819

# %%
# download file
#df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
#files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
data = """Name,Address
"""

# %%
for x in range (0,len(df_z_prop_detail_output),1):
  # Step 1: Open the file in write mode
  file = open('example.txt', 'a')

  # Step 2: Write text to the file
  if x==0:
    file.write("Name,Address\n")
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" CA"+"\n")
  else:
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" CA"+"\n")
  # Step 3: Close the file
file.close()

# %%
import pandas as pd
data=pd.read_csv('./example.txt')

# %%
df=data

# %%
# !rm -rf example.txt

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df["loc"] = df["Address"].apply(geolocator.geocode)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+118+Wallace+Cir%3B+Moraga+CA&format=json&limit=1

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef5dfaa6b269b8912c6fea7f00266835 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef5dfaa6b269b8912c6fea7f00266835&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef5dfaa6b269b8912c6fea7f00266835 = L.map(
#                 &quot;map_ef5dfaa6b269b8912c6fea7f00266835&quot;,
#                 {
#                     center: [37.8378765358021, -122.1392098400748],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d0ffe1521df9ac2957800bed9f5381c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef5dfaa6b269b8912c6fea7f00266835);
#
#
#             var marker_cluster_2d229ceebcf1025fb274fe9a0cd82252 = L.markerClusterGroup(
#                 {}
#             );
#             map_ef5dfaa6b269b8912c6fea7f00266835.addLayer(marker_cluster_2d229ceebcf1025fb274fe9a0cd82252);
#
#
#             var marker_cfc8510e41d72bf2d5083faecd722d00 = L.marker(
#                 [37.8357338, -122.1330461],
#                 {}
#             ).addTo(marker_cluster_2d229ceebcf1025fb274fe9a0cd82252);
#
#
#         var popup_8a92a2af73ff5a3d54c63e892292e63e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_010c96ee523526472322760356fe5e03 = $(`&lt;div id=&quot;html_010c96ee523526472322760356fe5e03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_0&lt;/div&gt;`)[0];
#                 popup_8a92a2af73ff5a3d54c63e892292e63e.setContent(html_010c96ee523526472322760356fe5e03);
#
#
#
#         marker_cfc8510e41d72bf2d5083faecd722d00.bindPopup(popup_8a92a2af73ff5a3d54c63e892292e63e)
#         ;
#
#
#
#
#             marker_cfc8510e41d72bf2d5083faecd722d00.bindTooltip(
#                 `&lt;div&gt;
#                      House_0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1fed2d8d3294b9b73b646440a70d55ac = L.marker(
#                 [37.83908824963956, -122.14323471616677],
#                 {}
#             ).addTo(marker_cluster_2d229ceebcf1025fb274fe9a0cd82252);
#
#
#         var popup_a90b4fb0c52a9b41f9fcf25a6d67f31d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d235f9a029d2a91d16d5595b458d90eb = $(`&lt;div id=&quot;html_d235f9a029d2a91d16d5595b458d90eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_1&lt;/div&gt;`)[0];
#                 popup_a90b4fb0c52a9b41f9fcf25a6d67f31d.setContent(html_d235f9a029d2a91d16d5595b458d90eb);
#
#
#
#         marker_1fed2d8d3294b9b73b646440a70d55ac.bindPopup(popup_a90b4fb0c52a9b41f9fcf25a6d67f31d)
#         ;
#
#
#
#
#             marker_1fed2d8d3294b9b73b646440a70d55ac.bindTooltip(
#                 `&lt;div&gt;
#                      House_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1122099a9c3fe99d717b3d053026df93 = L.marker(
#                 [37.83490655207515, -122.13308441891657],
#                 {}
#             ).addTo(marker_cluster_2d229ceebcf1025fb274fe9a0cd82252);
#
#
#         var popup_1b8890741de26ff3042c73019586d15f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89e82585b4a1a92e7885e71044da3d5f = $(`&lt;div id=&quot;html_89e82585b4a1a92e7885e71044da3d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_2&lt;/div&gt;`)[0];
#                 popup_1b8890741de26ff3042c73019586d15f.setContent(html_89e82585b4a1a92e7885e71044da3d5f);
#
#
#
#         marker_1122099a9c3fe99d717b3d053026df93.bindPopup(popup_1b8890741de26ff3042c73019586d15f)
#         ;
#
#
#
#
#             marker_1122099a9c3fe99d717b3d053026df93.bindTooltip(
#                 `&lt;div&gt;
#                      House_2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f5d43028e058458d591332fbc0d77055 = L.marker(
#                 [37.840668450692185, -122.14328778105961],
#                 {}
#             ).addTo(marker_cluster_2d229ceebcf1025fb274fe9a0cd82252);
#
#
#         var popup_ebb9bc34edff5d05dfe4c

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
