# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'briarcliff manor'
state = 'ny'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: briarcliff manor, ny

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Townhomes",
               "minPrice": "500000",
               "maxPrice": "900000",
               "sqftMin": "1000",
               "bedsMin": "2"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 436,
#    'address': '37 Deer Tree Lane, Briarcliff Manor, NY 10510',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b42b38bfb9f0bc9223a1379d4ca254ea-p_e.jpg',
#    'price': 674000,
#    'detailUrl': '/homedetails/37-Deer-Tree-Ln-Briarcliff-Manor-NY-10510/66520036_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -73.82334,
#    'latitude': 41.15874,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '66520036',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 1,
#    'bathrooms': 3,
#    'livingArea': 2106,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 436,
#    'address': '705 Pheasant Woods Road, Briarcliff Manor, NY 10510',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d4b8b1c2b1c5aeaf77a4ea15af3158f2-p_e.jpg',
#    'price': 750000,
#    'detailUrl': '/homedetails/705-Pheasant-Woods-Rd-Briarcliff-Manor-NY-10510/299052775_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -73.85892,
#    'latitude': 41.14359,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '299052775',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 9,
#    'bathrooms': 4,
#    'livingArea': 2586,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 436,
#    'address': '301 Glenwood Drive, Briarcliff Manor, NY 10510',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2cc6f3e0c26ca23fe7ccb56c2642165a-p_e.jpg',
#    'price': 725000,
#    'detailUrl': '/homedetails/301-Glenwood-Dr-Briarcliff-Manor-NY-10510/299052762_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -73.859474,
#    'latitude': 41.144203,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '299052762',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 16,
#    'bathrooms': 3,
#    'livingArea': 2390,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 3485,
#    'address': '12 Jackson Road, Briarcliff Manor, NY 10510',
#    'variableData': None,
#    'priceChange': -25000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/596f12394f409d7c6249d86cfb428eb6-p_e.jpg',
#    'price': 900000,
#    'detailUrl': '/homedetails/12-Jackson-Rd-Briarcliff-NY-10510/33055040_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -73.82087,
#    'latitude': 41.141403,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '33055040',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 51,
#    'bathrooms': 4,
#    'livingArea': 2446,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 1,
#  'totalResultCount': 4,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 4
# Num of cols: 26
#   dateSold propertyType  lotAreaValue  \
# 0     None    TOWNHOUSE           436
# 1     None    TOWNHOUSE           436
# 2     None    TOWNHOUSE           436
# 3     None    TOWNHOUSE          3485
#
#                                              address variableData  \
# 0      37 Deer Tree Lane, Briarcliff Manor, NY 10510         None
# 1  705 Pheasant Woods Road, Briarcliff Manor, NY ...         None
# 2     301 Glenwood Drive, Briarcliff Manor, NY 10510         None
# 3        12 Jackson Road, Briarcliff Manor, NY 10510         None
#
#    priceChange zestimate                                             imgSrc  \
# 0          NaN      None  https://photos.zillowstatic.com/fp/b42b38bfb9f...
# 1          NaN      None  https://photos.zillowstatic.com/fp/d4b8b1c2b1c...
# 2          NaN      None  https://photos.zillowstatic.com/fp/2cc6f3e0c26...
# 3     -25000.0      None  https://photos.zillowstatic.com/fp/596f12394f4...
#
#     price                                          detailUrl  bedrooms  \
# 0  674000  /homedetails/37-Deer-Tree-Ln-Briarcliff-Manor-...         3
# 1  750000  /homedetails/705-Pheasant-Woods-Rd-Briarcliff-...         3
# 2  725000  /homedetails/301-Glenwood-Dr-Briarcliff-Manor-...         2
# 3  900000  /homedetails/12-Jackson-Rd-Briarcliff-NY-10510...         4
#
#   contingentListingType  longitude   latitude listingStatus       zpid  \
# 0                  None -73.823340  41.158740      FOR_SALE   66520036
# 1                  None -73.858920  41.143590      FOR_SALE  299052775
# 2                  None -73.859474  41.144203      FOR_SALE  299052762
# 3                  None -73.820870  41.141403      FOR_SALE   33055040
#
#   rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0          None             1          3        2106     USA      USD
# 1          None             9          4        2586     USA      USD
# 2          None            16          3        2390     USA      USD
# 3          None            51          4        2446     USA      USD
#
#   lotAreaUnit  hasImage  listingSubType.is_FSBA listingSubType.is_openHouse
# 0        sqft      True                    True                        True
# 1        sqft      True                    True                         NaN
# 2        sqft      True                    True                         NaN
# 3        sqft      True                    True                         NaN

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['66520036', '299052775', '299052762', '33055040']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 4
# Num of cols: 299
#   listingProvider       zpid buildingPermits  propertyTaxRate  \
# 0            None   66520036            None             1.58
# 1            None  299052775            None             1.58
#
#                                   contact_recipients zipcode  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   10510
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   10510
#
#                                    openHouseSchedule  longitude  \
# 0  [{'startTime': '2024-06-01 12:00:00', 'endTime...  -73.82334
# 1                                                NaN  -73.85892
#
#   zestimateLowPercent  cityId timeOnZillow  \
# 0                None   28254        1 day
# 1                None   28254       9 days
#
#                                                  url zestimate  \
# 0  /homedetails/37-Deer-Tree-Ln-Briarcliff-Manor-...      None
# 1  /homedetails/705-Pheasant-Woods-Rd-Briarcliff-...      None
#
#                                               imgSrc  \
# 0  https://photos.zillowstatic.com/fp/b42b38bfb9f...
# 1  https://photos.zillowstatic.com/fp/d4b8b1c2b1c...
#
#                                          description   price  livingAreaValue  \
# 0  Welcome home to Wyndcrest, where modern living...  674000             2106
# 1  Come enjoy the carefree lifestyle of Scarborou...  750000             2586
#
#   brokerId  stateId            streetAddress solarPotential dateSold  \
# 0     None       43        37 Deer Tree Lane           None     None
# 1     None       43  705 Pheasant Woods Road           None     None
#
#    countyId          timeZone   homeType livingAreaUnits  \
# 0      3148  America/New_York  TOWNHOUSE            sqft
# 1      3148  America/New_York  TOWNHOUSE            sqft
#
#   comingSoonOnMarketDate rentZestimate  bathrooms  annualHomeownersInsurance  \
# 0                   None          None          3                       2831
# 1                   None          None          4                       3150
#
#   state propertyTypeDimension building  yearBuilt           brokerageName  \
# 0    NY             Townhouse     None       1997  Houlihan Lawrence Inc.
# 1    NY             Townhouse     None       2001  Houlihan Lawrence Inc.
#
#    pageViewCount              county  monthlyHoaFee homeStatus homeFacts  \
# 0           1804  Westchester County          500.0   FOR_SALE      None
# 1           1445  Westchester County          644.0   FOR_SALE      None
#
#    latitude  datePosted  bedrooms  \
# 0  41.15874  2024-05-29         3
# 1  41.14359  2024-05-22         3
#
#                                          nearbyHomes  livingArea  \
# 0  [{'livingArea': None, 'livingAreaValue': None,...        2106
# 1  [{'livingArea': 2146, 'livingAreaValue': 2146,...        2586
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0.14237288135593, 'date':...            191
# 1  [{'priceChangeRate': 0.2448132780083, 'date': ...             58
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/new-yo...                 None
# 1  [{'link': 'https://www.greatschools.org/new-yo...                 None
#
#       mlsid countyFIPS              city providerListingID country currency  \
# 0  H6309811      36119  Briarcliff Manor              None     USA      USD
# 1  H6302920      36119  Briarcliff Manor              None     USA      USD
#
#   isListedByOwner contingentListingType address.community      address.city  \
# 0            None                  None              None  Briarcliff Manor
# 1            None                  None              None  Briarcliff Manor
#
#   address.state address.neighborhood address.subdivision  \
# 0            NY                 None                None
# 1            NY                 None                None
#
#      address.streetAddress address.zipcode  resoFacts.hasAttachedProperty  \
# 0        37 Deer Tree Lane           10510                           True
# 1  705 Pheasant Woods Road           10510                           True
#
#   resoFacts.frontageType resoFacts.poolFeatures  resoFacts.flooring  \
# 0                   None                   None                None
# 1                   None                   None  [Hardwood, Carpet]
#
#   resoFacts.builderModel resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0              Abbington                            None                False
# 1                   None                            None                 True
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     True               None                 None
# 1                     True               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
# 1                              None                           False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factValue': 'Condominium, Townhouse', 'fact...
# 1                  None  [{'factValue': 'Condominium, Townhouse', 'fact...
#
#   resoFacts.offerReviewDate resoFacts.horseYN  \
# 0                      None              None
# 1                      None              None
#
#   resoFacts.buyerAgencyCompensationType resoFacts.belowGradeFinishedArea  \
# 0                                     %                             None
# 1                                     %                             None
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': None, 'name': None, 'fee': '$500 mo...     Briarcliff Manor
# 1  [{'phone': None, 'name': None, 'fee': '$644 mo...     Briarcliff Manor
#
#   resoFacts.subAgencyCompensation resoFacts.hasPrivatePool  \
# 0                            None                     None
# 1                            None                     None
#
#                     resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0  [Maintenance Grounds, Maintenance Structure, S...              [Public]
# 1  [Maintenance Grounds, Maintenance Structure, O...              [Public]
#
#   resoFacts.carportParkingCapacity  \
# 0                             None
# 1                             None
#
#   resoFacts.transactionBrokerCompensationType resoFacts.hasFireplace  \
# 0                                        None                   True
# 1                                        None                   True
#
#   resoFacts.gas resoFacts.sewer resoFacts.elevationUnits  \
# 0          None  [Public Sewer]                     None
# 1          None  [Public Sewer]                     None
#
#   resoFacts.roadSurfaceType resoFacts.mainLevelBedrooms  \
# 0                      None                        None
# 1                      None                        None
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView  \
# 0                          None                        None
# 1                          None                        None
#
#   resoFacts.bathroomsOneQuarter resoFacts.lotSize  \
# 0                          None          436 sqft
# 1                          None          436 sqft
#
#   resoFacts.subAgencyCompensationType resoFacts.entryLevel  \
# 0                                None                 None
# 1                                None                 None
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.greenWaterConservation  \
# 0                                 None                             None
# 1                                 None                             None
#
#    resoFacts.stories  resoFacts.bathrooms resoFacts.numberOfUnitsInCommunity  \
# 0                3.0                    3                               None
# 1                3.0                    4                               None
#
#   resoFacts.listingTerms resoFacts.otherParking resoFacts.associationFee  \
# 0                   None   [Assigned Spaces: 2]             $500 monthly
# 1                   None                   None             $644 monthly
#
#   resoFacts.marketingType resoFacts.greenEnergyEfficient  \
# 0                    None                           None
# 1                    None                           None
#
#   resoFacts.greenSustainability          resoFacts.heating  \
# 0                          None  [Natural Gas, Forced Air]
# 1                          None  [Natural Gas, Forced Air]
#
#   resoFacts.associationPhone resoFacts.greenBuildingVerificationType  \
# 0                       None                                    None
# 1                       None                                    None
#
#    resoFacts.hasAttachedGarage  resoFacts.bedrooms  \
# 0                        False                   3
# 1                         True                   3
#
#   resoFacts.architecturalStyle resoFacts.listingId resoFacts.structureType  \
# 0                         None                None               Townhouse
# 1                         None                None               Townhouse
#
#                           resoFacts.interiorFeatures resoFacts.horseAmenities  \
# 0             [Cathedral Ceiling(s), Eat-in Kitchen]                     None
# 1  [Cathedral Ceiling(s), Eat-in Kitchen, Master ...                     None
#
#   resoFacts.electric              resoFacts.lotFeatures resoFacts.roofType  \
# 0               None  [Near Public Transit, Cul-De-Sac]               None
# 1               None  [Near Public Transit, Cul-De-Sac]               None
#
#   resoFacts.compensationBasedOn resoFacts.greenEnergyGeneration  \
# 0                          None                            None
# 1                          None                            None
#
#    resoFacts.taxAnnualAmount  resoFacts.daysOnZillow resoFacts.listAOR  \
# 0                      10649                       1              None
# 1                      11850                       9              None
#
#    resoFacts.hasHeating resoFacts.elementarySchool  \
# 0                  True     Todd Elementary School
# 1                  True         Call Listing Agent
#
#   resoFacts.constructionMaterials  resoFacts.basementYN resoFacts.hoaFeeTotal  \
# 0                [Shingle Siding]                  True          $500 monthly
# 1            [Frame, Wood Siding]                  True          $644 monthly
#
#                                 resoFacts.appliances resoFacts.virtualTour  \
# 0  [Cooktop, Dishwasher, Dryer, Microwave, Oven, ...                  None
# 1  [Dishwasher, Dryer, Microwave, Oven, Refrigera...                  None
#
#   resoFacts.bathroomsPartial resoFacts.fencing resoFacts.yearBuiltEffective  \
# 0                       None              None                         None
# 1                       None              None                         None
#
#      resoFacts.buildingName resoFacts.hasAssociation  \
# 0                 Wyndcrest                     True
# 1  Scarborough Glen - Condo                     True
#
#   resoFacts.isSeniorCommunity resoFacts.propertySubType  \
# 0                        None  [Condominium, Townhouse]
# 1                        None  [Condominium, Townhouse]
#
#   resoFacts.propertyCondition  resoFacts.hasCarport  resoFacts.canRaiseHorses  \
# 0                        None                 False                     False
# 1                        None                 False                     False
#
#    resoFacts.hasLandLease resoFacts.communityFeatures  \
# 0                   False                [Pool, Park]
# 1                   False           [Clubhouse, Pool]
#
#          resoFacts.parcelNumber resoFacts.elevation  \
# 0  4201098007000000000004000491                None
# 1  4201097015000000000007000354                None
#
#   resoFacts.lotSizeDimensions resoFacts.buildingAreaSource  \
# 0                        None                         None
# 1                        None                         None
#
#   resoFacts.contingency  resoFacts.yearBuilt resoFacts.otherStructures  \
# 0                  None                 1997                      None
# 1                  None                 2001                      None
#
#   resoFacts.livingArea  resoFacts.bathroomsFull  \
# 0           2,106 sqft                        2
# 1           2,586 sqft                        2
#
#   resoFacts.livingAreaRangeUnits resoFacts.incomeIncludes  \
# 0                           None                     None
# 1                           None                     None
#
#      resoFacts.highSchool resoFacts.aboveGradeFinishedArea  \
# 0  Briarcliff High School                             None
# 1    Ossining High School                             None
#
#   resoFacts.isNewConstruction  \
# 0                        None
# 1                        None
#
#                                 resoFacts.inclusions  \
# 0  [Alarm System, B/I Shelves, Ceiling Fan, Chand...
# 1  [Ceiling Fan, Dishwasher, Dryer, Garage Door O...
#
#    resoFacts.hasHomeWarranty resoFacts.additionalFeeInfo  \
# 0                      False                        None
# 1                      False                        None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0                     None               Condo                 None
# 1                     None               Condo                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                       Briarcliff Manor                        None
# 1                               Ossining                        None
#
#   resoFacts.exteriorFeatures resoFacts.buildingFeatures  \
# 0         [Basketball Court]                       None
# 1                        NaN                       None
#
#   resoFacts.frontageLength resoFacts.buildingArea  \
# 0                     None                  2,106
# 1                     None                  2,586
#
#   resoFacts.associationAmenities  resoFacts.bathroomsHalf  \
# 0                           None                        1
# 1                           None                        2
#
#    resoFacts.hasCooling resoFacts.additionalParcelsDescription  \
# 0                  True                                   None
# 1                  True                                   None
#
#                  resoFacts.parkingFeatures resoFacts.foundationArea  \
# 0  [Assigned, Common, Driveway, No Garage]                     None
# 1                               [Attached]                     None
#
#   resoFacts.zoning resoFacts.hoaFee resoFacts.livingAreaRange  \
# 0             None     $500 monthly                      None
# 1             None     $644 monthly                      None
#
#   resoFacts.zoningDescription resoFacts.developmentStatus  \
# 0                        None                        None
# 1                        None                        None
#
#   resoFacts.availabilityDate resoFacts.waterfrontFeatures  \
# 0                       None                         None
# 1                       None                         None
#
#   resoFacts.waterBodyName resoFacts.utilities resoFacts.entryLocation  \
# 0                    None                None                     End
# 1                    None                None                     End
#
#   resoFacts.totalActualRent  resoFacts.hasView resoFacts.subdivisionName  \
# 0                      None              False                 Wyndcrest
# 1                      None              False  Scarborough Glen - Condo
#
#   resoFacts.securityFeatures resoFacts.attic resoFacts.fireplaceFeatures  \
# 0                       None         Partial                        None
# 1                       None         Scuttle                        None
#
#   resoFacts.mainLevelBathrooms resoFacts.doorFeatures resoFacts.ownershipType  \
# 0                         None                   None                    None
# 1                         None                   None                    None
#
#   resoFacts.associationName  \
# 0                      None
# 1                      None
#
#                               resoFacts.associations resoFacts.waterView  \
# 0  [{'feeFrequency': '$500 monthly', 'name': None...                None
# 1  [{'feeFrequency': '$644 monthly', 'name': None...                None
#
#    resoFacts.garageParkingCapacity resoFacts.cropsIncludedYN  \
# 0                              NaN                      None
# 1                              NaN                      None
#
#   resoFacts.laundryFeatures resoFacts.buyerAgencyCompensation  \
# 0                      None                                 2
# 1                      None                                 2
#
#   resoFacts.greenIndoorAirQuality resoFacts.homeType resoFacts.spaFeatures  \
# 0                            None          Townhouse                  None
# 1                            None          Townhouse                  None
#
#   resoFacts.municipality resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  \
# 0                   None                            None             False
# 1                   None                            None             False
#
#                         resoFacts.basement resoFacts.associationFee2  \
# 0                 Finished,Walk-Out Access                      None
# 1  Full,Partially Finished,Walk-Out Access                      None
#
#   resoFacts.cooling resoFacts.openParkingCapacity resoFacts.associationName2  \
# 0     [Central Air]                          None                       None
# 1     [Central Air]                          None                       None
#
#   resoFacts.hasRentControl resoFacts.elementarySchoolDistrict  \
# 0                     None                   Briarcliff Manor
# 1                     None                           Ossining
#
#   resoFacts.otherEquipment resoFacts.commonWalls  \
# 0                     None       2+ Common Walls
# 1                     None       2+ Common Walls
#
#   resoFacts.specialListingConditions  resoFacts.furnished  \
# 0                               None                False
# 1                               None                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                          [Deck]
# 1                 None                          [Deck]
#
#    resoFacts.bathroomsFloat resoFacts.builderName  \
# 0                         3                  None
# 1                         4                  None
#
#   resoFacts.highSchoolDistrict resoFacts.transactionBrokerCompensation  \
# 0             Briarcliff Manor                                    None
# 1                     Ossining                                    None
#
#    resoFacts.storiesTotal resoFacts.cumulativeDaysOnMarket  \
# 0                     4.0                             None
# 1                     NaN                             None
#
#    resoFacts.fireplaces resoFacts.irrigationWaterRightsYN  \
# 0                   1.0                              None
# 1                   1.0                              None
#
#                 resoFacts.exclusions resoFacts.hasOpenParking  \
# 0  [Curtains/Drapes, Second Freezer]                     True
# 1                               None                     None
#
#   resoFacts.landLeaseAmount  resoFacts.coveredParkingCapacity  \
# 0                      None                               NaN
# 1                      None                               NaN
#
#   resoFacts.middleOrJuniorSchool resoFacts.hasElectricOnProperty  \
# 0       Briarcliff Middle School                            None
# 1    Anne M Dorner Middle School                            None
#
#    resoFacts.onMarketDate  resoFacts.pricePerSquareFoot  \
# 0           1717113600000                           320
# 1           1716336000000                           290
#
#    resoFacts.parkingCapacity resoFacts.levels  listingSubType.is_FSBA  \
# 0                          0    Three Or More                    True
# 1                          1    Three Or More                    True
#
#    listingSubType.is_comingSoon  listingSubType.is_newHome  \
# 0                         False                      False
# 1                         False                      False
#
#    listingSubType.is_pending  listingSubType.is_forAuction  \
# 0                      False                         False
# 1                      False                         False
#
#    listingSubType.is_foreclosure  listingSubType.is_bankOwned  \
# 0                          False                        False
# 1                          False                        False
#
#    listingSubType.is_openHouse  listingSubType.is_FSBO  \
# 0                         True                   False
# 1                        False                   False
#
#    listed_by.agent_reason listed_by.zpro  listed_by.recent_sales  \
# 0                     3.0          False                     0.0
# 1                     3.0          False                     1.0
#
#             listed_by.zuid  listed_by.review_count listed_by.display_name  \
# 0  X1-ZUxlaaa0t256a1_6frtm                    39.0    Bonnie Field Besner
# 1  X1-ZUywmhvi1ukk5l_6o78g                    20.0  Maria “Teresa” Duguet
#
#                                listed_by.profile_url listed_by.business_name  \
# 0       https://www.zillow.com/profile/bonnie-field/  Houlihan Lawrence Inc.
# 1  https://www.zillow.com/profile/Teresaduguetrea...  Houlihan Lawrence Inc.
#
#    listed_by.rating_average listed_by.phone.prefix listed_by.phone.areacode  \
# 0                       5.0                    446                      917
# 1                       5.0                    420                      914
#
#   listed_by.phone.number listed_by.badge_type  \
# 0                   0211        Listing Agent
# 1                   8155        Listing Agent
#
#                                  listed_by.image_url  \
# 0  https://photos.zillowstatic.com/h_n/ISy3tcrh8y...
# 1  https://photos.zillowstatic.com/h_n/IS3zbfbufc...
#
#    mortgageRates.thirtyYearFixedRate attributionInfo.buyerAgentName  \
# 0                              6.755                           None
# 1                              6.811                           None
#
#   attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0             OneKey® MLS                                 None
# 1             OneKey® MLS                                 None
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-05-30 22:23:25                                         None
# 1         2024-05-25 12:11:25                                         None
#
#   attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0     Houlihan Lawrence Inc.                             None
# 1     Houlihan Lawrence Inc.                             None
#
#                         attributionInfo.infoString10  \
# 0  The data relating to real estate for sale or l...
# 1  The data relating to real estate for sale or l...
#
#   attributionInfo.trueStatus  \
# 0                       None
# 1                       None
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/4e66a55bd37...
# 1  https://photos.zillowstatic.com/fp/4e66a55bd37...
#
#   attributionInfo.agentEmail attributionInfo.agentName  \
# 0                       None             Bonnie Besner
# 1                       None       Maria Teresa Duguet
#
#   attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                      Listing by:              H6309811
# 1                      Listing by:              H6302920
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1                        None                          None
#
#   attributionInfo.infoString5  \
# 0                917-446-0211
# 1                914-420-8155
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': '10401276339', 'member...
# 1  [{'memberStateLicense': '10301200212', 'member...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     917-446-0211                               None
# 1                     914-420-8155                               None
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/4e66a55bd37...
# 1  https://photos.zillowstatic.com/fp/4e66a55bd37...
#
#   attributionInfo.infoString16 attributionInfo.buyerBrokerageName  \
# 0                         None                               None
# 1                         None                               None
#
#                        attributionInfo.mlsDisclaimer  \
# 0  The data relating to real estate for sale or l...
# 1  The data relating to real estate for sale or l...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      914-762-7200         2024-05-31 10:59:32
# 1                      914-762-7200         2024-05-31 11:05:04
#
#                                           taxHistory  \
# 0                                                NaN
# 1  [{'time': 1685556504117, 'valueIncreaseRate': ...
#
#                                      resoFacts.rooms  listed_by.phone
# 0                                                NaN              NaN
# 1  [{'level': None, 'dimensions': None, 'features...              NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#              streetAddress              city              county zipcode  \
# 0        37 Deer Tree Lane  Briarcliff Manor  Westchester County   10510
# 1  705 Pheasant Woods Road  Briarcliff Manor  Westchester County   10510
# 2       301 Glenwood Drive  Briarcliff Manor  Westchester County   10510
# 3          12 Jackson Road        Briarcliff  Westchester County   10510
#
#   state   price   homeType timeOnZillow zestimate rentZestimate  livingArea  \
# 0    NY  674000  TOWNHOUSE        1 day      None          None        2106
# 1    NY  750000  TOWNHOUSE       9 days      None          None        2586
# 2    NY  725000  TOWNHOUSE      16 days      None          None        2390
# 3    NY  900000  TOWNHOUSE      51 days      None          None        2446
#
#    bedrooms  bathrooms  yearBuilt  \
# 0         3          3       1997
# 1         3          4       2001
# 2         2          3       1996
# 3         4          4       1972
#
#                                          description  \
# 0  Welcome home to Wyndcrest, where modern living...
# 1  Come enjoy the carefree lifestyle of Scarborou...
# 2  Beautiful four-level end unit in sought-after ...
# 3  Welcome to this beautiful single family attach...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': 0.14237288135593, 'date':...
# 1  [{'priceChangeRate': 0.2448132780083, 'date': ...
# 2  [{'priceChangeRate': 2.2954545454545, 'date': ...
# 3  [{'priceChangeRate': -0.027027027027027, 'date...
#
#                                           taxHistory       zpid
# 0                                                NaN   66520036
# 1  [{'time': 1685556504117, 'valueIncreaseRate': ...  299052775
# 2  [{'time': 1685556506943, 'valueIncreaseRate': ...  299052762
# 3  [{'time': 1685556509886, 'valueIncreaseRate': ...   33055040

# %%
# download file
#df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
#files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
df_z_prop_detail_output['streetAddress'].iloc[0]
# Out:
# '37 Deer Tree Lane'

# %%
data = """Name,Address
"""

# %%
for x in range (0,len(df_z_prop_detail_output),1):
  # Step 1: Open the file in write mode
  file = open('example.txt', 'a')

  # Step 2: Write text to the file
  if x==0:
    file.write("Name,Address\n")
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" NY"+"\n")
  else:
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" NY"+"\n")
  # Step 3: Close the file
file.close()

# %%
import pandas as pd
data=pd.read_csv('./example.txt')

# %%
df=data

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df["loc"] = df["Address"].apply(geolocator.geocode)

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87011af5b62a33ada727a41a24492828 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87011af5b62a33ada727a41a24492828&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87011af5b62a33ada727a41a24492828 = L.map(
#                 &quot;map_87011af5b62a33ada727a41a24492828&quot;,
#                 {
#                     center: [41.146993075, -73.84065375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45485f6146aff8a0003ec1885d9fc83b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_87011af5b62a33ada727a41a24492828);
#
#
#             var marker_cluster_b0b61ca5739ec9e5f1c5988120d2d7ee = L.markerClusterGroup(
#                 {}
#             );
#             map_87011af5b62a33ada727a41a24492828.addLayer(marker_cluster_b0b61ca5739ec9e5f1c5988120d2d7ee);
#
#
#             var marker_11d3de159cf8ecb26b2e0acb90b3e8f0 = L.marker(
#                 [41.1587688, -73.8233436],
#                 {}
#             ).addTo(marker_cluster_b0b61ca5739ec9e5f1c5988120d2d7ee);
#
#
#         var popup_16828d2559cfb61d04d31d923c57ec7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04931428a16a10d0c0e3e34ef184b345 = $(`&lt;div id=&quot;html_04931428a16a10d0c0e3e34ef184b345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_0&lt;/div&gt;`)[0];
#                 popup_16828d2559cfb61d04d31d923c57ec7b.setContent(html_04931428a16a10d0c0e3e34ef184b345);
#
#
#
#         marker_11d3de159cf8ecb26b2e0acb90b3e8f0.bindPopup(popup_16828d2559cfb61d04d31d923c57ec7b)
#         ;
#
#
#
#
#             marker_11d3de159cf8ecb26b2e0acb90b3e8f0.bindTooltip(
#                 `&lt;div&gt;
#                      House_0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9caccf79099a866cea2226b73ef98532 = L.marker(
#                 [41.1435903, -73.8589206],
#                 {}
#             ).addTo(marker_cluster_b0b61ca5739ec9e5f1c5988120d2d7ee);
#
#
#         var popup_0df2731b6ea3ba20ff16f4a52d88afd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1827314fe3d3dd7abd70c088e650d70d = $(`&lt;div id=&quot;html_1827314fe3d3dd7abd70c088e650d70d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_1&lt;/div&gt;`)[0];
#                 popup_0df2731b6ea3ba20ff16f4a52d88afd7.setContent(html_1827314fe3d3dd7abd70c088e650d70d);
#
#
#
#         marker_9caccf79099a866cea2226b73ef98532.bindPopup(popup_0df2731b6ea3ba20ff16f4a52d88afd7)
#         ;
#
#
#
#
#             marker_9caccf79099a866cea2226b73ef98532.bindTooltip(
#                 `&lt;div&gt;
#                      House_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1e439eb9d511de252d51956a852b686c = L.marker(
#                 [41.1442026, -73.8594755],
#                 {}
#             ).addTo(marker_cluster_b0b61ca5739ec9e5f1c5988120d2d7ee);
#
#
#         var popup_50f5b3b883648508e457656c3779a63e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7373ed370833c4e6ae2cd6e7d361f53e = $(`&lt;div id=&quot;html_7373ed370833c4e6ae2cd6e7d361f53e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_2&lt;/div&gt;`)[0];
#                 popup_50f5b3b883648508e457656c3779a63e.setContent(html_7373ed370833c4e6ae2cd6e7d361f53e);
#
#
#
#         marker_1e439eb9d511de252d51956a852b686c.bindPopup(popup_50f5b3b883648508e457656c3779a63e)
#         ;
#
#
#
#
#             marker_1e439eb9d511de252d51956a852b686c.bindTooltip(
#                 `&lt;div&gt;
#                      House_2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1a43cbefe77a98525011007eb6caaa9e = L.marker(
#                 [41.1414106, -73.8208753],
#                 {}
#             ).addTo(marker_cluster_b0b61ca5739ec9e5f1c5988120d2d7ee);
#
#
#         var popup_054e750477b15275a35401377ce20393 = L.popup({&quot;maxWidth&quot;: &quot;100%&q

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
