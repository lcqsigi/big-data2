# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'concord'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Search string: concord, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"HOUSES",
               "minPrice": "800000",
               "maxPrice": "1000000",
               "sqftMin": "1500"}

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8712,
#    'address': '1925 N 3rd St, Concord, CA 94519',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 905600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e26baffdd56b9d3d924ec8e8a666fe0a-p_e.jpg',
#    'price': 866000,
#    'detailUrl': '/homedetails/1925-N-3rd-St-Concord-CA-94519/18344088_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.026436,
#    'latitude': 37.980556,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18344088',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3519,
#    'daysOnZillow': 0,
#    'bathrooms': 2,
#    'livingArea': 1537,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7301,
#    'address': '4070 Wilson Ln, Concord, CA 94521',
#    'variableData': {'text': 'Open: Fri. 4:30-7pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': 989600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ce24aa44cea4963c03dd6a19ed7b9019-p_e.jpg',
#    'price': 965000,
#    'detailUrl': '/homedetails/4070-Wilson-Ln-Concord-CA-94521/18350092_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -121.99334,
#    'latitude': 37.972626,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18350092',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3699,
#    'daysOnZillow': 6,
#    'bathrooms': 2,
#    'livingArea': 1795,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8712,
#    'address': '3594 Kimball Way, Concord, CA 94518',
#    'variableData': {'text': 'Open: Sat. 1-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/faf2087a39f1baefb2ed5f7d9e0adedf-p_e.jpg',
#    'price': 888000,
#    'detailUrl': '/homedetails/3594-Kimball-Way-Concord-CA-94518/18339530_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.00927,
#    'latitude': 37.967735,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18339530',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3522,
#    'daysOnZillow': 15,
#    'bathrooms': 2,
#    'livingArea': 1655,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9583.2,
#    'address': '1506 American Beauty Dr, Concord, CA 94521',
#    'variableData': {'text': 'Open: Sat. 1-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/8433b102a0e795816ba18ea19c420062-p_e.jpg',
#    'price': 848000,
#    'detailUrl': '/homedetails/1506-American-Beauty-Dr-Concord-CA-94521/18354159_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -121.9652,
#    'latitude': 37.955235,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18354159',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3594,
#    'daysOnZillow': 6,
#    'bathrooms': 2,
#    'livingArea': 1558,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7405.2,
#    'address': '2872 Lyon Cir, Concord, CA 94518',
#    'variableData': {'text': 'Open: Sat. 1-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': 1060000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/211b9946f90188bf7384d79a1f5b92d6-p_e.jpg',
#    'price': 999999,
#    'detailUrl': '/homedetails/2872-Lyon-Cir-Concord-CA-94518/18368386_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.02328,
#    'latitude': 37.94753,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18368386',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3890,
#    'daysOnZillow': 3,
#    'bathrooms': 2,
#    'livingArea': 2078,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10454.4,
#    'address': '5103 Coral Ct, Concord, CA 94521',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e7199349110b4767e6035810054330d2-p_e.jpg',
#    'price': 800000,
#    'detailUrl': '/homedetails/5103-Coral-Ct-Concord-CA-94521/18353668_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -121.964226,
#    'latitude': 37.962387,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18353668',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3599,
#    'daysOnZillow': '6',
#    'bathrooms': 2,
#    'livingArea': 1612,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.36000918273646,
#    'address': '1042 Kaski Ln, Concord, CA 94518',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d185ee45571fb01ee99f6d9778169a81-p_e.jpg',
#    'price': 995000,
#    'detailUrl': '/homedetails/1042-Kaski-Ln-Concord-CA-94518/18369676_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.00897,
#    'latitude': 37.95182,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18369676',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': '7',
#    'bathrooms': 2,
#    'livingArea': 1624,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7840.8,
#    'address': '5577 Ohio Ct, Concord, CA 94521',
#    'variableData': {'text': 'Open: Sat. 1-3pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -30000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/df85c6ec7ddc7cae355598ee8922986e-p_e.jpg',
#    'price': 849000,
#    'detailUrl': '/homedetails/5577-Ohio-Ct-Concord-CA-94521/18360039_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -121.9512,
#    'latitude': 37.941616,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18360039',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3499,
#    'daysOnZillow': 21,
#    'bathrooms': 3,
#    'livingArea': 1820,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5662.8,
#    'address': '1803 Alicante Ct, Concord, CA 94521',
#    'variableData': {'text': 'Open: Sat. 1-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e8f19b64689ff9e8d25daee0e1923568-p_e.jpg',
#    'price': 850000,
#    'detailUrl': '/homedetails/1803-Alicante-Ct-Concord-CA-94521/18355111_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -121.95065,
#    'latitude': 37.954086,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18355111',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3499,
#    'daysOnZillow': 7,
#    'bathrooms': 2,
#    'livingArea': 1657,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3049.2,
#    'address': '1250 Poppy Seed Ct, Concord, CA 94520',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cfc4b44a61df6b4b820368963e98254c-p_e.jpg',
#    'price': 888000,
#    'detailUrl': '/homedetails/1250-Poppy-Seed-Ct-Concord-CA-94520/68036293_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.04822,
#    'latitude': 37.947983,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '68036293',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3870,
#    'daysOnZillow': '27',
#    'bathrooms': 3,
#    'livingArea': 2043,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.35,
#    'address': '1326 Babel Ln, Concord, CA 94518',
#    'variableData': {'text': 'Open: Sat. 2-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -20000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aa27a4dff0ec443e883507469a592c79-p_e.jpg',
#    'price': 885000,
#    'detailUrl': '/homedetails/1326-Babel-Ln-Concord-CA-94518/18370332_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.008125,
#    'latitude': 37.964848,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18370332',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3499,
#    'daysOnZillow': 10,
#    'bathrooms': 2,
#    'livingArea': 1646,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7840.8,
#    'address': '1722 Shellwood Dr, Concord, CA 94521',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4493042118a64a9a5a5b9ef62e816339-p_e.jpg',
#    'price': 998500,
#    'detailUrl': '/homedetails/1722-Shellwood-Dr-Concord-CA-94521/18353354_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -121.97369,
#    'latitude': 37.96478,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18353354',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3695,
#    'daysOnZillow': '34',
#    'bathrooms': 2,
#    'livingArea': 1857,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '1675 Nuala St, Concord, CA 94518',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f9884197c764d08e1bbd07fb66d2a569-p_e.jpg',
#    'price': 999000,
#    'detailUrl': '/homedetails/1675-Nuala-St-Concord-CA-94518/18385954_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.04028,
#    'latitude': 37.94251,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18385954',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3629,
#    'daysOnZillow': '37',
#    'bathrooms': 2,
#    'livingArea': 1581,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2549,
#    'address': '1302 Tapestry Ln, Concord, CA 94520',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 893300,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d792ef2fd3e9c51fb74f3e871c6eeb5c-p_e.jpg',
#    'price': 850000,
#    'detailUrl': '/homedetails/1302-Tapestry-Ln-Concord-CA-94520/68042448_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.04446,
#    'latitude': 37.96163,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '68042448',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3949,
#    'daysOnZillow': '5',
#    'bathrooms': 3,
#    'livingArea': 2108,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '4289 Oakwood Ct, Concord, CA 94521',
#    'variableData': {'text': 'Open: Sat. 2-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': 1024100,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2fafd42c1eb3745357049f32db7b16bf-p_e.jpg',
#    'price': 969000,
#    'detailUrl': '/homedetails/4289-Oakwood-Ct-Concord-CA-94521/18350512_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -121.98936,
#    'latitude': 37.970867,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18350512',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3597,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1765,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7405.2,
#    'address': '1517 Criquet Ct, Concord, CA 94518',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'priceChange': None,
#    'zestimate': 1116700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9c1686d9e467bc37863efbab3668c47e-p_e.jpg',
#    'price': 999999,
#    'detailUrl': '/homedetails/1517-Criquet-Ct-Concord-CA-94518/18386909_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.04448,
#    'latitude': 37.94221,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18386909',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3900,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1849,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10018.8,
#    'address': '993 Oak Grove Rd, Concord, CA 94518',
#    'variableData': {'text': '$20,000 (Feb 29)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -20000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1d661b5fecb1fb0cf5f01d6bae544b43-p_e.jpg',
#    'price': 969000,
#    'detailUrl': '/homedetails/993-Oak-Grove-Rd-Concord-CA-94518/18385773_zpid/',
#    'bedrooms': 6,
#    'contingentListingType': None,
#    'longitude': -122.03384,
#    'latitude': 37.947807,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18385773',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3800,
#    'daysOnZillow': 131,
#    'bathrooms': 2,
#    'livingArea': 1795,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7840.8,
#    'address': '5345 Meadow Wood Pl, Concord, CA 94521',
#    'variableData': {'text': 'Open: Sun. 1-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': 951200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d15120190e8d4579517d6fe3b77cc3cf-p_e.jpg',
#    'price': 900000,
#    'detailUrl': '/homedetails/5345-Meadow-Wood-Pl-Concord-CA-94521/18354460_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -121.949936,
#    'latitude': 37.960762,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18354460',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3727,
#    'daysOnZillow': 0,
#    'bathrooms': 3,
#    'livingArea': 1921,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 1,
#  'totalResultCount': 18,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 18
# Num of cols: 28
#   dateSold   propertyType  lotAreaValue  \
# 0     None  SINGLE_FAMILY        8712.0
# 1     None  SINGLE_FAMILY        7301.0
# 2     None  SINGLE_FAMILY        8712.0
# 3     None  SINGLE_FAMILY        9583.2
# 4     None  SINGLE_FAMILY        7405.2
#
#                                       address  variableData  priceChange  \
# 0            1925 N 3rd St, Concord, CA 94519           NaN          NaN
# 1           4070 Wilson Ln, Concord, CA 94521           NaN          NaN
# 2         3594 Kimball Way, Concord, CA 94518           NaN          NaN
# 3  1506 American Beauty Dr, Concord, CA 94521           NaN          NaN
# 4            2872 Lyon Cir, Concord, CA 94518           NaN          NaN
#
#    zestimate                                             imgSrc   price  \
# 0   905600.0  https://photos.zillowstatic.com/fp/e26baffdd56...  866000
# 1   989600.0  https://photos.zillowstatic.com/fp/ce24aa44cea...  965000
# 2        NaN  https://photos.zillowstatic.com/fp/faf2087a39f...  888000
# 3        NaN  https://photos.zillowstatic.com/fp/8433b102a0e...  848000
# 4  1060000.0  https://photos.zillowstatic.com/fp/211b9946f90...  999999
#
#                                            detailUrl  bedrooms  \
# 0  /homedetails/1925-N-3rd-St-Concord-CA-94519/18...         3
# 1  /homedetails/4070-Wilson-Ln-Concord-CA-94521/1...         4
# 2  /homedetails/3594-Kimball-Way-Concord-CA-94518...         3
# 3  /homedetails/1506-American-Beauty-Dr-Concord-C...         4
# 4  /homedetails/2872-Lyon-Cir-Concord-CA-94518/18...         4
#
#   contingentListingType   longitude   latitude listingStatus      zpid  \
# 0                  None -122.026436  37.980556      FOR_SALE  18344088
# 1                  None -121.993340  37.972626      FOR_SALE  18350092
# 2                  None -122.009270  37.967735      FOR_SALE  18339530
# 3                  None -121.965200  37.955235      FOR_SALE  18354159
# 4                  None -122.023280  37.947530      FOR_SALE  18368386
#
#    rentZestimate daysOnZillow  bathrooms  livingArea country currency  \
# 0         3519.0            0          2        1537     USA      USD
# 1         3699.0            6          2        1795     USA      USD
# 2         3522.0           15          2        1655     USA      USD
# 3         3594.0            6          2        1558     USA      USD
# 4         3890.0            3          2        2078     USA      USD
#
#   lotAreaUnit  hasImage  listingSubType.is_FSBA    variableData.text  \
# 0        sqft      True                    True                  NaN
# 1        sqft      True                    True  Open: Fri. 4:30-7pm
# 2        sqft      True                    True     Open: Sat. 1-4pm
# 3        sqft      True                    True     Open: Sat. 1-4pm
# 4        sqft      True                    True     Open: Sat. 1-4pm
#
#   variableData.type listingSubType.is_openHouse
# 0               NaN                         NaN
# 1        OPEN_HOUSE                        True
# 2        OPEN_HOUSE                        True
# 3        OPEN_HOUSE                        True
# 4        OPEN_HOUSE                        True

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['18344088',
#  '18350092',
#  '18339530',
#  '18354159',
#  '18368386',
#  '18353668',
#  '18369676',
#  '18360039',
#  '18355111',
#  '68036293',
#  '18370332',
#  '18353354',
#  '18385954',
#  '68042448',
#  '18350512',
#  '18386909',
#  '18385773',
#  '18354460']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 18
# Num of cols: 302
#    listingProvider        zpid  buildingPermits  propertyTaxRate  \
# 0              NaN  18344088.0              NaN             1.16
# 1              NaN  18350092.0              NaN             1.16
#
#                                   contact_recipients zipcode   longitude  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   94519 -122.026436
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   94521 -121.993340
#
#   zestimateLowPercent   cityId timeOnZillow  \
# 0                   5  51518.0     16 hours
# 1                   5  51518.0       6 days
#
#                                                  url  zestimate  \
# 0  /homedetails/1925-N-3rd-St-Concord-CA-94519/18...   905600.0
# 1  /homedetails/4070-Wilson-Ln-Concord-CA-94521/1...   989600.0
#
#                                               imgSrc  \
# 0  https://photos.zillowstatic.com/fp/e26baffdd56...
# 1  https://photos.zillowstatic.com/fp/ce24aa44cea...
#
#                                          description     price  \
# 0  Welcome to Concord's best 3-bed, 2-bath single...  866000.0
# 1  Rare Eichler Gem with Atrium, Modern Updates &...  965000.0
#
#    livingAreaValue                                         taxHistory  \
# 0           1537.0  [{'time': 1681849114136, 'valueIncreaseRate': ...
# 1           1795.0  [{'time': 1681849118822, 'valueIncreaseRate': ...
#
#    brokerId  stateId   streetAddress  solarPotential  dateSold  countyId  \
# 0       NaN      9.0   1925 N 3rd St             NaN       NaN    3159.0
# 1       NaN      9.0  4070 Wilson Ln             NaN       NaN    3159.0
#
#               timeZone       homeType livingAreaUnits  comingSoonOnMarketDate  \
# 0  America/Los_Angeles  SINGLE_FAMILY            sqft                     NaN
# 1  America/Los_Angeles  SINGLE_FAMILY            sqft                     NaN
#
#    rentZestimate  bathrooms  annualHomeownersInsurance state  \
# 0         3519.0        2.0                     3637.0    CA
# 1         3699.0        2.0                     4053.0    CA
#
#   propertyTypeDimension  building  yearBuilt              brokerageName  \
# 0         Single Family       NaN     2000.0        KW Bay Area Estates
# 1         Single Family       NaN     1963.0  Twin Oaks Real Estate INC
#
#    pageViewCount               county  monthlyHoaFee homeStatus  homeFacts  \
# 0          118.0  Contra Costa County            NaN   FOR_SALE        NaN
# 1         1730.0  Contra Costa County            NaN   FOR_SALE        NaN
#
#     latitude  datePosted  bedrooms  \
# 0  37.980556  2024-04-18       3.0
# 1  37.972626  2024-04-12       4.0
#
#                                          nearbyHomes  livingArea  \
# 0  [{'livingArea': 930, 'livingAreaValue': 930, '...      1537.0
# 1  [{'livingArea': 2003, 'livingAreaValue': 2003,...      1795.0
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0, 'date': '2024-04-18', ...            7.0
# 1  [{'priceChangeRate': 4.9937888198758, 'date': ...          153.0
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/califo...                    5
# 1  [{'link': 'https://www.greatschools.org/califo...                    5
#
#         mlsid countyFIPS     city  providerListingID country currency  \
# 0  ML81960817      06013  Concord                NaN     USA      USD
# 1   324024538      06013  Concord                NaN     USA      USD
#
#    isListedByOwner  contingentListingType  address.community address.city  \
# 0              NaN                    NaN                NaN      Concord
# 1              NaN                    NaN                NaN      Concord
#
#   address.state  address.neighborhood  address.subdivision  \
# 0            CA                   NaN                  NaN
# 1            CA                   NaN                  NaN
#
#   address.streetAddress address.zipcode resoFacts.hasAttachedProperty  \
# 0         1925 N 3rd St           94519                         False
# 1        4070 Wilson Ln           94521                         False
#
#    resoFacts.frontageType resoFacts.poolFeatures resoFacts.flooring  \
# 0                     NaN                   None               None
# 1                     NaN                   None               None
#
#    resoFacts.builderModel resoFacts.accessibilityFeatures resoFacts.hasGarage  \
# 0                     NaN                            None                True
# 1                     NaN                            None                True
#
#   resoFacts.hasPetsAllowed  resoFacts.bodyType  resoFacts.topography  \
# 0                     None                 NaN                   NaN
# 1                     None                 NaN                   NaN
#
#    resoFacts.landLeaseExpirationDate resoFacts.hasAdditionalParcels  \
# 0                                NaN                          False
# 1                                NaN                          False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factValue': 'Single Family Residence, ', 'f...
# 1                  None  [{'factValue': 'Single Family Residence', 'fac...
#
#    resoFacts.offerReviewDate resoFacts.horseYN  \
# 0                        NaN             False
# 1                        NaN              None
#
#   resoFacts.buyerAgencyCompensationType  \
# 0                                     %
# 1                                     %
#
#                                      resoFacts.rooms  \
# 0  [{'level': None, 'dimensions': None, 'features...
# 1  [{'level': None, 'dimensions': None, 'features...
#
#    resoFacts.belowGradeFinishedArea resoFacts.cityRegion  \
# 0                               NaN              Concord
# 1                               NaN              Concord
#
#    resoFacts.subAgencyCompensation resoFacts.hasPrivatePool  \
# 0                              NaN                     None
# 1                              NaN                     None
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0                             None              [Public]
# 1                             None              [Public]
#
#    resoFacts.carportParkingCapacity  \
# 0                               NaN
# 1                               2.0
#
#    resoFacts.transactionBrokerCompensationType resoFacts.hasFireplace  \
# 0                                          NaN                   None
# 1                                          NaN                   True
#
#        resoFacts.gas resoFacts.sewer resoFacts.elevationUnits  \
# 0  [PublicUtilities]  [Public Sewer]                     None
# 1               None  [Public Sewer]                     None
#
#    resoFacts.roadSurfaceType  resoFacts.mainLevelBedrooms  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#    resoFacts.numberOfUnitsVacant  resoFacts.hasWaterfrontView  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#    resoFacts.bathroomsOneQuarter resoFacts.lotSize  \
# 0                            NaN        8,712 sqft
# 1                            NaN        7,301 sqft
#
#    resoFacts.subAgencyCompensationType  resoFacts.entryLevel  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
#
#    resoFacts.irrigationWaterRightsAcres  resoFacts.greenWaterConservation  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
#
#    resoFacts.stories  resoFacts.bathrooms  resoFacts.numberOfUnitsInCommunity  \
# 0                1.0                  2.0                                 NaN
# 1                1.0                  2.0                                 0.0
#
#   resoFacts.listingTerms  resoFacts.otherParking resoFacts.associationFee  \
# 0                   None                     NaN                     None
# 1                   None                     NaN                     None
#
#    resoFacts.marketingType resoFacts.greenEnergyEfficient  \
# 0                      NaN                           None
# 1                      NaN                           None
#
#    resoFacts.greenSustainability     resoFacts.heating  \
# 0                            NaN  [Central Forced Air]
# 1                            NaN          [MultiUnits]
#
#   resoFacts.associationPhone  resoFacts.greenBuildingVerificationType  \
# 0                       None                                      NaN
# 1                       None                                      NaN
#
#   resoFacts.hasAttachedGarage  resoFacts.bedrooms  \
# 0                        True                 3.0
# 1                        True                 4.0
#
#   resoFacts.architecturalStyle  resoFacts.listingId  resoFacts.structureType  \
# 0                         None                  NaN                      NaN
# 1                  Mid-Century                  NaN                      NaN
#
#   resoFacts.interiorFeatures  resoFacts.horseAmenities resoFacts.electric  \
# 0                       None                       NaN               None
# 1                       None                       NaN               None
#
#   resoFacts.lotFeatures resoFacts.roofType  resoFacts.compensationBasedOn  \
# 0                  None        Composition                            NaN
# 1             [Private]               None                            NaN
#
#   resoFacts.greenEnergyGeneration  resoFacts.taxAnnualAmount  \
# 0                            None                    10046.0
# 1                         [Solar]                    11194.0
#
#    resoFacts.daysOnZillow resoFacts.listAOR resoFacts.hasHeating  \
# 0                     0.0              None                 True
# 1                     6.0              None                 True
#
#    resoFacts.elementarySchool resoFacts.basementYN resoFacts.hoaFeeTotal  \
# 0                         NaN                 None                  None
# 1                         NaN                False                  None
#
#                                 resoFacts.appliances  \
# 0                                               None
# 1  [Built-In Electric Oven, Dishwasher, Gas Cookt...
#
#                                resoFacts.virtualTour  \
# 0                https://www.tourfactory.com/3140375
# 1  https://www.youtube.com/watch?v=kVHLjojZIjo&t=59s
#
#    resoFacts.bathroomsPartial resoFacts.fencing  resoFacts.yearBuiltEffective  \
# 0                         NaN              None                           NaN
# 1                         NaN              None                           NaN
#
#   resoFacts.foundationDetails  resoFacts.buildingName  \
# 0        [Concrete Perimeter]                     NaN
# 1                         NaN                     NaN
#
#   resoFacts.hasAssociation  resoFacts.isSeniorCommunity  \
# 0                     None                          NaN
# 1                     None                          NaN
#
#      resoFacts.propertySubType resoFacts.propertyCondition  \
# 0  [Single Family Residence, ]                        None
# 1    [Single Family Residence]                        None
#
#   resoFacts.hasCarport resoFacts.canRaiseHorses resoFacts.hasLandLease  \
# 0                False                    False                  False
# 1                 True                    False                  False
#
#    resoFacts.communityFeatures resoFacts.parcelNumber  resoFacts.elevation  \
# 0                          NaN             1112300221                  NaN
# 1                          NaN             1150310173                  NaN
#
#    resoFacts.lotSizeDimensions  resoFacts.buildingAreaSource  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
#
#    resoFacts.contingency  resoFacts.yearBuilt resoFacts.otherStructures  \
# 0                    NaN               2000.0                      None
# 1                    NaN               1963.0                      None
#
#   resoFacts.livingArea  resoFacts.bathroomsFull  \
# 0           1,537 sqft                      2.0
# 1           1,795 sqft                      2.0
#
#    resoFacts.livingAreaRangeUnits  resoFacts.incomeIncludes  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
#
#    resoFacts.highSchool  resoFacts.aboveGradeFinishedArea  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
#
#   resoFacts.isNewConstruction  resoFacts.inclusions resoFacts.hasHomeWarranty  \
# 0                       False                   NaN                     False
# 1                       False                   NaN                     False
#
#    resoFacts.additionalFeeInfo resoFacts.windowFeatures  resoFacts.ownership  \
# 0                          NaN                     None                  NaN
# 1                          NaN         [Dual Pane Full]                  NaN
#
#    resoFacts.woodedArea  resoFacts.middleOrJuniorSchoolDistrict  \
# 0                   NaN                                     NaN
# 1                   NaN                                     NaN
#
#    resoFacts.associationPhone2  resoFacts.buildingFeatures  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#    resoFacts.frontageLength resoFacts.buildingArea  \
# 0                       NaN                  1,537
# 1                       NaN                  1,795
#
#   resoFacts.associationAmenities  resoFacts.bathroomsHalf  \
# 0                           None                      NaN
# 1                           None                      0.0
#
#   resoFacts.hasCooling  resoFacts.additionalParcelsDescription  \
# 0                 True                                     NaN
# 1                 True                                     NaN
#
#   resoFacts.parkingFeatures  resoFacts.foundationArea resoFacts.zoning  \
# 0                [Attached]                       NaN              SFR
# 1                [Attached]                       NaN             None
#
#   resoFacts.hoaFee  resoFacts.livingAreaRange  resoFacts.zoningDescription  \
# 0             None                        NaN                          NaN
# 1             None                        NaN                          NaN
#
#    resoFacts.developmentStatus  resoFacts.availabilityDate  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#    resoFacts.waterfrontFeatures  resoFacts.waterBodyName  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
#
#                 resoFacts.utilities  resoFacts.entryLocation  \
# 0  [Public Utilities, Water Public]                      NaN
# 1                              None                      NaN
#
#    resoFacts.totalActualRent resoFacts.hasView    resoFacts.subdivisionName  \
# 0                        NaN             False                         None
# 1                        NaN             False  Clayton Valley Neighborhood
#
#   resoFacts.securityFeatures  resoFacts.attic resoFacts.fireplaceFeatures  \
# 0                       None              NaN                        None
# 1                       None              NaN               [Family Room]
#
#    resoFacts.mainLevelBathrooms resoFacts.doorFeatures  \
# 0                           NaN                   None
# 1                           NaN                   None
#
#    resoFacts.ownershipType resoFacts.associationName  resoFacts.waterView  \
# 0                      NaN                      None                  NaN
# 1                      NaN                      None                  NaN
#
#    resoFacts.garageParkingCapacity  resoFacts.cropsIncludedYN  \
# 0                              2.0                        NaN
# 1                              2.0                        NaN
#
#   resoFacts.laundryFeatures resoFacts.buyerAgencyCompensation  \
# 0                      None                               2.5
# 1             [Inside Area]                               2.5
#
#    resoFacts.greenIndoorAirQuality resoFacts.homeType  resoFacts.spaFeatures  \
# 0                              NaN       SingleFamily                    NaN
# 1                              NaN       SingleFamily                    NaN
#
#    resoFacts.municipality  resoFacts.bathroomsThreeQuarter resoFacts.hasSpa  \
# 0                     NaN                              NaN            False
# 1                     NaN                              NaN            False
#
#   resoFacts.basement  resoFacts.associationFee2  \
# 0               None                        NaN
# 1               None                        NaN
#
#                 resoFacts.cooling  resoFacts.openParkingCapacity  \
# 0                   [Central Air]                            NaN
# 1  [Ceiling Fan(s), Wall Unit(s)]                            2.0
#
#    resoFacts.associationName2  resoFacts.hasRentControl  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                    MtDiabloUnified                     None
# 1                               None                     None
#
#    resoFacts.commonWalls resoFacts.specialListingConditions  \
# 0                    NaN                           Standard
# 1                    NaN                           Standard
#
#   resoFacts.furnished  resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0               False                   NaN                            None
# 1               False                   NaN                            None
#
#    resoFacts.bathroomsFloat  resoFacts.builderName  \
# 0                       2.0                    NaN
# 1                       2.0                    NaN
#
#   resoFacts.highSchoolDistrict  resoFacts.transactionBrokerCompensation  \
# 0              MtDiabloUnified                                      NaN
# 1                         None                                      NaN
#
#    resoFacts.storiesTotal resoFacts.cumulativeDaysOnMarket  \
# 0                     NaN                             None
# 1                     NaN                             None
#
#    resoFacts.fireplaces  resoFacts.irrigationWaterRightsYN  \
# 0                   NaN                                NaN
# 1                   1.0                                NaN
#
#    resoFacts.exclusions resoFacts.hasOpenParking  resoFacts.landLeaseAmount  \
# 0                   NaN                     None                        NaN
# 1                   NaN                     True                        NaN
#
#    resoFacts.coveredParkingCapacity  resoFacts.middleOrJuniorSchool  \
# 0                               2.0                             NaN
# 1                               4.0                             NaN
#
#   resoFacts.hasElectricOnProperty  resoFacts.onMarketDate  \
# 0                            None            1.712707e+12
# 1                            None            1.712794e+12
#
#    resoFacts.pricePerSquareFoot  resoFacts.parkingCapacity resoFacts.levels  \
# 0                         563.0                        2.0             None
# 1                         538.0                        6.0              One
#
#   listingSubType.is_FSBA listingSubType.is_comingSoon  \
# 0                   True                        False
# 1                   True                        False
#
#   listingSubType.is_newHome listingSubType.is_pending  \
# 0                     False                     False
# 1                     False                     False
#
#   listingSubType.is_forAuction listingSubType.is_foreclosure  \
# 0                        False                         False
# 1                        False                         False
#
#   listingSubType.is_bankOwned listingSubType.is_openHouse  \
# 0                       False                       False
# 1                       False                        True
#
#   listingSubType.is_FSBO  listed_by.agent_reason listed_by.zpro  \
# 0                  False                     3.0          False
# 1                  False                     3.0          False
#
#    listed_by.recent_sales            listed_by.zuid  listed_by.review_count  \
# 0                     1.0   X1-ZUzbm8njerig3t_6y17r                    35.0
# 1                     0.0  X1-ZU13iqtlenyhy4p_6msnz                    31.0
#
#   listed_by.display_name                             listed_by.profile_url  \
# 0          Mario Ramirez  https://www.zillow.com/profile/MarioRamirezSVRE/
# 1  Ambar Estrella Toledo       https://www.zillow.com/profile/AmbarToledo/
#
#      listed_by.business_name  listed_by.rating_average listed_by.phone.prefix  \
# 0        KW Bay Area Estates                       5.0                    605
# 1  Twin Oaks Real Estate INC                       5.0                    239
#
#   listed_by.phone.areacode listed_by.phone.number listed_by.badge_type  \
# 0                      408                   9999        Listing Agent
# 1                      510                   8827        Listing Agent
#
#                                  listed_by.image_url  \
# 0  https://photos.zillowstatic.com/h_n/ISfgt1iwyn...
# 1  https://photos.zillowstatic.com/h_n/ISni0j8zwu...
#
#    mortgageRates.thirtyYearFixedRate  attributionInfo.buyerAgentName  \
# 0                              6.951                             NaN
# 1                              6.951                             NaN
#
#   attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0         MLSListings Inc                                 None
# 1                  BAREIS                                 None
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated  attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-04-12 05:54:11                                           NaN
# 1         2024-04-18 05:00:34                                           NaN
#
#   attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0        KW Bay Area Estates             ExclusiveRightToSell
# 1  Twin Oaks Real Estate INC                             None
#
#                         attributionInfo.infoString10  \
# 0  Based on information from the MLSListings MLS ...
# 1  Listing information deemed reliable but not gu...
#
#    attributionInfo.trueStatus  \
# 0                         NaN
# 1                         NaN
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/f6d938e7ba0...
# 1  https://photos.zillowstatic.com/fp/865e93bf342...
#
#    attributionInfo.agentEmail attributionInfo.agentName  \
# 0                         NaN             Mario Ramirez
# 1                         NaN            Ambar E Toledo
#
#    attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                               NaN            ML81960817
# 1                               NaN             324024538
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1                        None                          None
#
#   attributionInfo.infoString5  \
# 0                408-605-9999
# 1                510-239-8827
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': '01093234', 'memberFul...
# 1  [{'memberStateLicense': 'DRE #02031803', 'memb...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     408-605-9999                           01093234
# 1                     510-239-8827                      DRE #02031803
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/f6d938e7ba0...
# 1  https://photos.zillowstatic.com/fp/865e93bf342...
#
#    attributionInfo.infoString16  attributionInfo.buyerBrokerageName  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
#
#                        attributionInfo.mlsDisclaimer  \
# 0  Based on information from the MLSListings MLS ...
# 1  Listing information deemed reliable but not gu...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      408-560-9000         2024-04-18 12:32:37
# 1                      707-746-8700         2024-04-18 13:04:43
#
#                                    openHouseSchedule  \
# 0                                                NaN
# 1  [{'startTime': '2024-04-19 16:30:00', 'endTime...
#
#                                resoFacts.feesAndDues  \
# 0                                                NaN
# 1  [{'phone': None, 'name': None, 'fee': None, 't...
#
#   resoFacts.constructionMaterials resoFacts.exteriorFeatures listed_by.phone  \
# 0                             NaN                        NaN             NaN
# 1                      [Concrete]                        NaN             NaN
#
#   resoFacts.view resoFacts.associations message
# 0            NaN                    NaN     NaN
# 1            NaN                    NaN     NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#              streetAddress     city               county zipcode state  \
# 0            1925 N 3rd St  Concord  Contra Costa County   94519    CA
# 1           4070 Wilson Ln  Concord  Contra Costa County   94521    CA
# 2         3594 Kimball Way  Concord  Contra Costa County   94518    CA
# 3  1506 American Beauty Dr  Concord  Contra Costa County   94521    CA
# 4            2872 Lyon Cir  Concord  Contra Costa County   94518    CA
#
#       price       homeType timeOnZillow  zestimate  rentZestimate  livingArea  \
# 0  866000.0  SINGLE_FAMILY     16 hours   905600.0         3519.0      1537.0
# 1  965000.0  SINGLE_FAMILY       6 days   989600.0         3699.0      1795.0
# 2  888000.0  SINGLE_FAMILY      15 days        NaN         3522.0      1655.0
# 3  848000.0  SINGLE_FAMILY       6 days        NaN         3594.0      1558.0
# 4  999999.0  SINGLE_FAMILY       3 days  1060000.0         3890.0      2078.0
#
#    bedrooms  bathrooms  yearBuilt  \
# 0       3.0        2.0     2000.0
# 1       4.0        2.0     1963.0
# 2       3.0        2.0     1956.0
# 3       4.0        2.0     1961.0
# 4       4.0        2.0     1969.0
#
#                                          description  \
# 0  Welcome to Concord's best 3-bed, 2-bath single...
# 1  Rare Eichler Gem with Atrium, Modern Updates &...
# 2  Just listed in an idyllic Concord location! Th...
# 3  Ready and waiting for you! This delightful, no...
# 4  This updated 4-bedroom, 2-bathroom home in the...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': 0, 'date': '2024-04-18', ...
# 1  [{'priceChangeRate': 4.9937888198758, 'date': ...
# 2  [{'priceChangeRate': 0.4208, 'date': '2024-04-...
# 3  [{'priceChangeRate': 0, 'date': '2024-04-12', ...
# 4  [{'priceChangeRate': 0.46946305766179, 'date':...
#
#                                           taxHistory        zpid
# 0  [{'time': 1681849114136, 'valueIncreaseRate': ...  18344088.0
# 1  [{'time': 1681849118822, 'valueIncreaseRate': ...  18350092.0
# 2  [{'time': 1681849121498, 'valueIncreaseRate': ...  18339530.0
# 3  [{'time': 1681849129465, 'valueIncreaseRate': ...  18354159.0
# 4  [{'time': 1681849132015, 'valueIncreaseRate': ...  18368386.0

# %%
# download file
df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
# !pip install python-zillow -q

# %%
# list of addresses
address_dict = {
    'address': [
                '125 Lithia Pinecrest Rd, Brandon, FL',
                '705 Westwood Ln, Brandon, FL',
                '101 Ruby Cir, Brandon, FL '],
    'postal_code': [
                    33511,
                    33511,
                    33510]
}
df_addresses = pd.DataFrame(data=address_dict)
df_addresses
# Out:
#                                 address  postal_code
# 0  125 Lithia Pinecrest Rd, Brandon, FL        33511
# 1          705 Westwood Ln, Brandon, FL        33511
# 2            101 Ruby Cir, Brandon, FL         33510

# %%
zillow_api_key = df_api_keys.loc[df_api_keys['API'] =='zillow']['KEY'].iloc[0] # replace this with your own key

# %%
import zillow

# create api instance
zillow_api = zillow.ValuationApi()

# create empty list
zpid_list = []

# iterate through dataframe
for index, row in df_addresses.iterrows():
  # get values to pass through api
  _address = row['address']
  _postal_code = row['postal_code']
  print(_address, _postal_code)

  # get search results
  _search_results = zillow_api.GetSearchResults(zillow_api_key, _address, _postal_code)

  # append zpid
  zpid_list.append(_search_results.zpid)
# Out:
# 125 Lithia Pinecrest Rd, Brandon, FL 33511
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# <ipython-input-24-9e878041af8c> in <module>()
#      15
#      16   # get search results
# ---> 17   _search_results = zillow_api.GetSearchResults(zillow_api_key, _address, _postal_code)
#      18
#      19   # append zpid
#
# /usr/local/lib/python3.7/dist-packages/zillow/api.py in GetSearchResults(self, zws_id, address, citystatezip, retnzestimate)
#      58         data = resp.content.decode('utf-8')
#      59
# ---> 60         xmltodict_data = xmltodict.parse(data)
#      61
#      62         place = Place()
#
# /usr/local/lib/python3.7/dist-packages/xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, **kwargs)
#     325         parser.ParseFile(xml_input)
#     326     else:
# --> 327         parser.Parse(xml_input, True)
#     328     return handler.item
#     329
#
# ExpatError: not well-formed (invalid token): line 32, column 38

# %%
df_addresses['zpid'] = zpid_list
df_addresses

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()

# %% [markdown]
# # End Notebook
