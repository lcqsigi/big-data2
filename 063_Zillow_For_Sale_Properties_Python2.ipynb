# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'moraga'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: moraga, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Condos",
               "minPrice": "700000",
               "maxPrice": "9000000",
               "sqftMin": "1000",
               "bedsMin": "2"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'CONDO',
#    'lotAreaValue': 1306.8,
#    'address': '54 Miramonte Dr, Moraga, CA 94556',
#    'variableData': {'text': 'Open: Sun. 2-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -20000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9b9f3841d236fe7c489394bb725e7859-p_e.jpg',
#    'price': 859000,
#    'detailUrl': '/homedetails/54-Miramonte-Dr-Moraga-CA-94556/18471532_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -122.144135,
#    'latitude': 37.839676,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18471532',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3951,
#    'daysOnZillow': 95,
#    'bathrooms': 2,
#    'livingArea': 1248,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 1,
#  'totalResultCount': 1,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 1
# Num of cols: 27
#   dateSold propertyType  lotAreaValue                            address  \
# 0     None        CONDO        1306.8  54 Miramonte Dr, Moraga, CA 94556
#
#    priceChange zestimate                                             imgSrc  \
# 0       -20000      None  https://photos.zillowstatic.com/fp/9b9f3841d23...
#
#     price                                          detailUrl  bedrooms  \
# 0  859000  /homedetails/54-Miramonte-Dr-Moraga-CA-94556/1...         2
#
#   contingentListingType   longitude   latitude listingStatus      zpid  \
# 0                  None -122.144135  37.839676      FOR_SALE  18471532
#
#    rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0           3951            95          2        1248     USA      USD
#
#   lotAreaUnit  hasImage variableData.text variableData.type  \
# 0        sqft      True  Open: Sun. 2-4pm        OPEN_HOUSE
#
#    listingSubType.is_FSBA  listingSubType.is_openHouse
# 0                    True                         True

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['18471532']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 1
# Num of cols: 296
#   listingProvider      zpid buildingPermits  propertyTaxRate  \
# 0            None  18471532            None             1.16
#
#                                   contact_recipients zipcode  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   94556
#
#                                    openHouseSchedule   longitude  \
# 0  [{'startTime': '2024-04-28 14:00:00', 'endTime... -122.144135
#
#   zestimateLowPercent  cityId timeOnZillow  \
# 0                None   32942      95 days
#
#                                                  url zestimate  \
# 0  /homedetails/54-Miramonte-Dr-Moraga-CA-94556/1...      None
#
#                                               imgSrc  \
# 0  https://photos.zillowstatic.com/fp/9b9f3841d23...
#
#                                          description   price  livingAreaValue  \
# 0  INCREDIBLE PRICE!! This captivating two-story ...  859000             1248
#
#                                           taxHistory brokerId  stateId  \
# 0  [{'time': 1682541735080, 'valueIncreaseRate': ...     None        9
#
#      streetAddress solarPotential dateSold  countyId             timeZone  \
# 0  54 Miramonte Dr           None     None      3159  America/Los_Angeles
#
#   homeType livingAreaUnits comingSoonOnMarketDate  rentZestimate  bathrooms  \
# 0    CONDO            sqft                   None           3951          2
#
#    annualHomeownersInsurance state propertyTypeDimension building  yearBuilt  \
# 0                       3608    CA                 Condo     None       1964
#
#               brokerageName  pageViewCount               county  \
# 0  Corcoran Icon Properties           1151  Contra Costa County
#
#    monthlyHoaFee homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0            511   FOR_SALE      None  37.839676  2024-01-22         2
#
#                                          nearbyHomes  livingArea  \
# 0  [{'livingArea': 1248, 'livingAreaValue': 1248,...        1248
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': -0.022753128555176, 'date...             28
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/califo...                 None
#
#       mlsid countyFIPS    city providerListingID country currency  \
# 0  41048108      06013  Moraga              None     USA      USD
#
#   isListedByOwner contingentListingType address.community address.city  \
# 0            None                  None              None       Moraga
#
#   address.state address.neighborhood address.subdivision  \
# 0            CA                 None                None
#
#   address.streetAddress address.zipcode  resoFacts.hasAttachedProperty  \
# 0       54 Miramonte Dr           94556                          False
#
#   resoFacts.frontageType  resoFacts.poolFeatures  resoFacts.flooring  \
# 0                   None  [In Ground, Community]  [Hardwood, Carpet]
#
#   resoFacts.builderModel resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0                   None                            None                False
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     None               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factValue': 'Condominium', 'factLabel': 'Ty...
#
#   resoFacts.offerReviewDate resoFacts.horseYN  \
# 0                      None              None
#
#   resoFacts.buyerAgencyCompensationType resoFacts.belowGradeFinishedArea  \
# 0                                     %                             None
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': '925-376-3727', 'name': 'MIRAMONTE ...               Moraga
#
#   resoFacts.subAgencyCompensation resoFacts.hasPrivatePool  \
# 0                            None                     None
#
#                     resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0  [Common Area Maint, Hazard Insurance, Manageme...              [Public]
#
#   resoFacts.carportParkingCapacity  \
# 0                             None
#
#   resoFacts.transactionBrokerCompensationType  resoFacts.hasFireplace  \
# 0                                        None                    True
#
#   resoFacts.gas resoFacts.sewer resoFacts.elevationUnits  \
# 0          None  [Public Sewer]                     None
#
#   resoFacts.roadSurfaceType resoFacts.mainLevelBedrooms  \
# 0                      None                        None
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView  \
# 0                          None                        None
#
#   resoFacts.bathroomsOneQuarter resoFacts.lotSize  \
# 0                          None        1,306 sqft
#
#   resoFacts.subAgencyCompensationType resoFacts.entryLevel  \
# 0                                None                 None
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.greenWaterConservation  \
# 0                                 None                             None
#
#    resoFacts.stories  resoFacts.bathrooms  resoFacts.numberOfUnitsInCommunity  \
# 0                  2                    2                                 202
#
#      resoFacts.listingTerms resoFacts.otherParking resoFacts.associationFee  \
# 0  Cash,Conventional,FHA,VA                   None             $511 monthly
#
#   resoFacts.marketingType resoFacts.greenEnergyEfficient  \
# 0                    None                           None
#
#   resoFacts.greenSustainability resoFacts.heating resoFacts.associationPhone  \
# 0                          None      [Forced Air]               925-376-3727
#
#   resoFacts.greenBuildingVerificationType  resoFacts.hasAttachedGarage  \
# 0                                    None                        False
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   2                     Colonial                None
#
#   resoFacts.structureType                         resoFacts.interiorFeatures  \
# 0                    None  [Stone Counters, Eat-in Kitchen, Kitchen Islan...
#
#   resoFacts.horseAmenities resoFacts.electric resoFacts.lotFeatures  \
# 0                     None         [No Solar]               [Level]
#
#   resoFacts.roofType resoFacts.compensationBasedOn  \
# 0            Shingle                          None
#
#   resoFacts.greenEnergyGeneration  resoFacts.taxAnnualAmount  \
# 0                            None                       9964
#
#    resoFacts.daysOnZillow resoFacts.listAOR  resoFacts.hasHeating  \
# 0                      95              None                  True
#
#   resoFacts.elementarySchool resoFacts.constructionMaterials  \
# 0                       None           [Stucco, Wood Siding]
#
#   resoFacts.basementYN resoFacts.hoaFeeTotal  \
# 0                 None          $511 monthly
#
#                                 resoFacts.appliances resoFacts.virtualTour  \
# 0  [Dishwasher, Disposal, Free-Standing Range, Re...                  None
#
#   resoFacts.bathroomsPartial resoFacts.fencing resoFacts.yearBuiltEffective  \
# 0                       None         Back Yard                         None
#
#   resoFacts.buildingName  resoFacts.hasAssociation  \
# 0                   None                      True
#
#   resoFacts.isSeniorCommunity resoFacts.propertySubType  \
# 0                        None             [Condominium]
#
#   resoFacts.propertyCondition  resoFacts.hasCarport  resoFacts.canRaiseHorses  \
# 0                    Existing                 False                     False
#
#    resoFacts.hasLandLease resoFacts.communityFeatures resoFacts.parcelNumber  \
# 0                   False                        None             2573000540
#
#   resoFacts.elevation resoFacts.lotSizeDimensions  \
# 0                None                        None
#
#   resoFacts.buildingAreaSource resoFacts.contingency  resoFacts.yearBuilt  \
# 0                         None                  None                 1964
#
#   resoFacts.otherStructures resoFacts.livingArea  resoFacts.bathroomsFull  \
# 0                      None           1,248 sqft                        1
#
#   resoFacts.livingAreaRangeUnits resoFacts.incomeIncludes  \
# 0                           None                     None
#
#   resoFacts.highSchool resoFacts.aboveGradeFinishedArea  \
# 0                 None                             None
#
#    resoFacts.isNewConstruction resoFacts.inclusions  \
# 0                        False                 None
#
#    resoFacts.hasHomeWarranty resoFacts.additionalFeeInfo  \
# 0                      False                        None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0       [Window Coverings]                None                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                                   None                        None
#
#   resoFacts.buildingFeatures resoFacts.frontageLength resoFacts.buildingArea  \
# 0                       None                     None                  1,248
#
#                       resoFacts.associationAmenities  resoFacts.bathroomsHalf  \
# 0  [Clubhouse, Greenbelt, Pool, Barbecue, BBQ Are...                        1
#
#    resoFacts.hasCooling resoFacts.additionalParcelsDescription  \
# 0                  True                                   None
#
#                            resoFacts.parkingFeatures resoFacts.foundationArea  \
# 0  [Off Street, Space Per Unit - 2, Guest, Parkin...                     None
#
#   resoFacts.zoning resoFacts.hoaFee resoFacts.livingAreaRange  \
# 0             None     $511 monthly                      None
#
#   resoFacts.zoningDescription resoFacts.developmentStatus  \
# 0                        None                        None
#
#   resoFacts.availabilityDate resoFacts.waterfrontFeatures  \
# 0                       None                         None
#
#   resoFacts.waterBodyName          resoFacts.utilities  \
# 0                    None  [Individual Electric Meter]
#
#   resoFacts.entryLocation resoFacts.totalActualRent  resoFacts.hasView  \
# 0                    None                      None              False
#
#   resoFacts.subdivisionName  \
# 0                      None
#
#                           resoFacts.securityFeatures resoFacts.attic  \
# 0  [Carbon Monoxide Detector(s), Double Strapped ...            None
#
#   resoFacts.fireplaceFeatures resoFacts.mainLevelBathrooms  \
# 0               [Living Room]                         None
#
#       resoFacts.doorFeatures resoFacts.ownershipType  \
# 0  [Mirrored Closet Door(s)]                    None
#
#   resoFacts.associationName  \
# 0             MIRAMONTE HOA
#
#                               resoFacts.associations resoFacts.waterView  \
# 0  [{'feeFrequency': '$511 monthly', 'name': 'MIR...                None
#
#    resoFacts.garageParkingCapacity resoFacts.cropsIncludedYN  \
# 0                                2                      None
#
#        resoFacts.laundryFeatures resoFacts.buyerAgencyCompensation  \
# 0  [Dryer, Laundry Room, Washer]                               2.5
#
#   resoFacts.greenIndoorAirQuality resoFacts.homeType resoFacts.spaFeatures  \
# 0                            None              Condo                  None
#
#   resoFacts.municipality resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  \
# 0                   None                            None             False
#
#   resoFacts.basement resoFacts.associationFee2 resoFacts.cooling  \
# 0               None                      None     [Central Air]
#
#   resoFacts.openParkingCapacity resoFacts.associationName2  \
# 0                          None                       None
#
#   resoFacts.hasRentControl resoFacts.elementarySchoolDistrict  \
# 0                     None                               None
#
#   resoFacts.otherEquipment resoFacts.commonWalls  \
# 0                     None                  None
#
#   resoFacts.specialListingConditions  resoFacts.furnished  \
# 0                           Standard                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                            None
#
#    resoFacts.bathroomsFloat resoFacts.builderName  \
# 0                         2                  None
#
#   resoFacts.highSchoolDistrict resoFacts.transactionBrokerCompensation  \
# 0                         None                                    None
#
#   resoFacts.storiesTotal resoFacts.cumulativeDaysOnMarket  \
# 0                   None                             None
#
#    resoFacts.fireplaces resoFacts.irrigationWaterRightsYN  \
# 0                     1                              None
#
#   resoFacts.exclusions resoFacts.hasOpenParking resoFacts.landLeaseAmount  \
# 0                 None                     None                      None
#
#    resoFacts.coveredParkingCapacity resoFacts.middleOrJuniorSchool  \
# 0                                 2                           None
#
#   resoFacts.hasElectricOnProperty  resoFacts.onMarketDate  \
# 0                            None           1705881600000
#
#    resoFacts.pricePerSquareFoot  resoFacts.parkingCapacity resoFacts.levels  \
# 0                           688                          2    Two Story,Two
#
#    listingSubType.is_FSBA  listingSubType.is_comingSoon  \
# 0                    True                         False
#
#    listingSubType.is_newHome  listingSubType.is_pending  \
# 0                      False                      False
#
#    listingSubType.is_forAuction  listingSubType.is_foreclosure  \
# 0                         False                          False
#
#    listingSubType.is_bankOwned  listingSubType.is_openHouse  \
# 0                        False                         True
#
#    listingSubType.is_FSBO  listed_by.agent_reason  listed_by.zpro  \
# 0                   False                       3           False
#
#    listed_by.recent_sales           listed_by.zuid  listed_by.review_count  \
# 0                       0  X1-ZUyw49wslc36rt_7aoc0                       0
#
#   listed_by.display_name                  listed_by.profile_url  \
# 0         MICHELLE VASEY  https://www.zillow.com/profile/vasey/
#
#     listed_by.business_name  listed_by.rating_average listed_by.phone.prefix  \
# 0  Corcoran Icon Properties                         0                    282
#
#   listed_by.phone.areacode listed_by.phone.number listed_by.badge_type  \
# 0                      510                   1285        Listing Agent
#
#                                  listed_by.image_url  \
# 0  https://photos.zillowstatic.com/h_n/ISfksfnauo...
#
#    mortgageRates.thirtyYearFixedRate attributionInfo.buyerAgentName  \
# 0                              6.901                           None
#
#        attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0  bridgeMLS/CCAR/Bay East AOR                                 None
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-04-19 11:29:50                                         None
#
#   attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0   Corcoran Icon Properties                             None
#
#                         attributionInfo.infoString10  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.trueStatus  \
# 0                       None
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.agentEmail attributionInfo.agentName  \
# 0                       None            Michelle Vasey
#
#   attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                             None              41048108
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
#
#   attributionInfo.infoString5  \
# 0                510-282-1285
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': 'DRE #01187806', 'memb...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     510-282-1285                      DRE #01187806
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.infoString16 attributionInfo.buyerBrokerageName  \
# 0                         None                               None
#
#                        attributionInfo.mlsDisclaimer  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked
# 0                      510-428-0900         2024-04-26 13:31:43

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#      streetAddress    city               county zipcode state   price  \
# 0  54 Miramonte Dr  Moraga  Contra Costa County   94556    CA  859000
#
#   homeType timeOnZillow zestimate  rentZestimate  livingArea  bedrooms  \
# 0    CONDO      95 days      None           3951        1248         2
#
#    bathrooms  yearBuilt                                        description  \
# 0          2       1964  INCREDIBLE PRICE!! This captivating two-story ...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': -0.022753128555176, 'date...
#
#                                           taxHistory      zpid
# 0  [{'time': 1682541735080, 'valueIncreaseRate': ...  18471532

# %%
# download file
#df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
#files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
df_z_prop_detail_output['streetAddress'].iloc[0]
# Out:
# '54 Miramonte Dr'

# %%
data = """Name,Address
"""

# %%
# Step 1: Open the file in write mode
file = open('example.txt', 'w')

# Step 2: Write text to the file
file.write("Name,Address\n")
file.write("House_1, "+df_z_prop_detail_output['streetAddress'].iloc[0]+"; "+df_z_prop_detail_output['city'].iloc[0]+" CA"+"\n")
# Step 3: Close the file
file.close()

# %%
import pandas as pd
data=pd.read_csv('./example.txt')

# %%
df=data

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df["loc"] = df["Address"].apply(geolocator.geocode)

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79f70087d67087b3aee730859f47b6ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79f70087d67087b3aee730859f47b6ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79f70087d67087b3aee730859f47b6ff = L.map(
#                 &quot;map_79f70087d67087b3aee730859f47b6ff&quot;,
#                 {
#                     center: [37.83988076050329, -122.1431557965214],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cbe31b772882af6e800dffcf0ba1622 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_79f70087d67087b3aee730859f47b6ff);
#
#
#             var marker_cluster_ec827e50e143b368fbe7084eccb796b4 = L.markerClusterGroup(
#                 {}
#             );
#             map_79f70087d67087b3aee730859f47b6ff.addLayer(marker_cluster_ec827e50e143b368fbe7084eccb796b4);
#
#
#             var marker_5e2aa4294eebc6a36fa8cee696e5724d = L.marker(
#                 [37.83988076050329, -122.1431557965214],
#                 {}
#             ).addTo(marker_cluster_ec827e50e143b368fbe7084eccb796b4);
#
#
#         var popup_76668ac627a741543e915c2f88c04e43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af3629cc1f162fb210a5a60a4e0f0a8d = $(`&lt;div id=&quot;html_af3629cc1f162fb210a5a60a4e0f0a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_1&lt;/div&gt;`)[0];
#                 popup_76668ac627a741543e915c2f88c04e43.setContent(html_af3629cc1f162fb210a5a60a4e0f0a8d);
#
#
#
#         marker_5e2aa4294eebc6a36fa8cee696e5724d.bindPopup(popup_76668ac627a741543e915c2f88c04e43)
#         ;
#
#
#
#
#             marker_5e2aa4294eebc6a36fa8cee696e5724d.bindTooltip(
#                 `&lt;div&gt;
#                      House_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
