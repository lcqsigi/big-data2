# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python3.091724.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'hayward'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: hayward, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring1 = {
               "location": "94611",
               "home_type":"Single_Family",
               "minPrice": "800000",
               "maxPrice": "1150000",
               "sqftMin": "1500",
               "bedsMin": "3"
               }

querystring2 = {
               "location": "94605",
               "home_type":"Single_Family",
               "minPrice": "800000",
               "maxPrice": "1150000",
               "sqftMin": "1500",
               "bedsMin": "3"
               }

querystring3 = {
               "location": "94619",
               "home_type":"Single_Family",
               "minPrice": "800000",
               "maxPrice": "1150000",
               "sqftMin": "1500",
               "bedsMin": "3"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp1 = requests.request("GET", url, headers=headers, params=querystring1)
z_for_sale_resp2 = requests.request("GET", url, headers=headers, params=querystring2)
z_for_sale_resp3 = requests.request("GET", url, headers=headers, params=querystring3)

# transform to json
z_for_sale_resp_json1 = z_for_sale_resp1.json()
z_for_sale_resp_json2 = z_for_sale_resp2.json()
z_for_sale_resp_json3 = z_for_sale_resp3.json()

# %%
len(z_for_sale_resp_json1.get('props', []))
# Out:
# 11

# %%
# view data
df_z_for_sale1 = pd.json_normalize(data=z_for_sale_resp_json1['props'])
df_z_for_sale2 = pd.json_normalize(data=z_for_sale_resp_json2['props'])
df_z_for_sale3 = pd.json_normalize(data=z_for_sale_resp_json3['props'])

df_z_for_sale = pd.concat([df_z_for_sale1,df_z_for_sale2,df_z_for_sale3], ignore_index=True)

print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
#df_z_for_sale.head(50)
# Out:
# Num of rows: 50
# Num of cols: 29

# %%
# download file (if needed)
df_z_for_sale=df_z_for_sale.sort_values('daysOnZillow')
df_z_for_sale.to_csv('df_z_for_sale.csv')
files.download('df_z_for_sale.csv')

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df=df_z_for_sale

# %%
df["loc"] = df['address'].apply(geolocator.geocode)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4246+Terrace+St%2C+Oakland%2C+CA+94611&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3106+Rawson+St%2C+Oakland%2C+CA+94619&format=json&limit=1

# %%
df.dropna(subset=['loc'],inplace=True)

# %%
df["price2"] = df['price'].apply(lambda x: f'{x/10**6:.1f}M')

# %%
#df['Index'] = str(df.reset_index().index)
#df = df.sort_values('daysOnZillow')
df['Index'] = df.reset_index().index.astype(str)

# %%
df["address_price"] = df['Index'] + ', ' + df['address'] + ', ' + df['price2']

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)

# Custom HTML template for the tooltip
tooltip_html = '''
<div class="tooltip"><input type="text" value="{text}" readonly onclick="this.select(); document.execCommand('copy');"><button onclick="navigator.clipboard.writeText('{text}');">Copy</button></div>
'''

# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                  tooltip=r['address_price'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a233e83b1c7ae06c6e406cd75f169cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a233e83b1c7ae06c6e406cd75f169cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a233e83b1c7ae06c6e406cd75f169cb = L.map(
#                 &quot;map_5a233e83b1c7ae06c6e406cd75f169cb&quot;,
#                 {
#                     center: [37.78601625301899, -122.18082287626595],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e680b4549619beda16fa94d24a81621f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e680b4549619beda16fa94d24a81621f.addTo(map_5a233e83b1c7ae06c6e406cd75f169cb);
#
#
#             var marker_cluster_6156d36919cbca99fc7409978af5fc3d = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_190a9ad469ca748959f4e8718b95d712 = L.marker(
#                 [37.77287765, -122.17065583142202],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_190a9ad469ca748959f4e8718b95d712.bindTooltip(
#                 `&lt;div&gt;
#                      0, 6933 Simson St, Oakland, CA 94605, 0.9M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_536b24e74e8c0a40653521e6086a120c = L.marker(
#                 [37.77180975, -122.18811842292632],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_536b24e74e8c0a40653521e6086a120c.bindTooltip(
#                 `&lt;div&gt;
#                      1, 2708 60th Ave, Oakland, CA 94605, 0.9M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e8560d0c6f4d4c59bdfafae44acf7bc4 = L.marker(
#                 [37.7705761, -122.1772542088843],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_e8560d0c6f4d4c59bdfafae44acf7bc4.bindTooltip(
#                 `&lt;div&gt;
#                      2, 2939 68th Ave, Oakland, CA 94605, 1.0M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4c4507c0ec5abdbcb4abee11a4f09c8f = L.marker(
#                 [37.8402173, -122.2073642704905],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_4c4507c0ec5abdbcb4abee11a4f09c8f.bindTooltip(
#                 `&lt;div&gt;
#                      3, 1738 Indian Way, Oakland, CA 94611, 1.1M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cb762716012f3822429f42be748c90e2 = L.marker(
#                 [37.78211895, -122.18854719286996],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_cb762716012f3822429f42be748c90e2.bindTooltip(
#                 `&lt;div&gt;
#                      4, 6 Wyman Pl, Oakland, CA 94619, 0.9M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_39257348430319d8e3adfa56256f916f = L.marker(
#                 [37.77016795, -122.12994189712765],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_39257348430319d8e3adfa56256f916f.bindTooltip(
#                 `&lt;div&gt;
#                      5, 33 Graeagle, Oakland, CA 94605, 0.9M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0b60767f1e519c6de19d8d42cc19b026 = L.marker(
#                 [37.781907700000005, -122.19144944555576],
#                 {}
#             ).addTo(marker_cluster_6156d36919cbca99fc7409978af5fc3d);
#
#
#             marker_0b60767f1e519c6de19d8d42cc19b026.bindTooltip(
#                 `&lt;div&gt;
#                      6, 3374 Madera Ave, Oakland, CA 94619, 1.0M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4f708cf6f69bd9d60246290be7419942 = L.marker(
#                 [37.83576495, -122.18586692939164],
#                 {}
#             ).addT

# %%
df
# Out:
#    dateSold   propertyType  lotAreaValue  \
# 20     None  SINGLE_FAMILY   6400.000000
# 16     None  SINGLE_FAMILY   4400.000000
# 24     None   MULTI_FAMILY   4791.600000
# 1      None  SINGLE_FAMILY   8276.400000
# 40     None  SINGLE_FAMILY   5967.720000
# 19     None      TOWNHOUSE   2178.000000
# 42     None  SINGLE_FAMILY   4356.000000
# 8      None  SINGLE_FAMILY   5508.000000
# 11     None  SINGLE_FAMILY   7405.200000
# 13     None  SINGLE_FAMILY   6534.000000
# 39     None  SINGLE_FAMILY      0.280000
# 28     None   MULTI_FAMILY   8288.000000
# 38     None  SINGLE_FAMILY   4578.156000
# 36     None  SINGLE_FAMILY   5227.200000
# 14     None  SINGLE_FAMILY   4356.000000
# 23     None      TOWNHOUSE   2831.400000
# 37     None  SINGLE_FAMILY   5227.200000
# 12     None  SINGLE_FAMILY   5227.200000
# 22     None  SINGLE_FAMILY   9174.000000
# 3      None  SINGLE_FAMILY   6098.400000
# 15     None  SINGLE_FAMILY      0.292998
# 4      None  SINGLE_FAMILY   6969.600000
# 2      None  SINGLE_FAMILY   8276.400000
# 9      None   MULTI_FAMILY   3920.400000
# 5      None  SINGLE_FAMILY   3920.400000
# 27     None      TOWNHOUSE   2178.000000
# 21     None  SINGLE_FAMILY   7405.200000
# 46     None  SINGLE_FAMILY   5227.200000
# 41     None  SINGLE_FAMILY   6098.400000
# 26     None  SINGLE_FAMILY   7840.800000
# 7      None  SINGLE_FAMILY   6547.068000
# 18     None  SINGLE_FAMILY      1.120000
# 47     None  SINGLE_FAMILY   2940.038600
# 25     None  SINGLE_FAMILY   6098.400000
# 17     None  SINGLE_FAMILY   6272.640000
# 32     None   MULTI_FAMILY   6534.000000
# 48     None   MULTI_FAMILY   7896.000000
# 44     None  SINGLE_FAMILY   4356.000000
# 0      None  SINGLE_FAMILY   6969.600000
# 6      None  SINGLE_FAMILY  10454.400000
# 33     None   MULTI_FAMILY   5300.000000
# 31     None  SINGLE_FAMILY      0.000000
# 45     None  SINGLE_FAMILY   6969.600000
# 43     None  SINGLE_FAMILY   4360.000000
# 30     None  SINGLE_FAMILY   5227.200000
# 29     None  SINGLE_FAMILY      0.250000
# 34     None   MULTI_FAMILY   2500.000000
# 10     None   MULTI_FAMILY   4373.424000
# 49     None   MULTI_FAMILY   3049.200000
# 35     None  SINGLE_FAMILY   5207.000000
#
#                                        address variableData  priceChange  \
# 20           6933 Simson St, Oakland, CA 94605         None          NaN
# 16            2708 60th Ave, Oakland, CA 94605         None          NaN
# 24            2939 68th Ave, Oakland, CA 94605         None          NaN
# 1           1738 Indian Way, Oakland, CA 94611         None          NaN
# 40               6 Wyman Pl, Oakland, CA 94619         None     -70000.0
# 19              33 Graeagle, Oakland, CA 94605         None          NaN
# 42          3374 Madera Ave, Oakland, CA 94619         None          NaN
# 8   8040 Shepherd Canyon Rd, Oakland, CA 94611         None          NaN
# 11        4800 Shetland Ave, Oakland, CA 94605         None          NaN
# 13         3660 Calafia Ave, Oakland, CA 94605         None          NaN
# 39        4121 Maybelle Ave, Oakland, CA 94619         None          NaN
# 28             7717 Ney Ave, Oakland, CA 94605         None          NaN
# 38           4854 Walnut St, Oakland, CA 94619         None          NaN
# 36           32 Kingwood Rd, Oakland, CA 94619         None          NaN
# 14         8300 Outlook Ave, Oakland, CA 94605         None          NaN
# 23        6403 Blue Rock Ct, Oakland, CA 94605         None          NaN
# 37            3817 Enos Ave, Oakland, CA 94619         None          NaN
# 12   4495 Mountain View Ave, Oakland, CA 94605         None     -96000.0
# 22      3660 Oak Knoll Blvd, Oakland, CA 94605         None          NaN
# 3              134 Moss Ave, Oakland, CA 94611         None          NaN
# 15       8424 Golf Links Rd, Oakland, CA 94605         None     -50112.0
# 4           6684 Banning Dr, Oakland, CA 94611         None          NaN
# 2       6206 Valley View Rd, Oakland, CA 94611         None          NaN
# 9           4246 Terrace St, Oakland, CA 94611         None          NaN
# 5           4250 Terrace St, Oakland, CA 94611         None          NaN
# 27      6272 Rocky Point Ct, Oakland, CA 94605         None          NaN
# 21          9810 Thermal St, Oakland, CA 94605         None    -111000.0
# 24         3274.0             4          6        2992     USA      USD
# 1             NaN             4          2        1584     USA      USD
# 40         3227.0             4          2        1800     USA      USD
# 19         4010.0             4          3        1636     USA      USD
# 42         4526.0             5          3        1657     USA      USD
# 8          5153.0             5          2        1778     USA      USD
# 11         4508.0             5          3        1773     USA      USD
# 13         2306.0             5          3        2428     USA      USD
# 39         4748.0             6          2        1710     USA      USD
# 28         2219.0             6          4        4130     USA      USD
# 38         3598.0            11          2        2155     USA      USD
# 36         5214.0            11          3        2028     USA      USD
# 14         3268.0            11          2        1737     USA      USD
# 23         4468.0            12          4        2291     USA      USD
# 37         4290.0            12          3        2020     USA      USD
# 12         3824.0            12          3        1943     USA      USD
# 22         5834.0            13          3        3160     USA      USD
# 3          5099.0            14          2        2239     USA      USD
# 15         6363.0            26          3        2392     USA      USD
# 4          5682.0            26          3        2452     USA      USD
# 2          5295.0            27          2        1502     USA      USD
# 9             NaN            31          2        2391     USA      USD
# 5          5870.0            31          2        2497     USA      USD
# 27         4405.0            32          3        2269     USA      USD
# 21         5063.0            32          3        3010     USA      USD
# 46            NaN            33          3        1528     USA      USD
# 41         5171.0            33          2        1827     USA      USD
# 26         4737.0            39          2        1792     USA      USD
# 7          6235.0            40          3        2263     USA      USD
# 18         5293.0            41          2        2155     USA      USD
# 47         3958.0            41          2        1746     USA      USD
# 25         4448.0            46          3        2242     USA      USD
# 17         3983.0            53          2        1608     USA      USD
# 32         5089.0            59          3        2770     USA      USD
# 48            NaN            61          3        2175     USA      USD
# 44         4208.0            62          2        1839     USA      USD
# 0          5684.0            67          2        1914     USA      USD
# 6          5248.0            67          2        1808     USA      USD
# 33         4274.0            83          4        3264     USA      USD
# 31         6507.0           108          4        4055     USA      USD
# 45         4111.0           121          3        1767     USA      USD
# 43         5055.0           143          4        2241     USA      USD
# 30         4474.0           144          3        2257     USA      USD
# 29         4398.0           155          2        1834     USA      USD
# 34         3237.0           173          4        3196     USA      USD
# 10         4075.0           208          2        1911     USA      USD
# 49         3234.0           213          4        2718     USA      USD
# 35         4044.0           627          3        2020     USA      USD
#
#    lotAreaUnit  hasImage listingSubType.is_FSBA listingSubType.is_openHouse  \
# 20        sqft      True                   True                         NaN
# 16        sqft      True                   True                         NaN
# 24        sqft      True                   True                        True
# 1         sqft      True                   True                        True
# 40        sqft      True                   True                        True
# 19        sqft      True                   True                         NaN
# 42        sqft      True                   True                         NaN
# 8         sqft      True                   True                         NaN
# 11        sqft      True                   True                        True
# 13        sqft      True                   True                        True
# 39       acres      True                   True                        True
# 28        sqft      True                   True                         NaN
# 38        sqft      True                   True                         NaN
# 36        sqft      True                   True                         NaN
# 14        sqft      True                   True                         NaN
# 23        sqft      True                   True                         NaN
# 37        sqft      True                   True                        True
# 12        sqft      True                   True                         NaN
# 22        sqft      True                   True                         NaN
# 3         sqft      True                   True                        True
# 15       acres      True                   True                        True
# 4         sqft      True                   True                         NaN
# 2         sqft      True                   True                         NaN
# 9         sqft      True                   True                         NaN
# 5         sqft      True                   True                         NaN
# 27        sqft      True                   True                         NaN
# 21        sqft      True                   True                         NaN
# 46        sqft      True                   True                         NaN
# 41        sqft      True                   True                         NaN
# 26        sqft      True                   True                         NaN
# 7         sqft      True                    NaN                         NaN
# 18       acres      True                   True                         NaN
# 47        sqft      True                   True                         NaN
# 25        sqft      True                   True                         NaN
# 17        sqft      True                   True                         NaN
# 32        sqft      True                   True                         NaN
# 48        sqft      True                   True                         NaN
# 44        sqft      True                   True                         NaN
# 0         sqft      True                   True                        True
# 6         sqft      True                   True                         NaN
# 33        sqft      True                   True                         NaN
# 31        sqft      True                    NaN                         NaN
# 45        sqft      True                   True                         NaN
# 43        sqft      True                   True                         NaN
# 30        sqft      True                   True                         NaN
# 29       acres      True                   True                         NaN
# 34        sqft      True                   True                         NaN
# 10        sqft      True                   True                         NaN
# 49        sqft      True                   True                         NaN
# 35        sqft      True                    NaN                         NaN
#
#    listingSubType.is_foreclosure listingSubType.is_bankOwned  \
# 20                           NaN                         NaN
# 16                           NaN                         NaN
# 24                           NaN                         NaN
# 1                            NaN                         NaN
# 40                           NaN                         NaN
# 19                           NaN                         NaN
# 42                           NaN                         NaN
# 8                            NaN                         NaN
# 11                           NaN                         NaN
# 13                           NaN                         NaN
# 39                           NaN                         NaN
# 28                           NaN                         NaN
# 38                           NaN                         NaN
# 36                           NaN                         NaN
# 14                           NaN                         NaN
# 23                           NaN                         NaN
# 37                           NaN                         NaN
# 12                           NaN                         NaN
# 22                           NaN                         NaN
# 3                            NaN                         NaN
# 15                           NaN                         NaN
# 4                            NaN                         NaN
# 2                            NaN                         NaN
# 9                            NaN                         NaN
# 5                            NaN                         NaN
# 27                           NaN                         NaN
# 21                           NaN                         NaN
# 46                           NaN                         NaN
# 41                           NaN                         NaN
# 26                           NaN                         NaN
# 7                           True                         NaN
# 18                           NaN                         NaN
# 47                           NaN                         NaN
# 25                           NaN                         NaN
# 17                           NaN                         NaN
# 32                           NaN                         NaN
# 48                           NaN                         NaN
# 44                           NaN                         NaN
# 0                            NaN                         NaN
# 6                            NaN                         NaN
# 33                           NaN                         NaN
# 31                           NaN                        True
# 45                           NaN                         NaN
# 43                           NaN                         NaN
# 30                           NaN                         NaN
# 29                           NaN                         NaN
# 34                           NaN                         NaN
# 10                           NaN                         NaN
# 49                           NaN                         NaN
# 35                           NaN                         NaN
#
#    listingSubType.is_forAuction  \
# 20                          NaN
# 16                          NaN
# 24                          NaN
# 1                           NaN
# 40                          NaN
# 19                          NaN
# 42                          NaN
# 8                           NaN
# 11                          NaN
# 13                          NaN
# 39                          NaN
# 28                          NaN
# 38                          NaN
# 36                          NaN
# 14                          NaN
# 23                          NaN
# 37                          NaN
# 12                          NaN
# 22                          NaN
# 3                           NaN
# 15                          NaN
# 4                           NaN
# 2                           NaN
# 9                           NaN
# 5                           NaN
# 27                          NaN
# 21                          NaN
# 46                          NaN
# 41                          NaN
# 26                          NaN
# 7                           NaN
# 18                          NaN
# 47                          NaN
# 25                          NaN
# 17                          NaN
# 32                          NaN
# 48                          NaN
# 44                          NaN
# 0                           NaN
# 6                           NaN
# 33                          NaN
# 31                          NaN
# 45                          NaN
# 43                          NaN
# 30                          NaN
# 29                          NaN
# 34                          NaN
# 10                          NaN
# 49                          NaN
# 35                         True
#
#                                                   loc price2 Index  \
# 20  (6933, Simson Street, Eastmont, Oakland, Alame...   0.9M     0
# 16  (2708, 60th Avenue, Seminary Park, Oakland, Al...   0.9M     1
# 24  (2939;2941, 68th Avenue, Eastmont, Oakland, Al...   1.0M     2
# 1   (1738, Indian Way, Oakland, Alameda County, Ca...   1.1M     3
# 40  (6, Wyman Place, Maxwell Park, Oakland, Alamed...   0.9M     4
# 19  (33, Graeagle, Oakland, Alameda County, Califo...   0.9M     5
# 42  (3374, Madera Avenue, Maxwell Park, Oakland, A...   1.0M     6
# 8   (8040, Shepherd Canyon Road, Oakland, Alameda ...   1.0M     7
# 11  (4800, Shetland Avenue, Oakland, Alameda Count...   0.9M     8
# 13  (3660, Calafia Avenue, Oakland, Alameda County...   0.9M     9
# 39  (4121, Maybelle Avenue, Laurel, Oakland Hills,...   1.1M    10
# 28  (7717, Ney Avenue, Eastmont, Oakland, Alameda ...   0.9M    11
# 38  (4854, Walnut Street, Maxwell Park, East Oakla...   0.9M    12
# 36  (32, Kingwood Road, Oakland Hills, Oakland, Al...   1.0M    13
# 14  (8300, Outlook Avenue, Oakland, Alameda County...   0.8M    14
# 23  (6403, Blue Rock Court, Monte Visa Villas, Oak...   0.9M    15
# 37  (3817, Enos Avenue, Oakland, Alameda County, C...   1.0M    16
# 12  (4495, Mountain View Avenue, Oakland, Alameda ...   0.9M    17
# 22  (3660, Oak Knoll Boulevard, Oakland, Alameda C...   0.8M    18
# 3   (134, Moss Avenue, Harrison/Oakland, Oakland, ...   1.0M    19
# 15  (8424, Golf Links Road, Oakland, Alameda Count...   0.8M    20
# 4   (6684, Banning Drive, Oakland, Alameda County,...   1.0M    21
# 2   (6206, Valley View Road, Oakland, Alameda Coun...   0.9M    22
# 9   (4246, Terrace Street, Broadway Auto Row, Nort...   1.0M    23
# 5   (4250, Terrace Street, Broadway Auto Row, Nort...   1.0M    24
# 27  (6272, Rocky Point Court, Monte Visa Villas, O...   0.9M    25
# 21  (9810, Thermal Street, Oakland, Alameda County...   0.9M    26
# 46  (4433, Fair Avenue, Oakland, Alameda County, C...   1.0M    27
# 41  (4115, 39th Avenue, Laurel, Oakland Hills, Oak...   0.9M    28
# 26  (4701, Dunkirk Avenue, Oakland, Alameda County...   1.1M    29
# 7   (6038, Ascot Drive, Piedmont Pines, Oakland, A...   1.1M    30
# 18  (11165, Lochard Street, Oakland, Alameda Count...   1.0M    31
# 47  (4728, Meldon Avenue, Maxwell Park, Oakland, A...   0.9M    32
# 25  (6398, Buena Ventura Avenue, Millsmont, Oaklan...   1.0M    33
# 17  (3487, Margarita Avenue, Oakland, Alameda Coun...   0.9M    34
# 32  (7856, Ney Avenue, Eastmont, Oakland, Alameda ...   0.9M    35
# 48  (3227, 35th Avenue, Laurel, Oakland, Alameda C...   0.9M    36
# 44  (3106, Rawson Street, Maxwell Park, East Oakla...   1.0M    37
# 0   (5630, Balboa Drive, Montclair, Oakland, Alame...   1.1M    38
# 6   (7, East Circle, Oakland, Alameda County, Cali...   1.1M    39
# 33  (2232, 83rd Avenue, Oakland, Alameda County, C...   1.1M    40
# 31  (10990, Caloden Street, Oakland, Alameda Count...   1.1M    41
# 45  (3814;3816, Quigley Street, Laurel, Oakland, A...   0.9M    42
# 43  (2707, Monticello Avenue, Maxwell Park, East O...   0.9M    43
# 30  (6336, Buena Ventura Avenue, Millsmont, Oaklan...   1.1M    44
# 29  (175, Sequoyah View Drive, Oakland, Alameda Co...   1.1M    45
# 34  (2740, 73rd Avenue, Eastmont, Oakland, Alameda...   0.9M    46
# 10  (69;71, Echo Avenue, Piedmont Avenue, North Oa...   1.1M    47
# 49  (3792;3794;3796;3798, Angelo Avenue, Laurel, E...   0.9M    48
# 35  (6193, Oakdale Avenue, Millsmont, Oakland, Ala...   0.9M    49
#
#                                         address_price  \
# 20         0, 6933 Simson St, Oakland, CA 94605, 0.9M
# 16          1, 2708 60th Ave, Oakland, CA 94605, 0.9M
# 24          2, 2939 68th Ave, Oakland, CA 94605, 1.0M
# 1         3, 1738 Indian Way, Oakland, CA 94611, 1.1M
# 40             4, 6 Wyman Pl, Oakland, CA 94619, 0.9M
# 19            5, 33 Graeagle, Oakland, CA 94605, 0.9M
# 42        6, 3374 Madera Ave, Oakland, CA 94619, 1.0M
# 8   7, 8040 Shepherd Canyon Rd, Oakland, CA 94611,...
# 11      8, 4800 Shetland Ave, Oakland, CA 94605, 0.9M
# 13       9, 3660 Calafia Ave, Oakland, CA 94605, 0.9M
# 39     10, 4121 Maybelle Ave, Oakland, CA 94619, 1.1M
# 28          11, 7717 Ney Ave, Oakland, CA 94605, 0.9M
# 38        12, 4854 Walnut St, Oakland, CA 94619, 0.9M
# 36        13, 32 Kingwood Rd, Oakland, CA 94619, 1.0M
# 14      14, 8300 Outlook Ave, Oakland, CA 94605, 0.8M
# 23     15, 6403 Blue Rock Ct, Oakland, CA 94605, 0.9M
# 37         16, 3817 Enos Ave, Oakland, CA 94619, 1.0M
# 12  17, 4495 Mountain View Ave, Oakland, CA 94605,...
# 22   18, 3660 Oak Knoll Blvd, Oakland, CA 94605, 0.8M
# 3           19, 134 Moss Ave, Oakland, CA 94611, 1.0M
# 15    20, 8424 Golf Links Rd, Oakland, CA 94605, 0.8M
# 4        21, 6684 Banning Dr, Oakland, CA 94611, 1.0M
# 2    22, 6206 Valley View Rd, Oakland, CA 94611, 0.9M
# 9        23, 4246 Terrace St, Oakland, CA 94611, 1.0M
# 5        24, 4250 Terrace St, Oakland, CA 94611, 1.0M
# 27   25, 6272 Rocky Point Ct, Oakland, CA 94605, 0.9M
# 21       26, 9810 Thermal St, Oakland, CA 94605, 0.9M
# 46         27, 4433 Fair Ave, Oakland, CA 94619, 1.0M
# 41         28, 4115 39th Ave, Oakland, CA 94619, 0.9M
# 26      29, 4701 Dunkirk Ave, Oakland, CA 94605, 1.1M
