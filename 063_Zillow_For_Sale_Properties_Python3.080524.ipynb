# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python3.080524.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'hayward'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Search string: hayward, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Houses",
               "minPrice": "800000",
               "maxPrice": "1200000",
               "sqftMin": "1000",
               "bedsMin": "2"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.34,
#    'address': '2060 Quail Canyon Ct, Hayward, CA 94542',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/050fdc9b482843b82897fe9c9efd78ac-p_e.jpg',
#    'price': 999998,
#    'detailUrl': '/homedetails/2060-Quail-Canyon-Ct-Hayward-CA-94542/24969904_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.055695,
#    'latitude': 37.662945,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24969904',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4230,
#    'daysOnZillow': 3,
#    'bathrooms': 3,
#    'livingArea': 2077,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '2559 Bradford Ave, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 889100,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7def5a2c7f6e2d508ef058e45c4c7b26-p_e.jpg',
#    'price': 824999,
#    'detailUrl': '/homedetails/2559-Bradford-Ave-Hayward-CA-94545/24977424_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.10972,
#    'latitude': 37.63582,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24977424',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3324,
#    'daysOnZillow': 6,
#    'bathrooms': 2,
#    'livingArea': 1157,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6534,
#    'address': '24681 Willimet Way, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5a9220f47b0e4c6775b85c0ad095d37d-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/24681-Willimet-Way-Hayward-CA-94544/24979652_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.09815,
#    'latitude': 37.652042,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24979652',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3518,
#    'daysOnZillow': 19,
#    'bathrooms': 2,
#    'livingArea': 1285,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '1937 Southgate St, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 970200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5b66dbf4efa88ab969d6775f8ba8c799-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/1937-Southgate-St-Hayward-CA-94545/111408865_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.09411,
#    'latitude': 37.63551,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '111408865',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3418,
#    'daysOnZillow': 7,
#    'bathrooms': 2,
#    'livingArea': 1128,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6098.4,
#    'address': '932 Poinciana St, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/eedd3f6fbe9f1eb88fb9387f3bec4c72-p_e.jpg',
#    'price': 850000,
#    'detailUrl': '/homedetails/932-Poinciana-St-Hayward-CA-94545/24978387_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.101,
#    'latitude': 37.64891,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24978387',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3567,
#    'daysOnZillow': 11,
#    'bathrooms': 2,
#    'livingArea': 1398,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.61,
#    'address': '25124 Monte Vista Dr, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/827153cfad41e5f958618ad3b5c2661f-p_e.jpg',
#    'price': 1099999,
#    'detailUrl': '/homedetails/25124-Monte-Vista-Dr-Hayward-CA-94545/24977536_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -122.11371,
#    'latitude': 37.64003,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24977536',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3328,
#    'daysOnZillow': 11,
#    'bathrooms': 2,
#    'livingArea': 2104,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8276.4,
#    'address': '22238 Victory Dr, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1066000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/35867a52e5df3d931e43cba1fa00725b-p_e.jpg',
#    'price': 999999,
#    'detailUrl': '/homedetails/22238-Victory-Dr-Hayward-CA-94541/63084259_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.11031,
#    'latitude': 37.66296,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '63084259',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3552,
#    'daysOnZillow': 5,
#    'bathrooms': 2,
#    'livingArea': 3300,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1742.4,
#    'address': '22864 Amador St, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 880400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/91c9dcaf723cc2c02e1456abee078f42-p_e.jpg',
#    'price': 849000,
#    'detailUrl': '/homedetails/22864-Amador-St-Hayward-CA-94541/111393713_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.09855,
#    'latitude': 37.664436,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '111393713',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3943,
#    'daysOnZillow': 3,
#    'bathrooms': 3,
#    'livingArea': 1748,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5130,
#    'address': '26218 Adrian Ave, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1026900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6e043b51c4640f31b6049d9ae02847b9-p_e.jpg',
#    'price': 979000,
#    'detailUrl': '/homedetails/26218-Adrian-Ave-Hayward-CA-94545/24977067_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.1027,
#    'latitude': 37.63784,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24977067',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3495,
#    'daysOnZillow': 3,
#    'bathrooms': 2,
#    'livingArea': 1244,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '242 Blossom Way, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bc194892d2129071e0ba5e20774bad51-p_e.jpg',
#    'price': 809000,
#    'detailUrl': '/homedetails/242-Blossom-Way-Hayward-CA-94541/24973133_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.10795,
#    'latitude': 37.677235,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24973133',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3659,
#    'daysOnZillow': 25,
#    'bathrooms': 1,
#    'livingArea': 1272,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7952,
#    'address': '22515 Byron St, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 888000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4b6e9ce4a46575af2dbe2897628ee96b-p_e.jpg',
#    'price': 849000,
#    'detailUrl': '/homedetails/22515-Byron-St-Hayward-CA-94541/24966837_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.05312,
#    'latitude': 37.688377,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24966837',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3696,
#    'daysOnZillow': 5,
#    'bathrooms': 2,
#    'livingArea': 1715,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4791.6,
#    'address': '24674 Lyell Way, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/abc1dc13a880f4ecca6f73817a697f83-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/24674-Lyell-Way-Hayward-CA-94544/24981231_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.082985,
#    'latitude': 37.65793,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24981231',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3716,
#    'daysOnZillow': 9,
#    'bathrooms': 2,
#    'livingArea': 1418,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5662.8,
#    'address': '27744 Haldane Ct, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bef64a8c1b9b2e32f6b78cae8745af8f-p_e.jpg',
#    'price': 878000,
#    'detailUrl': '/homedetails/27744-Haldane-Ct-Hayward-CA-94544/24985101_zpid/',
#    'bedrooms': 5,
#    'contingentListingType': None,
#    'longitude': -122.07045,
#    'latitude': 37.63264,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24985101',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3999,
#    'daysOnZillow': 18,
#    'bathrooms': 2,
#    'livingArea': 1574,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.37,
#    'address': '31655 Chicoine Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1166000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7d946a653c86de0cecd8e8b4aac6d77d-p_e.jpg',
#    'price': 1079000,
#    'detailUrl': '/homedetails/31655-Chicoine-Ave-Hayward-CA-94544/24889878_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.0298,
#    'latitude': 37.617973,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24889878',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3890,
#    'daysOnZillow': 10,
#    'bathrooms': 2,
#    'livingArea': 1550,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9016.92,
#    'address': '2871 Hansen Rd, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5424d4c7e1d778bf9c3303febc93f327-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/2871-Hansen-Rd-Hayward-CA-94541/24968823_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.05241,
#    'latitude': 37.673836,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24968823',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3364,
#    'daysOnZillow': 11,
#    'bathrooms': 1,
#    'livingArea': 1035,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1742.4,
#    'address': '391 B St, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a0efaa90a9bfcb05683a3204aa7d07bc-p_e.jpg',
#    'price': 979950,
#    'detailUrl': '/homedetails/391-B-St-Hayward-CA-94541/124733487_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.09361,
#    'latitude': 37.668056,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '124733487',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3895,
#    'daysOnZillow': 20,
#    'bathrooms': 3,
#    'livingArea': 1607,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '825 Douglas St, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': -24000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4b4127044114a2d30338b1412245cdcf-p_e.jpg',
#    'price': 875000,
#    'detailUrl': '/homedetails/825-Douglas-St-Hayward-CA-94544/24887788_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.056206,
#    'latitude': 37.641224,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24887788',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 4156,
#    'daysOnZillow': 53,
#    'bathrooms': 3,
#    'livingArea': 1470,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5280,
#    'address': '24576 Oneil Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 890400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2fcf80c9168ef14a175de870fc62d4a4-p_e.jpg',
#    'price': 829000,
#    'detailUrl': '/homedetails/24576-Oneil-Ave-Hayward-CA-94544/24980982_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.0773,
#    'latitude': 37.662125,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24980982',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3891,
#    'daysOnZillow': 3,
#    'bathrooms': 2,
#    'livingArea': 1358,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6884,
#    'address': '2179 Palm Pl, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 923800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/170db9e817ef629bae27bbe7b419ee19-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/2179-Palm-Pl-Hayward-CA-94545/24988085_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.09027,
#    'latitude': 37.626545,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24988085',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3582,
#    'daysOnZillow': 17,
#    'bathrooms': 2,
#    'livingArea': 1119,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5559,
#    'address': '330 Falgren Ave, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 854900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f73b0c0e41d2f5a83929a6810b3dfabc-p_e.jpg',
#    'price': 849800,
#    'detailUrl': '/homedetails/330-Falgren-Ave-Hayward-CA-94541/24960644_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.11297,
#    'latitude': 37.672134,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24960644',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3842,
#    'daysOnZillow': 17,
#    'bathrooms': 2,
#    'livingArea': 1175,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '27647 Pompano Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e5b29113dde7049b17bb6ce0aaf80117-p_e.jpg',
#    'price': 899999,
#    'detailUrl': '/homedetails/27647-Pompano-Ave-Hayward-CA-94544/24992058_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.07778,
#    'latitude': 37.630222,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24992058',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3740,
#    'daysOnZillow': 20,
#    'bathrooms': 2,
#    'livingArea': 1556,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25,
#    'address': '25601 Firebrand Pl, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1f0d925606c390e01d9d169cc8d8c389-p_e.jpg',
#    'price': 1199886,
#    'detailUrl': '/homedetails/25601-Firebrand-Pl-Hayward-CA-94541/24969333_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.045975,
#    'latitude': 37.66869,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24969333',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4145,
#    'daysOnZillow': 17,
#    'bathrooms': 3,
#    'livingArea': 1896,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '356 Saint George St, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': -40000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7d9217579d9ba5d20693b3c5b8845af3-p_e.jpg',
#    'price': 848000,
#    'detailUrl': '/homedetails/356-Saint-George-St-Hayward-CA-94541/24973184_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.10602,
#    'latitude': 37.679184,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24973184',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3665,
#    'daysOnZillow': 53,
#    'bathrooms': 2,
#    'livingArea': 1329,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7888,
#    'address': '24688 Heather Ct, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 982200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/906ec9ee256d1244fcd89704ea4a515e-p_e.jpg',
#    'price': 998000,
#    'detailUrl': '/homedetails/24688-Heather-Ct-Hayward-CA-94545/24977017_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.110855,
#    'latitude': 37.645798,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24977017',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3584,
#    'daysOnZillow': 24,
#    'bathrooms': 2,
#    'livingArea': 1172,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5328,
#    'address': '23232 Lori Way, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': 61112,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e105185b68841f2ffdcaaa858f2dfdcf-p_e.jpg',
#    'price': 950000,
#    'detailUrl': '/homedetails/23232-Lori-Way-Hayward-CA-94541/24967241_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.045105,
#    'latitude': 37.683804,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24967241',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4249,
#    'daysOnZillow': 60,
#    'bathrooms': 3,
#    'livingArea': 1960,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1595,
#    'address': '24207 2nd St, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1100000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cd3695ecbe1c4c02ed48107bc7cb2a7a-p_e.jpg',
#    'price': 1098800,
#    'detailUrl': '/homedetails/24207-2nd-St-Hayward-CA-94541/318985703_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.0721,
#    'latitude': 37.669907,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '318985703',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4158,
#    'daysOnZillow': 10,
#    'bathrooms': 4,
#    'livingArea': 2009,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '31677 Trevor Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1014600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/847fa5cc40298aa8cc246c059684defa-p_e.jpg',
#    'price': 945000,
#    'detailUrl': '/homedetails/31677-Trevor-Ave-Hayward-CA-94544/24889938_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.030525,
#    'latitude': 37.617046,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24889938',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 3596,
#    'daysOnZillow': 4,
#    'bathrooms': 2,
#    'livingArea': 1175,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '272 Newton St, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c69c1ffff4682f89fa69015d158d01c3-p_e.jpg',
#    'price': 938888,
#    'detailUrl': '/homedetails/272-Newton-St-Hayward-CA-94544/24983107_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.07123,
#    'latitude': 37.64828,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24983107',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4123,
#    'daysOnZillow': 27,
#    'bathrooms': 2,
#    'livingArea': 1640,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5300,
#    'address': '27765 Decatur Way, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 882900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/29692e0baa19e9400acf0600c598edb1-p_e.jpg',
#    'price': 869777,
#    'detailUrl': '/homedetails/27765-Decatur-Way-Hayward-CA-94545/24988136_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.08798,
#    'latitude': 37.626926,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24988136',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3815,
#    'daysOnZillow': 19,
#    'bathrooms': 2,
#    'livingArea': 1455,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2136,
#    'address': '24253 Nora Cir, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1081700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/dac0f323f9bdecbe09cbaf44faa8c646-p_e.jpg',
#    'price': 1099000,
#    'detailUrl': '/homedetails/24253-Nora-Cir-Hayward-CA-94545/250134221_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.113914,
#    'latitude': 37.647053,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '250134221',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3892,
#    'daysOnZillow': 37,
#    'bathrooms': 3,
#    'livingArea': 1684,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5662.8,
#    'address': '87 Saint Andrews St, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/789991d9ef397720d9c776dcf2ae075d-p_e.jpg',
#    'price': 998888,
#    'detailUrl': '/homedetails/87-Saint-Andrews-St-Hayward-CA-94544/24888391_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.04392,
#    'latitude': 37.618908,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24888391',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3589,
#    'daysOnZillow': 11,
#    'bathrooms': 2,
#    'livingArea': 1160,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5900,
#    'address': '1158 Citron Way, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 999000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/60145b9dfafd53d54a7c83aa167e4698-p_e.jpg',
#    'price': 949888,
#    'detailUrl': '/homedetails/1158-Citron-Way-Hayward-CA-94545/24978378_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.10303,
#    'latitude': 37.645496,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24978378',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3895,
#    'daysOnZillow': 6,
#    'bathrooms': 2,
#    'livingArea': 1544,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6098.4,
#    'address': '756 Bluefield Ln, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/726030e21b68300dce352bc33ddf33d8-p_e.jpg',
#    'price': 899950,
#    'detailUrl': '/homedetails/756-Bluefield-Ln-Hayward-CA-94541/24976337_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.10541,
#    'latitude': 37.655247,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24976337',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3272,
#    'daysOnZillow': 31,
#    'bathrooms': 2,
#    'livingArea': 1510,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5005.044,
#    'address': '649 Quincy Way, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 985900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/025c4aff6fdf30db22a2bb321274782d-p_e.jpg',
#    'price': 949998,
#    'detailUrl': '/homedetails/649-Quincy-Way-Hayward-CA-94541/24976235_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.10463,
#    'latitude': 37.65704,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24976235',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3227,
#    'daysOnZillow': 11,
#    'bathrooms': 2,
#    'livingArea': 1438,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1845,
#    'address': '23320 Wilmot Cir, Hayward, CA 94545',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 838400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7e7047600bfb6d34baebcec2148e609e-p_e.jpg',
#    'price': 844900,
#    'detailUrl': '/homedetails/23320-Wilmot-Cir-Hayward-CA-94545/241574913_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -122.11766,
#    'latitude': 37.651108,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '241574913',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3791,
#    'daysOnZillow': 20,
#    'bathrooms': 3,
#    'livingArea': 1350,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9975.24,
#    'address': '969 Folsom Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c97e9f25c498fe5d202f47dfe1452f2a-p_e.jpg',
#    'price': 995888,
#    'detailUrl': '/homedetails/969-Folsom-Ave-Hayward-CA-94544/24992739_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.067406,
#    'latitude': 37.625416,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24992739',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3632,
#    'daysOnZillow': 33,
#    'bathrooms': 2,
#    'livingArea': 1236,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '601 Garin Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': -18000,
#    'zestimate': 998400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2d44b981c0465e313f18809790c26241-p_e.jpg',
#    'price': 1020000,
#    'detailUrl': '/homedetails/601-Garin-Ave-Hayward-CA-94544/24903371_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.04244,
#    'latitude': 37.627842,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24903371',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3594,
#    'daysOnZillow': 90,
#    'bathrooms': 2,
#    'livingArea': 1392,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7497,
#    'address': '121 Mamaz Ct, Hayward, CA 94541',
#    'newConstructionType': 'BUILDER_SPEC',
#    'variableData': None,
#    'priceChange': -50001,
#    'zestimate': 1076700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/129527e9c7b850feb8a367ef133d4a00-p_e.jpg',
#    'price': 1099999,
#    'detailUrl': '/homedetails/121-Mamaz-Ct-Hayward-CA-94541/353703372_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.084564,
#    'latitude': 37.67464,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '353703372',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': 3932,
#    'daysOnZillow': 37,
#    'bathrooms': 3,
#    'livingArea': 1569,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '26723 Huntwood Ave, Hayward, CA 94544',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/8b68d43b8d0640054de00df57096d639-p_e.jpg',
#    'price': 915000,
#    'detailUrl': '/homedetails/26723-Huntwood-Ave-Hayward-CA-94544/24984464_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.07353,
#    'latitude': 37.642616,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24984464',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3442,
#    'daysOnZillow': 42,
#    'bathrooms': 3,
#    'livingArea': 1592,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8276.4,
#    'address': '27048 Columbia Ct, Hayward, CA 94542',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1226400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/339fc23656814e1d03f2d482715353ad-p_e.jpg',
#    'price': 1129000,
#    'detailUrl': '/homedetails/27048-Columbia-Ct-Hayward-CA-94542/24903247_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.04324,
#    'latitude': 37.654095,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24903247',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4244,
#    'daysOnZillow': 1,
#    'bathrooms': 2,
#    'livingArea': 1688,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6850,
#    'address': '1115 Cotter Way, Hayward, CA 94541',
#    'variableData': None,
#    'priceChange': -50000,
#    'zestimate': 862000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/41470882f980858f5a7054144ad54401-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/1115-Cotter-Way-Hayward-CA-94541/24972312_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -122.09171,
#    'latitude': 37.681263,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '24972312',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 3648,
#    'daysOnZillow': 82,
#    'bathrooms': 2,
#    'livingArea': 1676,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 2,
#  'totalResultCount': 44,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 41
# Num of cols: 28
#   dateSold   propertyType  lotAreaValue  \
# 0     None  SINGLE_FAMILY          0.34
# 1     None  SINGLE_FAMILY       5227.20
# 2     None  SINGLE_FAMILY       6534.00
# 3     None  SINGLE_FAMILY       5227.20
# 4     None  SINGLE_FAMILY       6098.40
#
#                                    address variableData  priceChange  \
# 0  2060 Quail Canyon Ct, Hayward, CA 94542         None          NaN
# 1     2559 Bradford Ave, Hayward, CA 94545         None          NaN
# 2    24681 Willimet Way, Hayward, CA 94544         None          NaN
# 3     1937 Southgate St, Hayward, CA 94545         None          NaN
# 4      932 Poinciana St, Hayward, CA 94545         None          NaN
#
#    zestimate                                             imgSrc   price  \
# 0        NaN  https://photos.zillowstatic.com/fp/050fdc9b482...  999998
# 1   889100.0  https://photos.zillowstatic.com/fp/7def5a2c7f6...  824999
# 2        NaN  https://photos.zillowstatic.com/fp/5a9220f47b0...  899000
# 3   970200.0  https://photos.zillowstatic.com/fp/5b66dbf4efa...  899000
# 4        NaN  https://photos.zillowstatic.com/fp/eedd3f6fbe9...  850000
#
#                                            detailUrl  bedrooms  \
# 0  /homedetails/2060-Quail-Canyon-Ct-Hayward-CA-9...         4
# 1  /homedetails/2559-Bradford-Ave-Hayward-CA-9454...         3
# 2  /homedetails/24681-Willimet-Way-Hayward-CA-945...         3
# 3  /homedetails/1937-Southgate-St-Hayward-CA-9454...         3
# 4  /homedetails/932-Poinciana-St-Hayward-CA-94545...         3
#
#   contingentListingType   longitude   latitude listingStatus       zpid  \
# 0                  None -122.055695  37.662945      FOR_SALE   24969904
# 1                  None -122.109720  37.635820      FOR_SALE   24977424
# 2                  None -122.098150  37.652042      FOR_SALE   24979652
# 3                  None -122.094110  37.635510      FOR_SALE  111408865
# 4                  None -122.101000  37.648910      FOR_SALE   24978387
#
#    rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0           4230             3          3        2077     USA      USD
# 1           3324             6          2        1157     USA      USD
# 2           3518            19          2        1285     USA      USD
# 3           3418             7          2        1128     USA      USD
# 4           3567            11          2        1398     USA      USD
#
#   lotAreaUnit  hasImage listingSubType.is_FSBA listingSubType.is_openHouse  \
# 0       acres      True                   True                         NaN
# 1        sqft      True                   True                         NaN
# 2        sqft      True                   True                         NaN
# 3        sqft      True                   True                         NaN
# 4        sqft      True                   True                         NaN
#
#   newConstructionType listingSubType.is_newHome
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['24969904',
#  '24977424',
#  '24979652',
#  '111408865',
#  '24978387',
#  '24977536',
#  '63084259',
#  '111393713',
#  '24977067',
#  '24973133',
#  '24966837',
#  '24981231',
#  '24985101',
#  '24889878',
#  '24968823',
#  '124733487',
#  '24887788',
#  '24980982',
#  '24988085',
#  '24960644',
#  '24992058',
#  '24969333',
#  '24973184',
#  '24977017',
#  '24967241',
#  '318985703',
#  '24889938',
#  '24983107',
#  '24988136',
#  '250134221',
#  '24888391',
#  '24978378',
#  '24976337',
#  '24976235',
#  '241574913',
#  '24992739',
#  '24903371',
#  '353703372',
#  '24984464',
#  '24903247',
#  '24972312']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 41
# Num of cols: 301
#    buildingPermits                                 contact_recipients  \
# 0              NaN  [{'agent_reason': 1, 'zpro': None, 'recent_sal...
# 1              NaN  [{'agent_reason': 1, 'zpro': None, 'recent_sal...
#
#     longitude countyFIPS                                             imgSrc  \
# 0 -122.055695      06001  https://photos.zillowstatic.com/fp/050fdc9b482...
# 1 -122.109720      06001  https://photos.zillowstatic.com/fp/7def5a2c7f6...
#
#    livingAreaValue         streetAddress          county  monthlyHoaFee  \
# 0           2077.0  2060 Quail Canyon Ct  Alameda County            8.0
# 1           1157.0     2559 Bradford Ave  Alameda County            NaN
#
#               timeZone                                         taxHistory  \
# 0  America/Los_Angeles  [{'time': 1691266698593, 'valueIncreaseRate': ...
# 1  America/Los_Angeles  [{'time': 1691266701349, 'valueIncreaseRate': ...
#
#    dateSold  annualHomeownersInsurance state  yearBuilt  \
# 0       NaN                     4200.0    CA     1986.0
# 1       NaN                     3465.0    CA     1958.0
#
#                    brokerageName  \
# 0  Community Realty & Investment
# 1       eXp Realty of California
#
#                                          description zipcode  \
# 0  Welcome to the “suburban treehouse”, a peacefu...   94542
# 1  Discover this inviting 3-bedroom, 2-bathroom h...   94545
#
#                                          nearbyHomes  \
# 0  [{'livingArea': 864, 'livingAreaValue': 864, '...
# 1  [{'livingArea': 1148, 'livingAreaValue': 1148,...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': -0.19289911218725, 'date'...
# 1  [{'priceChangeRate': 0.4102547008547, 'date': ...
#
#                                              schools  rentZestimate     city  \
# 0  [{'link': 'https://www.greatschools.org/califo...         4230.0  Hayward
# 1  [{'link': 'https://www.greatschools.org/califo...         3324.0  Hayward
#
#    providerListingID currency  listingProvider  propertyTaxRate   cityId  \
# 0                NaN      USD              NaN             1.24  18518.0
# 1                NaN      USD              NaN             1.24  18518.0
#
#   timeOnZillow                                                url  zestimate  \
# 0       3 days  /homedetails/2060-Quail-Canyon-Ct-Hayward-CA-9...        NaN
# 1       6 days  /homedetails/2559-Bradford-Ave-Hayward-CA-9454...   889100.0
#
#          zpid  countyId  brokerId livingAreaUnits  pageViewCount  bathrooms  \
# 0  24969904.0    1510.0       NaN            sqft         1128.0        3.0
# 1  24977424.0    1510.0       NaN            sqft         2164.0        2.0
#
#    building  stateId zestimateLowPercent  comingSoonOnMarketDate homeStatus  \
# 0       NaN      9.0                None                     NaN   FOR_SALE
# 1       NaN      9.0                   5                     NaN   FOR_SALE
#
#    homeFacts  datePosted  bedrooms propertyTypeDimension     price   latitude  \
# 0        NaN  2024-08-02       4.0         Single Family  999998.0  37.662945
# 1        NaN  2024-07-30       3.0         Single Family  824999.0  37.635820
#
#    favoriteCount zestimateHighPercent     mlsid  isListedByOwner  livingArea  \
# 0          115.0                 None  41068657              NaN      2077.0
# 1          153.0                    5  41068175              NaN      1157.0
#
#    buildingId country       homeType  solarPotential  contingentListingType  \
# 0         NaN     USA  SINGLE_FAMILY             NaN                    NaN
# 1         NaN     USA  SINGLE_FAMILY             NaN                    NaN
#
#    listed_by.agent_reason listed_by.zpro  listed_by.recent_sales  \
# 0                     3.0          False                     0.0
# 1                     3.0          False                     0.0
#
#             listed_by.zuid  listed_by.review_count listed_by.display_name  \
# 0  X1-ZUywzmr0tjjax5_3pg0k                     6.0          David Cerruti
# 1  X1-ZUud5cc6skh1c9_9skq8                     8.0         Michael Sayage
#
#                            listed_by.profile_url  \
# 0  https://www.zillow.com/profile/David-Cerruti/
# 1  https://www.zillow.com/profile/michaelsayage/
#
#          listed_by.business_name  listed_by.rating_average  \
# 0  Community Realty & Investment                       5.0
# 1       eXp Realty of California                       5.0
#
#   listed_by.phone.prefix listed_by.phone.areacode listed_by.phone.number  \
# 0                    421                      510                   0695
# 1                    945                      510                   1945
#
#   listed_by.badge_type                                listed_by.image_url  \
# 0        Listing Agent  https://photos.zillowstatic.com/fp/ff06d55ae66...
# 1        Listing Agent  https://photos.zillowstatic.com/h_n/IS7y1ewv8u...
#
#    mortgageRates.thirtyYearFixedRate  address.community address.city  \
# 0                              5.987                NaN      Hayward
# 1                              5.987                NaN      Hayward
#
#   address.state  address.neighborhood  address.subdivision  \
# 0            CA                   NaN                  NaN
# 1            CA                   NaN                  NaN
#
#   address.streetAddress address.zipcode  attributionInfo.buyerAgentName  \
# 0  2060 Quail Canyon Ct           94542                             NaN
# 1     2559 Bradford Ave           94545                             NaN
#
#        attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0  bridgeMLS/CCAR/Bay East AOR                                 None
# 1  bridgeMLS/CCAR/Bay East AOR                                 None
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated  attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-08-04 17:30:17                                           NaN
# 1         2024-07-31 16:09:28                                           NaN
#
#       attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0  Community Realty & Investment                             None
# 1       eXp Realty of California                             None
#
#                         attributionInfo.infoString10  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
# 1  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#    attributionInfo.trueStatus  \
# 0                         NaN
# 1                         NaN
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
# 1  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.agentEmail attributionInfo.agentName  \
# 0                       None             David Cerruti
# 1                       None            Michael Sayage
#
#    attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                               NaN              41068657
# 1                               NaN              41068175
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1                        None                          None
#
#   attributionInfo.infoString5  \
# 0                510-421-0695
# 1                510-512-5349
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': 'DRE #01854038', 'memb...
# 1  [{'memberStateLicense': 'DRE #02086703', 'memb...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     510-421-0695                      DRE #01854038
# 1                     510-512-5349                      DRE #02086703
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
# 1  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#    attributionInfo.infoString16  attributionInfo.buyerBrokerageName  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
#
#                        attributionInfo.mlsDisclaimer  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
# 1  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      510-562-5053         2024-08-05 13:00:55
# 1                      888-832-7179         2024-08-05 13:00:55
#
#   resoFacts.hasAttachedProperty  resoFacts.frontageType  \
# 0                         False                     NaN
# 1                         False                     NaN
#
#   resoFacts.poolFeatures                   resoFacts.flooring  \
# 0                 [None]  [Hardwood Flrs Throughout, Parquet]
# 1                 [None]                     [Laminate, Tile]
#
#   resoFacts.accessibilityFeatures resoFacts.hasGarage  \
# 0                            None                True
# 1                            None                True
#
#   resoFacts.hasPetsAllowed  resoFacts.bodyType  resoFacts.topography  \
# 0                     None                 NaN                   NaN
# 1                     None                 NaN                   NaN
#
#    resoFacts.landLeaseExpirationDate resoFacts.hasAdditionalParcels  \
# 0                                NaN                          False
# 1                                NaN                          False
#
#    resoFacts.parkName  resoFacts.taxAssessedValue  \
# 0                 NaN                    889917.0
# 1                 NaN                    665618.0
#
#                             resoFacts.atAGlanceFacts  \
# 0  [{'factValue': 'Single Family Residence', 'fac...
# 1  [{'factValue': 'Single Family Residence', 'fac...
#
#    resoFacts.offerReviewDate resoFacts.horseYN  \
# 0                        NaN              None
# 1                        NaN              None
#
#    resoFacts.belowGradeFinishedArea  \
# 0                               NaN
# 1                               NaN
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': '510-813-1148', 'name': 'NOT LISTED...              Hayward
# 1                                                NaN              Hayward
#
#    resoFacts.mainLevelBathrooms  resoFacts.hasPrivatePool  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
#
#    resoFacts.landLeaseAmount resoFacts.waterSource resoFacts.exteriorFeatures  \
# 0                        NaN              [Public]            [Terraced Down]
# 1                        NaN                  None          [Low Maintenance]
#
#    resoFacts.inclusions resoFacts.hasFireplace resoFacts.gas  \
# 0                   NaN                   True          None
# 1                   NaN                   True          None
#
#   resoFacts.propertyCondition resoFacts.elevationUnits  resoFacts.exclusions  \
# 0                    Existing                     None                   NaN
# 1                    Existing                     None                   NaN
#
#    resoFacts.mainLevelBedrooms  resoFacts.numberOfUnitsVacant  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
#
#    resoFacts.hasWaterfrontView  resoFacts.bathroomsOneQuarter  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
#
#   resoFacts.lotSize  resoFacts.entryLevel  \
# 0        0.34 Acres                   NaN
# 1        5,227 sqft                   NaN
#
#    resoFacts.irrigationWaterRightsAcres  resoFacts.greenWaterConservation  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
#
#    resoFacts.stories resoFacts.livingArea  resoFacts.commonWalls  \
# 0                NaN           2,077 sqft                    NaN
# 1                1.0           1,157 sqft                    NaN
#
#      resoFacts.listingTerms  resoFacts.otherParking resoFacts.associationFee  \
# 0         Cash,Conventional                     NaN            $100 annually
# 1  Cash,Conventional,FHA,VA                     NaN                     None
#
#    resoFacts.marketingType  resoFacts.greenIndoorAirQuality  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
#
#    resoFacts.greenSustainability  resoFacts.livingAreaRangeUnits  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
#
#   resoFacts.associationPhone  resoFacts.greenBuildingVerificationType  \
# 0               510-813-1148                                      NaN
# 1                       None                                      NaN
#
#   resoFacts.hasAttachedGarage  resoFacts.bedrooms  \
# 0                       False                 4.0
# 1                        True                 3.0
#
#   resoFacts.architecturalStyle  resoFacts.listingId  resoFacts.structureType  \
# 0                 Contemporary                  NaN                      NaN
# 1                         None                  NaN                      NaN
#
#                           resoFacts.interiorFeatures  \
# 0  [Bonus/Plus Room, Breakfast Nook, Stone Counte...
# 1                  [Stone Counters, Updated Kitchen]
#
#    resoFacts.horseAmenities  resoFacts.garageParkingCapacity  \
# 0                       NaN                              2.0
# 1                       NaN                              2.0
#
#    resoFacts.developmentStatus resoFacts.lotFeatures resoFacts.roofType  \
# 0                          NaN  [Court, Sloped Down]               None
# 1                          NaN             [Regular]            Shingle
#
#    resoFacts.compensationBasedOn  resoFacts.greenEnergyGeneration  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
#
#    resoFacts.daysOnZillow resoFacts.listAOR  resoFacts.buildingAreaSource  \
# 0                     3.0              None                           NaN
# 1                     6.0              None                           NaN
#
#   resoFacts.elementarySchool  resoFacts.zoningDescription  \
# 0                       None                          NaN
# 1                       None                          NaN
#
#   resoFacts.constructionMaterials resoFacts.fireplaceFeatures  \
# 0                   [Wood Siding]                       [Gas]
# 1                        [Stucco]                      [None]
#
#   resoFacts.hoaFeeTotal                               resoFacts.appliances  \
# 0         $100 annually  [Dishwasher, Electric Range, Disposal, Range, ...
# 1                  None          [Dishwasher, Refrigerator, Dryer, Washer]
#
#    resoFacts.builderModel  resoFacts.bathroomsPartial resoFacts.fencing  \
# 0                     NaN                         NaN              None
# 1                     NaN                         NaN              None
#
#    resoFacts.yearBuiltEffective  resoFacts.waterfrontFeatures  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#    resoFacts.buildingName  resoFacts.attic  resoFacts.petsMaxWeight  \
# 0                     NaN              NaN                      NaN
# 1                     NaN              NaN                      NaN
#
#   resoFacts.specialListingConditions  resoFacts.storiesTotal  \
# 0                           Standard                     NaN
# 1                           Standard                     NaN
#
#    resoFacts.additionalParcelsDescription resoFacts.canRaiseHorses  \
# 0                                     NaN                    False
# 1                                     NaN                    False
#
#   resoFacts.hasLandLease resoFacts.isNewConstruction resoFacts.waterViewYN  \
# 0                  False                       False                  None
# 1                  False                       False                  None
#
#   resoFacts.middleOrJuniorSchool  resoFacts.lotSizeDimensions  \
# 0                           None                          NaN
# 1                           None                          NaN
#
#   resoFacts.associationName  resoFacts.contingency  resoFacts.yearBuilt  \
# 0                NOT LISTED                    NaN               1986.0
# 1                      None                    NaN               1958.0
#
#    resoFacts.waterBodyName resoFacts.virtualTour  resoFacts.bathroomsFull  \
# 0                      NaN                  None                      3.0
# 1                      NaN                  None                      2.0
#
#   resoFacts.greenEnergyEfficient  resoFacts.incomeIncludes  \
# 0                           None                       NaN
# 1                           None                       NaN
#
#    resoFacts.highSchool resoFacts.utilities  resoFacts.totalActualRent  \
# 0                   NaN                None                        NaN
# 1                   NaN                None                        NaN
#
#    resoFacts.parkingCapacity  resoFacts.taxAnnualAmount  \
# 0                        2.0                    10960.0
# 1                        2.0                     8209.0
#
#    resoFacts.subdivisionName resoFacts.windowFeatures  resoFacts.ownership  \
# 0                        NaN                     None                  NaN
# 1                        NaN                     None                  NaN
#
#    resoFacts.woodedArea  resoFacts.middleOrJuniorSchoolDistrict  \
# 0                   NaN                                     NaN
# 1                   NaN                                     NaN
#
#    resoFacts.associationPhone2  resoFacts.spaFeatures  resoFacts.sewer  \
# 0                          NaN                    NaN             None
# 1                          NaN                    NaN  [Private Sewer]
#
#    resoFacts.frontageLength  resoFacts.openParkingCapacity  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
#
#   resoFacts.associationAmenities  resoFacts.roadSurfaceType  \
# 0                        [Other]                        NaN
# 1                           None                        NaN
#
#   resoFacts.hasCooling  resoFacts.propertySubType  \
# 0                 True  [Single Family Residence]
# 1                 True  [Single Family Residence]
#
#    resoFacts.coveredParkingCapacity  resoFacts.foundationArea  \
# 0                               2.0                       NaN
# 1                               2.0                       NaN
#
#   resoFacts.zoning resoFacts.hoaFee  resoFacts.livingAreaRange  \
# 0             None    $100 annually                        NaN
# 1             None             None                        NaN
#
#   resoFacts.hasCarport resoFacts.parkingFeatures  resoFacts.cropsIncludedYN  \
# 0                False      [Garage, Off Street]                        NaN
# 1                False                [Attached]                        NaN
#
#    resoFacts.tenantPays resoFacts.parcelNumber  resoFacts.bathroomsHalf  \
# 0                   NaN              425390661                      0.0
# 1                   NaN                4413597                      0.0
#
#   resoFacts.otherStructures resoFacts.hasView  resoFacts.additionalFeeInfo  \
# 0                      None             False                          NaN
# 1                      None             False                          NaN
#
#        resoFacts.securityFeatures  resoFacts.onMarketDate  \
# 0  [Double Strapped Water Heater]            1.722557e+12
# 1                            None            1.722298e+12
#
#    resoFacts.numberOfUnitsInCommunity resoFacts.hasHomeWarranty  \
# 0                                 NaN                     False
# 1                                 NaN                     False
#
#   resoFacts.basementYN  resoFacts.ownershipType     resoFacts.doorFeatures  \
# 0                 None                      NaN  [Mirrored Closet Door(s)]
# 1                 None                      NaN                       None
#
#                               resoFacts.associations  resoFacts.waterView  \
# 0  [{'feeFrequency': '$100 annually', 'name': 'NO...                  NaN
# 1                                                NaN                  NaN
#
#    resoFacts.aboveGradeFinishedArea            resoFacts.electric  \
# 0                               NaN  [Photovoltaics Seller Owned]
# 1                               NaN                    [No Solar]
#
#   resoFacts.cumulativeDaysOnMarket resoFacts.hasOpenParking  \
# 0                             None                     None
# 1                             None                     None
#
#   resoFacts.hasElectricOnProperty resoFacts.homeType  \
# 0                            None       SingleFamily
# 1                            None       SingleFamily
#
#    resoFacts.isSeniorCommunity  resoFacts.municipality  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
#
#    resoFacts.bathroomsThreeQuarter resoFacts.hasSpa resoFacts.basement  \
# 0                              NaN            False               None
# 1                              NaN            False               None
#
#    resoFacts.associationFee2 resoFacts.cooling resoFacts.hasHeating  \
# 0                        NaN  [Ceiling Fan(s)]                 True
# 1                        NaN  [Ceiling Fan(s)]                 True
#
#    resoFacts.associationName2  resoFacts.hasRentControl  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                               None                     None
# 1                               None                     None
#
#    resoFacts.bathrooms resoFacts.buildingArea resoFacts.furnished  \
# 0                  3.0                  2,077               False
# 1                  2.0                  1,157               False
#
#    resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                   NaN                            None
# 1                   NaN                            None
#
#    resoFacts.bathroomsFloat resoFacts.builderName  \
# 0                       3.0                  None
# 1                       2.0                  None
#
#   resoFacts.highSchoolDistrict  resoFacts.entryLocation  \
# 0                         None                      NaN
# 1                         None                      NaN
#
#   resoFacts.laundryFeatures  resoFacts.buildingFeatures  resoFacts.fireplaces  \
# 0               [In Garage]                         NaN                   1.0
# 1               [In Garage]                         NaN                   1.0
#
#   resoFacts.heating  resoFacts.availabilityDate  \
# 0      [Forced Air]                         NaN
# 1      [Forced Air]                         NaN
#
#    resoFacts.carportParkingCapacity resoFacts.hasAssociation  \
# 0                               NaN                     True
# 1                               NaN                    False
#
#    resoFacts.irrigationWaterRightsYN resoFacts.associationFeeIncludes  \
# 0                                NaN                 [Management Fee]
# 1                                NaN                             None
#
#    resoFacts.leaseTerm resoFacts.levels  resoFacts.pricePerSquareFoot  \
# 0                  NaN      Multi/Split                         481.0
# 1                  NaN        One Story                         713.0
#
#    resoFacts.elevation  resoFacts.communityFeatures listingSubType.is_FSBA  \
# 0                  NaN                          NaN                   True
# 1                  NaN                          NaN                   True
#
#   listingSubType.is_comingSoon listingSubType.is_newHome  \
# 0                        False                     False
# 1                        False                     False
#
#   listingSubType.is_pending listingSubType.is_forAuction  \
# 0                     False                        False
# 1                     False                        False
#
#   listingSubType.is_foreclosure listingSubType.is_bankOwned  \
# 0                         False                       False
# 1                         False                       False
#
#   listingSubType.is_openHouse listingSubType.is_FSBO  \
# 0                       False                  False
# 1                       False                  False
#
#   resoFacts.foundationDetails resoFacts.view listed_by.phone resoFacts.rooms  \
# 0                         NaN            NaN             NaN             NaN
# 1                         NaN            NaN             NaN             NaN
#
#   message
# 0     NaN
# 1     NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.dropna(inplace=True)
# Out:
# <ipython-input-31-142e0213021c>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_z_prop_detail_output.dropna(inplace=True)

# %%
df_z_prop_detail_output.head(20)
# download file
#df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
#files.download('df_z_prop_detail_output.csv')
# Out:
#         streetAddress     city          county zipcode state      price  \
# 1   2559 Bradford Ave  Hayward  Alameda County   94545    CA   824999.0
# 3   1937 Southgate St  Hayward  Alameda County   94545    CA   899000.0
# 6    22238 Victory Dr  Hayward  Alameda County   94541    CA   999999.0
# 7     22864 Amador St  Hayward  Alameda County   94541    CA   849000.0
# 8    26218 Adrian Ave  Hayward  Alameda County   94545    CA   979000.0
# 17    24576 Oneil Ave  Hayward  Alameda County   94544    CA   829000.0
# 25       24207 2nd St  Hayward  Alameda County   94541    CA  1098800.0
# 28  27765 Decatur Way  Hayward  Alameda County   94545    CA   869777.0
# 34   23320 Wilmot Cir  Hayward  Alameda County   94545    CA   844900.0
# 39  27048 Columbia Ct  Hayward  Alameda County   94542    CA  1129000.0
#
#          homeType timeOnZillow  zestimate  rentZestimate  livingArea  \
# 1   SINGLE_FAMILY       6 days   889100.0         3324.0      1157.0
# 3   SINGLE_FAMILY       7 days   970200.0         3418.0      1128.0
# 6   SINGLE_FAMILY       5 days  1066000.0         3552.0      3300.0
# 7   SINGLE_FAMILY       3 days   880400.0         3943.0      1748.0
# 8   SINGLE_FAMILY       3 days  1026900.0         3495.0      1244.0
# 17  SINGLE_FAMILY       3 days   890400.0         3891.0      1358.0
# 25  SINGLE_FAMILY      10 days  1100000.0         4158.0      2009.0
# 28  SINGLE_FAMILY      19 days   882900.0         3815.0      1455.0
# 34  SINGLE_FAMILY      20 days   838400.0         3791.0      1350.0
# 39  SINGLE_FAMILY        1 day  1226400.0         4244.0      1688.0
#
#     bedrooms  bathrooms  yearBuilt  \
# 1        3.0        2.0     1958.0
# 3        3.0        2.0     1956.0
# 6        4.0        2.0     1942.0
# 7        4.0        3.0     2012.0
# 8        3.0        2.0     1960.0
# 17       3.0        2.0        0.0
# 25       3.0        4.0     2020.0
# 28       3.0        2.0     1955.0
# 34       2.0        3.0     2017.0
# 39       3.0        2.0     1979.0
#
#                                           description  \
# 1   Discover this inviting 3-bedroom, 2-bathroom h...
# 3   Welcome to 1937 Southgate St in Hayward, Calif...
# 6   Nestled in the charming Winton Grove neighborh...
# 7   Welcome home to 22864 Amador Street! This beau...
# 8   Welcome to your new home in the charming city ...
# 17  Welcome to your new home! An inviting home per...
# 25  Located in the heart of Hayward, welcome to th...
# 28  Opportunity to own a one story single family f...
# 34  Welcome to your contemporary oasis in the hear...
# 39  It is 3 bed & 2 bath & 2 car garage one story ...
#
#                                          priceHistory  \
# 1   [{'priceChangeRate': 0.4102547008547, 'date': ...
# 3   [{'priceChangeRate': 0.30289855072464, 'date':...
# 6   [{'priceChangeRate': 0, 'date': '2024-07-31', ...
# 7   [{'priceChangeRate': 0.18741258741259, 'date':...
# 8   [{'priceChangeRate': 1.5428571428571, 'date': ...
# 17  [{'priceChangeRate': 0.083660130718954, 'date'...
# 25  [{'priceChangeRate': 0.3003550295858, 'date': ...
# 28  [{'priceChangeRate': 2.6240708333333, 'date': ...
# 34  [{'priceChangeRate': -0.017558139534884, 'date...
# 39  [{'priceChangeRate': 0.61285714285714, 'date':...
#
#                                            taxHistory         zpid
# 1   [{'time': 1691266701349, 'valueIncreaseRate': ...   24977424.0
# 3   [{'time': 1691266707261, 'valueIncreaseRate': ...  111408865.0
# 6   [{'time': 1691266717025, 'valueIncreaseRate': ...   63084259.0
# 7   [{'time': 1691266720140, 'valueIncreaseRate': ...  111393713.0
# 8   [{'time': 1691266723051, 'valueIncreaseRate': ...   24977067.0
# 17  [{'time': 1691266744765, 'valueIncreaseRate': ...   24980982.0
# 25  [{'time': 1691266762821, 'valueIncreaseRate': ...  318985703.0
# 28  [{'time': 1691266770066, 'valueIncreaseRate': ...   24988136.0
# 34  [{'time': 1691266786285, 'valueIncreaseRate': ...  241574913.0
# 39  [{'time': 1691266798869, 'valueIncreaseRate': ...   24903247.0

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
# !rm example.txt
df_z_prop_detail_output['streetAddress'].iloc[0]
# Out:
# '2559 Bradford Ave'

# %%
data = """Name,Address
"""

# %%
for x in range (0,len(df_z_prop_detail_output),1):
  # Step 1: Open the file in write mode
  file = open('example.txt', 'a')

  # Step 2: Write text to the file
  if x==0:
    file.write("Name,Address\n")
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" CA"+"\n")
  else:
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" CA"+"\n")
  # Step 3: Close the file
file.close()

# %%
#!rm ./example.txt
import pandas as pd
data=pd.read_csv('./example.txt')

# %%
df=data

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df
# Out:
#       Name                         Address
# 0  House_0   2559 Bradford Ave; Hayward CA
# 1  House_1   1937 Southgate St; Hayward CA
# 2  House_2    22238 Victory Dr; Hayward CA
# 3  House_3     22864 Amador St; Hayward CA
# 4  House_4    26218 Adrian Ave; Hayward CA
# 5  House_5     24576 Oneil Ave; Hayward CA
# 6  House_6        24207 2nd St; Hayward CA
# 7  House_7   27765 Decatur Way; Hayward CA
# 8  House_8    23320 Wilmot Cir; Hayward CA
# 9  House_9   27048 Columbia Ct; Hayward CA

# %%
df["loc"] = df["Address"].apply(geolocator.geocode)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+2559+Bradford+Ave%3B+Hayward+CA&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+22238+Victory+Dr%3B+Hayward+CA&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+22864+Amador+St%3B+Hayward+CA&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+22864+Amador+St%3B+Hayward+CA&format=json&limit=1
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     538         except (BaseSSLError, OSError) as e:
# --> 539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     540             raise
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     370         if isinstance(err, SocketTimeout):
# --> 371             raise ReadTimeoutError(
#     372                 self, url, f"Read timed out. (read timeout={timeout_value})"
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     874             )
# --> 875             return self.urlopen(
#     876                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     874             )
# --> 875             return self.urlopen(
#     876                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     844
# --> 845             retries = retries.increment(
#     846                 method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     514             reason = error or ResponseError(cause)
# --> 515             raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     516
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=+22864+Amador+St%3B+Hayward+CA&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     481         try:
# --> 482             resp = self.session.get(url, timeout=timeout, headers=headers)
#     483         except Exception as error:
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=+22864+Amador+St%3B+Hayward+CA&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-58-e68086d293c3> in <cell line: 1>()
# ----> 1 df["loc"] = df["Address"].apply(geolocator.geocode)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1287         #  Categorical (GH51645).
#    1288         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289         mapped = obj._map_values(
#    1290             mapper=curried, na_action=action, convert=self.convert_dtype
#    1291         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1812     values = arr.astype(object, copy=False)
#    1813     if na_action is None:
# -> 1814         return lib.map_infer(values, mapper, convert=convert)
#    1815     else:
#    1816         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/local/lib/python3.10/dist-packages/geopy/geocoders/nominatim.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297         return self._call_geocoder(url, callback, timeout=timeout)
#     298
#     299     def reverse(
#
# /usr/local/lib/python3.10/dist-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     366         try:
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#     370                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# /usr/local/lib/python3.10/dist-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     470
#     471     def get_json(self, url, *, timeout, headers):
# --> 472         resp = self._request(url, timeout=timeout, headers=headers)
#     473         try:
#     474             return resp.json()
#
# /usr/local/lib/python3.10/dist-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     492                     raise GeocoderServiceError(message)
#     493                 else:
# --> 494                     raise GeocoderUnavailable(message)
#     495             elif isinstance(error, requests.Timeout):
#     496                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=+22864+Amador+St%3B+Hayward+CA&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-161ceeff2b55> in <cell line: 1>()
# ----> 1 df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'loc'

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ef0584974db4dc17a4d512b745ef25f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ef0584974db4dc17a4d512b745ef25f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ef0584974db4dc17a4d512b745ef25f = L.map(
#                 &quot;map_9ef0584974db4dc17a4d512b745ef25f&quot;,
#                 {
#                     center: [37.83910135419586, -122.13127529727053],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dadf792efe406450007ca5e233f6192a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dadf792efe406450007ca5e233f6192a.addTo(map_9ef0584974db4dc17a4d512b745ef25f);
#
#
#             var marker_cluster_427f64a772e0344f5061844c5cbdf393 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7c3dd7fb9426082da695a1ce78378f95 = L.marker(
#                 [37.837286590700735, -122.1226771637197],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_7dc674f9ba09b06b1e085d96424eed2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0034b9b8e4d9aa332eb67fa6209e331b = $(`&lt;div id=&quot;html_0034b9b8e4d9aa332eb67fa6209e331b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_0&lt;/div&gt;`)[0];
#                 popup_7dc674f9ba09b06b1e085d96424eed2a.setContent(html_0034b9b8e4d9aa332eb67fa6209e331b);
#
#
#
#         marker_7c3dd7fb9426082da695a1ce78378f95.bindPopup(popup_7dc674f9ba09b06b1e085d96424eed2a)
#         ;
#
#
#
#
#             marker_7c3dd7fb9426082da695a1ce78378f95.bindTooltip(
#                 `&lt;div&gt;
#                      House_0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9fa24696897c170b5b5027b8321e9dc = L.marker(
#                 [37.839706651643375, -122.12408733100484],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_f24fed45da39028feaf2fc41c87dd8b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_917d38e260517f4658a0ce241f3a6a9a = $(`&lt;div id=&quot;html_917d38e260517f4658a0ce241f3a6a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_1&lt;/div&gt;`)[0];
#                 popup_f24fed45da39028feaf2fc41c87dd8b5.setContent(html_917d38e260517f4658a0ce241f3a6a9a);
#
#
#
#         marker_c9fa24696897c170b5b5027b8321e9dc.bindPopup(popup_f24fed45da39028feaf2fc41c87dd8b5)
#         ;
#
#
#
#
#             marker_c9fa24696897c170b5b5027b8321e9dc.bindTooltip(
#                 `&lt;div&gt;
#                      House_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f9bf490c9bb7f8f7d919a96fd04ea533 = L.marker(
#                 [37.8394509974858, -122.1231658858972],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_974cc0cdee5063662058614b5eb4bbab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6450d370818498842b129449279af63c = $(`&lt;div id=&quot;html_6450d370818498842b129449279af63c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_2&lt;/div&gt;`)[0];
#                 popup_974cc0cdee5063662058614b5eb4bbab.setContent(html_6450d370818498842b129449279af63c);
#
#
#
#         marker_f9bf490c9bb7f8f7d919a96fd04ea533.bindPopup(popup_974cc0cdee5063662058614b5eb4bbab)
#         ;
#
#
#
#
#             marker_f9bf490c9bb7f8f7d919a96fd04ea533.bindTooltip(
#                 `&lt;div&gt;
#                      House_2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_93a6b824fec71a8da0c1a78cc5ba2c20 = L.marker(
#                 [37.83908824963956, -122.14323471616677],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_6a609123dd6aba35780dc37a32390aa6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_64575bcf561a6bb22d90bd65ba9cdb52 = $(`&lt;

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
