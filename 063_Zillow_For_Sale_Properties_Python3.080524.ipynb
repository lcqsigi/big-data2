# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python3.080524.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'moraga'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Search string: moraga, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Townhomes",
               "minPrice": "800000",
               "maxPrice": "1300000",
               "sqftMin": "1000",
               "bedsMin": "2"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 0,
#    'address': '282 Paseo Bernal, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 1106600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ddadd67bb34e123058e0869cbe765c32-p_e.jpg',
#    'price': 1099000,
#    'detailUrl': '/homedetails/282-Paseo-Bernal-Moraga-CA-94556/18473664_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.12358,
#    'latitude': 37.83651,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18473664',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 5172,
#    'daysOnZillow': 4,
#    'bathrooms': 3,
#    'livingArea': 2044,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 2613.6,
#    'address': '1419 Camino Peral, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/015af83e7748413cd4931e51811eedfa-p_e.jpg',
#    'price': 970000,
#    'detailUrl': '/homedetails/1419-Camino-Peral-Moraga-CA-94556/18473332_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.12409,
#    'latitude': 37.839783,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18473332',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4559,
#    'daysOnZillow': 11,
#    'bathrooms': 3,
#    'livingArea': 1440,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 2613.6,
#    'address': '1479 Camino Peral, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0e032ec432545f06a60d1f71e59a0e96-p_e.jpg',
#    'price': 995000,
#    'detailUrl': '/homedetails/1479-Camino-Peral-Moraga-CA-94556/18473360_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.123055,
#    'latitude': 37.839508,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18473360',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 2,
#    'bathrooms': 3,
#    'livingArea': 1635,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1742.4,
#    'address': '133 Miramonte Dr, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': -20000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2363916d5e23d54c5c0a655ab89b1f24-p_e.jpg',
#    'price': 948000,
#    'detailUrl': '/homedetails/133-Miramonte-Dr-Moraga-CA-94556/18471812_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.143005,
#    'latitude': 37.839252,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18471812',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 4554,
#    'daysOnZillow': 11,
#    'bathrooms': 2,
#    'livingArea': 1514,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 1512,
#    'address': '50 Miramonte Dr, Moraga, CA 94556',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/77410da847a4cfe7e238337f34d47924-p_e.jpg',
#    'price': 949000,
#    'detailUrl': '/homedetails/50-Miramonte-Dr-Moraga-CA-94556/18471528_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -122.14415,
#    'latitude': 37.840096,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '18471528',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 18,
#    'bathrooms': 2,
#    'livingArea': 1436,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 1,
#  'totalResultCount': 5,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 5
# Num of cols: 26
#   dateSold propertyType  lotAreaValue                              address  \
# 0     None    TOWNHOUSE           0.0   282 Paseo Bernal, Moraga, CA 94556
# 1     None    TOWNHOUSE        2613.6  1419 Camino Peral, Moraga, CA 94556
# 2     None    TOWNHOUSE        2613.6  1479 Camino Peral, Moraga, CA 94556
# 3     None    TOWNHOUSE        1742.4   133 Miramonte Dr, Moraga, CA 94556
# 4     None    TOWNHOUSE        1512.0    50 Miramonte Dr, Moraga, CA 94556
#
#   variableData  priceChange  zestimate  \
# 0         None          NaN  1106600.0
# 1         None          NaN        NaN
# 2         None          NaN        NaN
# 3         None     -20000.0        NaN
# 4         None          NaN        NaN
#
#                                               imgSrc    price  \
# 0  https://photos.zillowstatic.com/fp/ddadd67bb34...  1099000
# 1  https://photos.zillowstatic.com/fp/015af83e774...   970000
# 2  https://photos.zillowstatic.com/fp/0e032ec4325...   995000
# 3  https://photos.zillowstatic.com/fp/2363916d5e2...   948000
# 4  https://photos.zillowstatic.com/fp/77410da847a...   949000
#
#                                            detailUrl  bedrooms  \
# 0  /homedetails/282-Paseo-Bernal-Moraga-CA-94556/...         3
# 1  /homedetails/1419-Camino-Peral-Moraga-CA-94556...         3
# 2  /homedetails/1479-Camino-Peral-Moraga-CA-94556...         3
# 3  /homedetails/133-Miramonte-Dr-Moraga-CA-94556/...         3
# 4  /homedetails/50-Miramonte-Dr-Moraga-CA-94556/1...         3
#
#   contingentListingType   longitude   latitude listingStatus      zpid  \
# 0                  None -122.123580  37.836510      FOR_SALE  18473664
# 1                  None -122.124090  37.839783      FOR_SALE  18473332
# 2                  None -122.123055  37.839508      FOR_SALE  18473360
# 3                  None -122.143005  37.839252      FOR_SALE  18471812
# 4                  None -122.144150  37.840096      FOR_SALE  18471528
#
#    rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0         5172.0             4          3        2044     USA      USD
# 1         4559.0            11          3        1440     USA      USD
# 2            NaN             2          3        1635     USA      USD
# 3         4554.0            11          2        1514     USA      USD
# 4            NaN            18          2        1436     USA      USD
#
#   lotAreaUnit  hasImage  listingSubType.is_FSBA listingSubType.is_openHouse
# 0        sqft      True                    True                         NaN
# 1        sqft      True                    True                         NaN
# 2        sqft      True                    True                        True
# 3        sqft      True                    True                         NaN
# 4        sqft      True                    True                         NaN

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['18473664', '18473332', '18473360', '18471812', '18471528']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 5
# Num of cols: 301
#   buildingPermits                                 contact_recipients  \
# 0            None  [{'agent_reason': 1, 'zpro': None, 'recent_sal...
# 1            None  [{'agent_reason': 1, 'zpro': None, 'recent_sal...
#
#    longitude countyFIPS                                             imgSrc  \
# 0 -122.12358      06013  https://photos.zillowstatic.com/fp/ddadd67bb34...
# 1 -122.12409      06013  https://photos.zillowstatic.com/fp/015af83e774...
#
#    livingAreaValue      streetAddress               county  monthlyHoaFee  \
# 0             2044   282 Paseo Bernal  Contra Costa County            680
# 1             1440  1419 Camino Peral  Contra Costa County            450
#
#               timeZone                                         taxHistory  \
# 0  America/Los_Angeles  [{'time': 1691265053543, 'valueIncreaseRate': ...
# 1  America/Los_Angeles  [{'time': 1691265057263, 'valueIncreaseRate': ...
#
#   dateSold  annualHomeownersInsurance state  yearBuilt  \
# 0     None                       4616    CA       1978
# 1     None                       4074    CA       1972
#
#                brokerageName  \
# 0  ValleyVentures Realty Inc
# 1            Abio Properties
#
#                                          description zipcode  \
# 0  A HOMEOWNER'S DREAM COME TRUE !! This UPGRADED...   94556
# 1  Wonderful townhome in the ever-popular Casitas...   94556
#
#                                          nearbyHomes  \
# 0  [{'livingArea': 2044, 'livingAreaValue': 2044,...
# 1  [{'livingArea': 1126, 'livingAreaValue': 1126,...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': 0.036792452830189, 'date'...
# 1  [{'priceChangeRate': 0.87802516940949, 'date':...
#
#                                              schools  rentZestimate    city  \
# 0  [{'link': 'https://www.greatschools.org/califo...         5172.0  Moraga
# 1  [{'link': 'https://www.greatschools.org/califo...         4559.0  Moraga
#
#   providerListingID currency listingProvider  propertyTaxRate  cityId  \
# 0              None      USD            None             1.16   32942
# 1              None      USD            None             1.16   32942
#
#   timeOnZillow                                                url  zestimate  \
# 0       4 days  /homedetails/282-Paseo-Bernal-Moraga-CA-94556/...  1106600.0
# 1      11 days  /homedetails/1419-Camino-Peral-Moraga-CA-94556...        NaN
#
#        zpid  countyId brokerId livingAreaUnits  pageViewCount  bathrooms  \
# 0  18473664      3159     None            sqft            603          3
# 1  18473332      3159     None            sqft            886          3
#
#   building  stateId zestimateLowPercent comingSoonOnMarketDate homeStatus  \
# 0     None        9                   5                   None   FOR_SALE
# 1     None        9                None                   None   FOR_SALE
#
#   homeFacts  datePosted  bedrooms propertyTypeDimension    price   latitude  \
# 0      None  2024-08-01         3             Townhouse  1099000  37.836510
# 1      None  2024-07-25         3             Townhouse   970000  37.839783
#
#    favoriteCount zestimateHighPercent     mlsid isListedByOwner  livingArea  \
# 0             28                    5  41068361            None        2044
# 1             43                 None  41067682            None        1440
#
#   buildingId country   homeType solarPotential contingentListingType  \
# 0       None     USA  TOWNHOUSE           None                  None
# 1       None     USA  TOWNHOUSE           None                  None
#
#    listed_by.agent_reason  listed_by.zpro  listed_by.recent_sales  \
# 0                       3           False                       0
# 1                       3           False                       0
#
#             listed_by.zuid  listed_by.review_count listed_by.display_name  \
# 0  X1-ZUtxuv5jqcwu89_61q4w                       2       Sneader Sequeira
# 1  X1-ZUz65bsy4bzp55_2ca41                      22           Larry Jacobs
#
#                                listed_by.profile_url  \
# 0  https://www.zillow.com/profile/zuser2020030811...
# 1      https://www.zillow.com/profile/kressandlarry/
#
#      listed_by.business_name  listed_by.rating_average listed_by.phone.prefix  \
# 0  ValleyVentures Realty Inc                       4.8                    512
# 1            Abio Properties                       5.0                    788
#
#   listed_by.phone.areacode listed_by.phone.number listed_by.badge_type  \
# 0                      412                   3041        Listing Agent
# 1                      925                   1362        Listing Agent
#
#                                  listed_by.image_url  \
# 0  https://photos.zillowstatic.com/h_n/ISr5dfxf7v...
# 1  https://photos.zillowstatic.com/h_n/ISf8bqa6yq...
#
#    mortgageRates.thirtyYearFixedRate address.community address.city  \
# 0                              5.987              None       Moraga
# 1                              5.987              None       Moraga
#
#   address.state address.neighborhood address.subdivision  \
# 0            CA                 None                None
# 1            CA                 None                None
#
#   address.streetAddress address.zipcode attributionInfo.buyerAgentName  \
# 0      282 Paseo Bernal           94556                           None
# 1     1419 Camino Peral           94556                           None
#
#        attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0  bridgeMLS/CCAR/Bay East AOR                                 None
# 1  bridgeMLS/CCAR/Bay East AOR                        DRE #01465617
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-08-05 06:33:33                                         None
# 1         2024-08-04 10:38:57                                         None
#
#   attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0  ValleyVentures Realty Inc                             None
# 1            Abio Properties                             None
#
#                         attributionInfo.infoString10  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
# 1  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.trueStatus  \
# 0                       None
# 1                       None
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
# 1  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.agentEmail attributionInfo.agentName  \
# 0                       None          Sneader Sequeira
# 1                       None              Larry Jacobs
#
#   attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                             None              41068361
# 1                             None              41067682
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1                 Kress Hauri                  925-899-5739
#
#   attributionInfo.infoString5  \
# 0                412-512-3041
# 1                925-788-1362
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': 'DRE #02119534', 'memb...
# 1  [{'memberStateLicense': 'DRE #01495118', 'memb...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     412-512-3041                      DRE #02119534
# 1                     925-788-1362                      DRE #01495118
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/542acdc3b2c...
# 1  https://photos.zillowstatic.com/fp/542acdc3b2c...
#
#   attributionInfo.infoString16 attributionInfo.buyerBrokerageName  \
# 0                         None                               None
# 1                         None                               None
#
#                        attributionInfo.mlsDisclaimer  \
# 0  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
# 1  Bay East 2024. CCAR 2024. bridgeMLS 2024. Info...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      925-413-0269         2024-08-05 12:30:42
# 1                      925-310-4636         2024-08-05 12:30:42
#
#    resoFacts.hasAttachedProperty resoFacts.frontageType  \
# 0                          False                   None
# 1                          False                   None
#
#                    resoFacts.poolFeatures           resoFacts.flooring  \
# 0                  [In Ground, Community]             [Hardwood, Tile]
# 1  [In Ground, Pool/Spa Combo, Community]  [Tile, Vinyl, Carpet, Wood]
#
#   resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0                            None                 True
# 1                            None                 True
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     None               None                 None
# 1                     None               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
# 1                              None                           False
#
#   resoFacts.parkName  resoFacts.taxAssessedValue  \
# 0               None                     1000683
# 1               None                      691718
#
#                             resoFacts.atAGlanceFacts  \
# 0  [{'factValue': 'Townhouse', 'factLabel': 'Type...
# 1  [{'factValue': 'Townhouse', 'factLabel': 'Type...
#
#   resoFacts.offerReviewDate resoFacts.horseYN      resoFacts.view  \
# 0                      None              None  [Hills, Panoramic]
# 1                      None              None                 NaN
#
#   resoFacts.belowGradeFinishedArea  \
# 0                             None
# 1                             None
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': '925-743-3080', 'name': 'PASEO DE M...               Moraga
# 1  [{'phone': '925-743-3080', 'name': 'NONE', 'fe...               Moraga
#
#   resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool  \
# 0                         None                     None
# 1                         None                     None
#
#   resoFacts.landLeaseAmount resoFacts.waterSource  \
# 0                      None              [Public]
# 1                      None              [Public]
#
#              resoFacts.exteriorFeatures resoFacts.inclusions  \
# 0  [Back Yard, Front Yard, Garden/Play]                 None
# 1                                   NaN                 None
#
#    resoFacts.hasFireplace resoFacts.gas resoFacts.propertyCondition  \
# 0                    True          None                    Existing
# 1                    True          None                    Existing
#
#   resoFacts.elevationUnits resoFacts.exclusions resoFacts.mainLevelBedrooms  \
# 0                     None                 None                        None
# 1                     None                 None                        None
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView  \
# 0                          None                        None
# 1                          None                        None
#
#    resoFacts.bathroomsOneQuarter resoFacts.lotSize resoFacts.entryLevel  \
# 0                            NaN              None                 None
# 1                            NaN        2,613 sqft                 None
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.greenWaterConservation  \
# 0                                 None                             None
# 1                                 None                             None
#
#    resoFacts.stories resoFacts.livingArea resoFacts.commonWalls  \
# 0                  2           2,044 sqft                  None
# 1                  2           1,440 sqft                  None
#
#   resoFacts.listingTerms resoFacts.otherParking resoFacts.associationFee  \
# 0      Cash,Conventional                   None             $680 monthly
# 1      Cash,Conventional                   None             $450 monthly
#
#   resoFacts.marketingType resoFacts.greenIndoorAirQuality  \
# 0                    None                            None
# 1                    None                            None
#
#   resoFacts.greenSustainability resoFacts.livingAreaRangeUnits  \
# 0                          None                           None
# 1                          None                           None
#
#   resoFacts.associationPhone resoFacts.greenBuildingVerificationType  \
# 0               925-743-3080                                    None
# 1               925-743-3080                                    None
#
#   resoFacts.hasAttachedGarage  resoFacts.bedrooms  \
# 0                       False                   3
# 1                       False                   3
#
#   resoFacts.architecturalStyle resoFacts.listingId resoFacts.structureType  \
# 0                      Spanish                None                    None
# 1                 Contemporary                None                    None
#
#                           resoFacts.interiorFeatures resoFacts.horseAmenities  \
# 0     [Dining Area, Stone Counters, Updated Kitchen]                     None
# 1  [Dining Area, Counter - Solid Surface, Eat-in ...                     None
#
#    resoFacts.garageParkingCapacity resoFacts.developmentStatus  \
# 0                                2                        None
# 1                                2                        None
#
#                                resoFacts.lotFeatures resoFacts.roofType  \
# 0  [Level, Secluded, Landscape Back, Landscape Fr...               None
# 1                                          [Regular]               None
#
#   resoFacts.compensationBasedOn resoFacts.greenEnergyGeneration  \
# 0                          None                            None
# 1                          None                            None
#
#    resoFacts.daysOnZillow resoFacts.listAOR resoFacts.buildingAreaSource  \
# 0                       4              None                         None
# 1                      11              None                         None
#
#   resoFacts.elementarySchool resoFacts.zoningDescription  \
# 0                       None                        None
# 1                       None                        None
#
#   resoFacts.constructionMaterials resoFacts.fireplaceFeatures  \
# 0               [Siding - Stucco]               [Living Room]
# 1               [Siding - Stucco]               [Living Room]
#
#   resoFacts.hoaFeeTotal                               resoFacts.appliances  \
# 0          $680 monthly  [Dishwasher, Free-Standing Range, Refrigerator...
# 1          $450 monthly  [Dishwasher, Disposal, Free-Standing Range, Re...
#
#   resoFacts.builderModel resoFacts.bathroomsPartial resoFacts.fencing  \
# 0                   None                       None              None
# 1                   None                       None            Fenced
#
#   resoFacts.yearBuiltEffective resoFacts.waterfrontFeatures  \
# 0                         None                         None
# 1                         None                         None
#
#   resoFacts.buildingName resoFacts.attic resoFacts.petsMaxWeight  \
# 0                   None            None                    None
# 1                   None            None                    None
#
#   resoFacts.specialListingConditions resoFacts.storiesTotal  \
# 0                           Standard                   None
# 1                           Standard                   None
#
#   resoFacts.additionalParcelsDescription  resoFacts.canRaiseHorses  \
# 0                                   None                     False
# 1                                   None                     False
#
#    resoFacts.hasLandLease resoFacts.isNewConstruction resoFacts.waterViewYN  \
# 0                   False                       False                 False
# 1                   False                       False                  None
#
#   resoFacts.middleOrJuniorSchool resoFacts.lotSizeDimensions  \
# 0                           None                        None
# 1                           None                        None
#
#   resoFacts.associationName resoFacts.contingency  resoFacts.yearBuilt  \
# 0           PASEO DE MORAGA                  None                 1978
# 1                      NONE                  None                 1972
#
#   resoFacts.waterBodyName                           resoFacts.virtualTour  \
# 0                    None  https://my.matterport.com/show/?m=6WS4sjaAb9v&
# 1                    None                                            None
#
#    resoFacts.bathroomsFull resoFacts.greenEnergyEfficient  \
# 0                        2                           None
# 1                        2                           None
#
#   resoFacts.incomeIncludes resoFacts.highSchool resoFacts.utilities  \
# 0                     None                 None                None
# 1                     None                 None                None
#
#    resoFacts.totalActualRent  resoFacts.parkingCapacity  \
# 0                        NaN                          2
# 1                        NaN                          2
#
#    resoFacts.taxAnnualAmount resoFacts.subdivisionName  \
# 0                      12505                      None
# 1                       9208                      None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0                     None                None                 None
# 1                     None                None                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                                   None                        None
# 1                                   None                        None
#
#   resoFacts.spaFeatures resoFacts.sewer resoFacts.frontageLength  \
# 0                  None  [Public Sewer]                     None
# 1                  None  [Public Sewer]                     None
#
#    resoFacts.openParkingCapacity              resoFacts.associationAmenities  \
# 0                            NaN  [Greenbelt, Pool, Guest Parking, Trail(s)]
# 1                            NaN   [Clubhouse, Greenbelt, Pool, Spa/Hot Tub]
#
#   resoFacts.roadSurfaceType  resoFacts.hasCooling resoFacts.propertySubType  \
# 0                      None                  True               [Townhouse]
# 1                      None                  True               [Townhouse]
#
#    resoFacts.coveredParkingCapacity resoFacts.foundationArea resoFacts.zoning  \
# 0                                 2                     None             None
# 1                                 2                     None             None
#
#   resoFacts.hoaFee resoFacts.livingAreaRange  resoFacts.hasCarport  \
# 0     $680 monthly                      None                 False
# 1     $450 monthly                      None                 False
#
#                            resoFacts.parkingFeatures  \
# 0                        [Detached, Guest, Enclosed]
# 1  [Detached, Off Street, Garage Faces Rear, Gara...
#
#   resoFacts.cropsIncludedYN resoFacts.tenantPays resoFacts.parcelNumber  \
# 0                      None                 None             2585610500
# 1                      None                 None             2584400507
#
#    resoFacts.bathroomsHalf resoFacts.otherStructures  resoFacts.hasView  \
# 0                        1                      None               True
# 1                        1                      None              False
#
#   resoFacts.additionalFeeInfo  \
# 0                        None
# 1                        None
#
#                          resoFacts.securityFeatures  resoFacts.onMarketDate  \
# 0  [Carbon Monoxide Detector(s), Smoke Detector(s)]           1722470400000
# 1                                              None           1721865600000
#
#    resoFacts.numberOfUnitsInCommunity  resoFacts.hasHomeWarranty  \
# 0                                  88                      False
# 1                                 107                      False
#
#   resoFacts.basementYN resoFacts.ownershipType resoFacts.doorFeatures  \
# 0                 None                    None                   None
# 1                 None                    None                   None
#
#                               resoFacts.associations resoFacts.waterView  \
# 0  [{'feeFrequency': '$680 monthly', 'name': 'PAS...                None
# 1  [{'feeFrequency': '$450 monthly', 'name': 'NON...                None
#
#   resoFacts.aboveGradeFinishedArea resoFacts.electric  \
# 0                             None         [No Solar]
# 1                             None         [No Solar]
#
#   resoFacts.cumulativeDaysOnMarket resoFacts.hasOpenParking  \
# 0                             None                     None
# 1                             None                     None
#
#   resoFacts.hasElectricOnProperty resoFacts.homeType  \
# 0                            None          Townhouse
# 1                            None          Townhouse
#
#   resoFacts.isSeniorCommunity resoFacts.municipality  \
# 0                        None                   None
# 1                        None                   None
#
#    resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa resoFacts.basement  \
# 0                              NaN             False               None
# 1                              NaN              True        Crawl Space
#
#   resoFacts.associationFee2 resoFacts.cooling  resoFacts.hasHeating  \
# 0                      None     [Central Air]                  True
# 1                      None     [Central Air]                  True
#
#   resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                       None                     None
# 1                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                               None                     None
# 1                               None                     None
#
#    resoFacts.bathrooms resoFacts.buildingArea  resoFacts.furnished  \
# 0                    3                  2,044                False
# 1                    3                  1,440                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                            None
# 1                 None                            None
#
#    resoFacts.bathroomsFloat resoFacts.builderName  \
# 0                         3                  None
# 1                         3                  None
#
#   resoFacts.highSchoolDistrict resoFacts.entryLocation  \
# 0                         None                    None
# 1      Acalanes (925) 280-3900                    None
#
#        resoFacts.laundryFeatures resoFacts.buildingFeatures  \
# 0  [Dryer, Laundry Room, Washer]                       None
# 1               [Laundry Closet]                       None
#
#    resoFacts.fireplaces resoFacts.heating resoFacts.availabilityDate  \
# 0                     1      [Forced Air]                       None
# 1                     1      [Forced Air]                       None
#
#    resoFacts.carportParkingCapacity resoFacts.hasAssociation  \
# 0                               NaN                     True
# 1                               NaN                     True
#
#   resoFacts.irrigationWaterRightsYN  \
# 0                              None
# 1                              None
#
#                     resoFacts.associationFeeIncludes resoFacts.leaseTerm  \
# 0  [Common Area Maint, Exterior Maintenance, Mana...                None
# 1  [Common Area Maint, Hazard Insurance, Manageme...                None
#
#   resoFacts.levels  resoFacts.pricePerSquareFoot  resoFacts.elevation  \
# 0        Two Story                           538                  NaN
# 1    Two Story,Two                           674                  NaN
#
#   resoFacts.communityFeatures  listingSubType.is_FSBA  \
# 0                        None                    True
# 1                        None                    True
#
#    listingSubType.is_comingSoon  listingSubType.is_newHome  \
# 0                         False                      False
# 1                         False                      False
#
#    listingSubType.is_pending  listingSubType.is_forAuction  \
# 0                      False                         False
# 1                      False                         False
#
#    listingSubType.is_foreclosure  listingSubType.is_bankOwned  \
# 0                          False                        False
# 1                          False                        False
#
#    listingSubType.is_openHouse  listingSubType.is_FSBO  \
# 0                        False                   False
# 1                        False                   False
#
#   resoFacts.foundationDetails openHouseSchedule listed_by.phone  \
# 0                         NaN               NaN             NaN
# 1                    [Raised]               NaN             NaN
#
#   resoFacts.rooms
# 0             NaN
# 1             NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#        streetAddress    city               county zipcode state    price  \
# 0   282 Paseo Bernal  Moraga  Contra Costa County   94556    CA  1099000
# 1  1419 Camino Peral  Moraga  Contra Costa County   94556    CA   970000
# 2  1479 Camino Peral  Moraga  Contra Costa County   94556    CA   995000
# 3   133 Miramonte Dr  Moraga  Contra Costa County   94556    CA   948000
# 4    50 Miramonte Dr  Moraga  Contra Costa County   94556    CA   949000
#
#     homeType timeOnZillow  zestimate  rentZestimate  livingArea  bedrooms  \
# 0  TOWNHOUSE       4 days  1106600.0         5172.0        2044         3
# 1  TOWNHOUSE      11 days        NaN         4559.0        1440         3
# 2  TOWNHOUSE       2 days        NaN            NaN        1635         3
# 3  TOWNHOUSE      11 days        NaN         4554.0        1514         3
# 4  TOWNHOUSE      18 days        NaN            NaN        1436         3
#
#    bathrooms  yearBuilt                                        description  \
# 0          3       1978  A HOMEOWNER'S DREAM COME TRUE !! This UPGRADED...
# 1          3       1972  Wonderful townhome in the ever-popular Casitas...
# 2          3       1973  Open House Sunday August 4 from 12-3pm and Tue...
# 3          2       1965  Newly remodeled townhouse nestled by Moraga Co...
# 4          2       1964  Welcome to this charming townhouse located in ...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': 0.036792452830189, 'date'...
# 1  [{'priceChangeRate': 0.87802516940949, 'date':...
# 2  [{'priceChangeRate': 0, 'date': '2024-08-03', ...
# 3  [{'priceChangeRate': -0.020661157024793, 'date...
# 4  [{'priceChangeRate': 0.79056603773585, 'date':...
#
#                                           taxHistory      zpid
# 0  [{'time': 1691265053543, 'valueIncreaseRate': ...  18473664
# 1  [{'time': 1691265057263, 'valueIncreaseRate': ...  18473332
# 2  [{'time': 1691265060136, 'valueIncreaseRate': ...  18473360
# 3  [{'time': 1691265063279, 'valueIncreaseRate': ...  18471812
# 4  [{'time': 1691265066576, 'valueIncreaseRate': ...  18471528

# %%
# download file
#df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
#files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
df_z_prop_detail_output['streetAddress'].iloc[0]
# Out:
# '282 Paseo Bernal'

# %%
data = """Name,Address
"""

# %%
for x in range (0,len(df_z_prop_detail_output),1):
  # Step 1: Open the file in write mode
  file = open('example.txt', 'a')

  # Step 2: Write text to the file
  if x==0:
    file.write("Name,Address\n")
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" CA"+"\n")
  else:
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" CA"+"\n")
  # Step 3: Close the file
file.close()

# %%
#!rm ./example.txt
import pandas as pd
data=pd.read_csv('./example.txt')

# %%
df=data

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df
# Out:
#       Name                        Address
# 0  House_0    282 Paseo Bernal; Moraga CA
# 1  House_1   1419 Camino Peral; Moraga CA
# 2  House_2   1479 Camino Peral; Moraga CA
# 3  House_3    133 Miramonte Dr; Moraga CA
# 4  House_4     50 Miramonte Dr; Moraga CA

# %%
df["loc"] = df["Address"].apply(geolocator.geocode)

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ef0584974db4dc17a4d512b745ef25f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ef0584974db4dc17a4d512b745ef25f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ef0584974db4dc17a4d512b745ef25f = L.map(
#                 &quot;map_9ef0584974db4dc17a4d512b745ef25f&quot;,
#                 {
#                     center: [37.83910135419586, -122.13127529727053],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dadf792efe406450007ca5e233f6192a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dadf792efe406450007ca5e233f6192a.addTo(map_9ef0584974db4dc17a4d512b745ef25f);
#
#
#             var marker_cluster_427f64a772e0344f5061844c5cbdf393 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_7c3dd7fb9426082da695a1ce78378f95 = L.marker(
#                 [37.837286590700735, -122.1226771637197],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_7dc674f9ba09b06b1e085d96424eed2a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0034b9b8e4d9aa332eb67fa6209e331b = $(`&lt;div id=&quot;html_0034b9b8e4d9aa332eb67fa6209e331b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_0&lt;/div&gt;`)[0];
#                 popup_7dc674f9ba09b06b1e085d96424eed2a.setContent(html_0034b9b8e4d9aa332eb67fa6209e331b);
#
#
#
#         marker_7c3dd7fb9426082da695a1ce78378f95.bindPopup(popup_7dc674f9ba09b06b1e085d96424eed2a)
#         ;
#
#
#
#
#             marker_7c3dd7fb9426082da695a1ce78378f95.bindTooltip(
#                 `&lt;div&gt;
#                      House_0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9fa24696897c170b5b5027b8321e9dc = L.marker(
#                 [37.839706651643375, -122.12408733100484],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_f24fed45da39028feaf2fc41c87dd8b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_917d38e260517f4658a0ce241f3a6a9a = $(`&lt;div id=&quot;html_917d38e260517f4658a0ce241f3a6a9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_1&lt;/div&gt;`)[0];
#                 popup_f24fed45da39028feaf2fc41c87dd8b5.setContent(html_917d38e260517f4658a0ce241f3a6a9a);
#
#
#
#         marker_c9fa24696897c170b5b5027b8321e9dc.bindPopup(popup_f24fed45da39028feaf2fc41c87dd8b5)
#         ;
#
#
#
#
#             marker_c9fa24696897c170b5b5027b8321e9dc.bindTooltip(
#                 `&lt;div&gt;
#                      House_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f9bf490c9bb7f8f7d919a96fd04ea533 = L.marker(
#                 [37.8394509974858, -122.1231658858972],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_974cc0cdee5063662058614b5eb4bbab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6450d370818498842b129449279af63c = $(`&lt;div id=&quot;html_6450d370818498842b129449279af63c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_2&lt;/div&gt;`)[0];
#                 popup_974cc0cdee5063662058614b5eb4bbab.setContent(html_6450d370818498842b129449279af63c);
#
#
#
#         marker_f9bf490c9bb7f8f7d919a96fd04ea533.bindPopup(popup_974cc0cdee5063662058614b5eb4bbab)
#         ;
#
#
#
#
#             marker_f9bf490c9bb7f8f7d919a96fd04ea533.bindTooltip(
#                 `&lt;div&gt;
#                      House_2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_93a6b824fec71a8da0c1a78cc5ba2c20 = L.marker(
#                 [37.83908824963956, -122.14323471616677],
#                 {}
#             ).addTo(marker_cluster_427f64a772e0344f5061844c5cbdf393);
#
#
#         var popup_6a609123dd6aba35780dc37a32390aa6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_64575bcf561a6bb22d90bd65ba9cdb52 = $(`&lt;

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
