# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python3.092324.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'hayward'
state = 'ca'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: hayward, ca

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring1 = {
               "location": "94611",
               "home_type":"Single_Family",
               "minPrice": "800000",
               "maxPrice": "1150000",
               "sqftMin": "1500",
               "bedsMin": "3"
               }

querystring2 = {
               "location": "94605",
               "home_type":"Single_Family",
               "minPrice": "800000",
               "maxPrice": "1150000",
               "sqftMin": "1500",
               "bedsMin": "3"
               }

querystring3 = {
               "location": "94619",
               "home_type":"Single_Family",
               "minPrice": "800000",
               "maxPrice": "1150000",
               "sqftMin": "1500",
               "bedsMin": "3"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp1 = requests.request("GET", url, headers=headers, params=querystring1)
z_for_sale_resp2 = requests.request("GET", url, headers=headers, params=querystring2)
z_for_sale_resp3 = requests.request("GET", url, headers=headers, params=querystring3)

# transform to json
z_for_sale_resp_json1 = z_for_sale_resp1.json()
z_for_sale_resp_json2 = z_for_sale_resp2.json()
z_for_sale_resp_json3 = z_for_sale_resp3.json()

# %%
len(z_for_sale_resp_json1.get('props', []))
# Out:
# 12

# %%
# view data
df_z_for_sale1 = pd.json_normalize(data=z_for_sale_resp_json1['props'])
df_z_for_sale2 = pd.json_normalize(data=z_for_sale_resp_json2['props'])
df_z_for_sale3 = pd.json_normalize(data=z_for_sale_resp_json3['props'])

df_z_for_sale = pd.concat([df_z_for_sale1,df_z_for_sale2,df_z_for_sale3], ignore_index=True)

print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
#df_z_for_sale.head(50)
# Out:
# Num of rows: 53
# Num of cols: 29

# %%
# download file (if needed)
df_z_for_sale=df_z_for_sale.sort_values('daysOnZillow')
df_z_for_sale.to_csv('df_z_for_sale.csv')
files.download('df_z_for_sale.csv')

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df=df_z_for_sale

# %%
df["loc"] = df['address'].apply(geolocator.geocode)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3115+Harrison+St%2C+Oakland%2C+CA+94611&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=9810+Thermal+St%2C+Oakland%2C+CA+94605&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2232+83rd+Ave%2C+Oakland%2C+CA+94605&format=json&limit=1

# %%
df.dropna(subset=['loc'],inplace=True)

# %%
df["price2"] = df['price'].apply(lambda x: f'{x/10**6:.1f}M')

# %%
#df['Index'] = str(df.reset_index().index)
#df = df.sort_values('daysOnZillow')
df['Index'] = df.reset_index().index.astype(str)

# %%
df["address_price"] = df['Index'] + ', ' + df['address'] + ', ' + df['price2']

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)

# Custom HTML template for the tooltip
tooltip_html = '''
<div class="tooltip"><input type="text" value="{text}" readonly onclick="this.select(); document.execCommand('copy');"><button onclick="navigator.clipboard.writeText('{text}');">Copy</button></div>
'''

# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                  tooltip=r['address_price'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa10837c24fb5bb2ab3986cb366bd470 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa10837c24fb5bb2ab3986cb366bd470&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa10837c24fb5bb2ab3986cb366bd470 = L.map(
#                 &quot;map_aa10837c24fb5bb2ab3986cb366bd470&quot;,
#                 {
#                     center: [37.785336802512276, -122.17969843267971],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_133877b02ed3801c4a524dc8557a81a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_133877b02ed3801c4a524dc8557a81a9.addTo(map_aa10837c24fb5bb2ab3986cb366bd470);
#
#
#             var marker_cluster_8be75ae7550de5026f1e1298a7083ab4 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_112fc5b80d24a3b7b34ff4b01e2f6ece = L.marker(
#                 [37.84195695, -122.21083382112457],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_112fc5b80d24a3b7b34ff4b01e2f6ece.bindTooltip(
#                 `&lt;div&gt;
#                      0, 6206 Valley View Rd, Oakland, CA 94611, 0.9M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fcee41213239126704c3ea64e366f37b = L.marker(
#                 [37.8402173, -122.2073642704905],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_fcee41213239126704c3ea64e366f37b.bindTooltip(
#                 `&lt;div&gt;
#                      1, 1738 Indian Way, Oakland, CA 94611, 1.1M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6d64c688160ee5f4c13ff709848df1e2 = L.marker(
#                 [37.8178161, -122.2569991],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_6d64c688160ee5f4c13ff709848df1e2.bindTooltip(
#                 `&lt;div&gt;
#                      2, 3115 Harrison St, Oakland, CA 94611, 0.9M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_34bd1e75fa665d00a24a6ea62d24dd0b = L.marker(
#                 [37.8316814, -122.19155820104427],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_34bd1e75fa665d00a24a6ea62d24dd0b.bindTooltip(
#                 `&lt;div&gt;
#                      3, 6684 Banning Dr, Oakland, CA 94611, 1.0M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2af884cc33cee01380c255d89aa8d206 = L.marker(
#                 [37.82131785, -122.25378656433486],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_2af884cc33cee01380c255d89aa8d206.bindTooltip(
#                 `&lt;div&gt;
#                      4, 134 Moss Ave, Oakland, CA 94611, 1.0M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_55f3f4d93fd233d6ee5fd0dc0a835de7 = L.marker(
#                 [37.83576495, -122.18586692939164],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_55f3f4d93fd233d6ee5fd0dc0a835de7.bindTooltip(
#                 `&lt;div&gt;
#                      5, 8040 Shepherd Canyon Rd, Oakland, CA 94611, 1.0M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_176410dc05ac221a852c3888515ea26d = L.marker(
#                 [37.830924350000004, -122.25305057518327],
#                 {}
#             ).addTo(marker_cluster_8be75ae7550de5026f1e1298a7083ab4);
#
#
#             marker_176410dc05ac221a852c3888515ea26d.bindTooltip(
#                 `&lt;div&gt;
#                      6, 4250 Terrace St, Oakland, CA 94611, 1.0M
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c142dcf518c447120e32f2c2fe319898 = L.marker(
#                 [37.831454550000004, -122.19224751367287],

# %%
df.iloc[19,:]
# Out:
# dateSold                                                                      None
# propertyType                                                         SINGLE_FAMILY
# lotAreaValue                                                               6272.64
# address                                      3487 Margarita Ave, Oakland, CA 94605
# variableData                                                                  None
# priceChange                                                               -24000.0
# zestimate                                                                      NaN
# imgSrc                           https://photos.zillowstatic.com/fp/356565ac68c...
# price                                                                       875000
# detailUrl                        /homedetails/3487-Margarita-Ave-Oakland-CA-946...
# bedrooms                                                                         3
# contingentListingType                                                         None
# longitude                                                              -122.150154
# latitude                                                                 37.758602
# listingStatus                                                             FOR_SALE
# zpid                                                                      24799995
# rentZestimate                                                               3846.0
# daysOnZillow                                                                    59
# bathrooms                                                                        2
# livingArea                                                                    1608
# country                                                                        USA
# currency                                                                       USD
# lotAreaUnit                                                                   sqft
# hasImage                                                                      True
# listingSubType.is_FSBA                                                        True
# listingSubType.is_openHouse                                                    NaN
# listingSubType.is_foreclosure                                                  NaN
# listingSubType.is_bankOwned                                                    NaN
# listingSubType.is_forAuction                                                   NaN
# loc                              (3487, Margarita Avenue, Oakland, Alameda Coun...
# price2                                                                        0.9M
# Index                                                                           19
# address_price                      19, 3487 Margarita Ave, Oakland, CA 94605, 0.9M
# point                                       (37.7585828, -122.15016413879542, 0.0)
# lat                                                                      37.758583
# lon                                                                    -122.150164
# altitude                                                                       0.0
# Name: 19, dtype: object

# %%
df.iloc[46,:]
# Out:
# dateSold                                                                      None
# propertyType                                                         SINGLE_FAMILY
# lotAreaValue                                                                5227.2
# address                                           4433 Fair Ave, Oakland, CA 94619
# variableData                                                                  None
# priceChange                                                                    NaN
# zestimate                                                                      NaN
# imgSrc                           https://photos.zillowstatic.com/fp/0c5d3d7bb90...
# price                                                                       995000
# detailUrl                        /homedetails/4433-Fair-Ave-Oakland-CA-94619/24...
# bedrooms                                                                         4
# contingentListingType                                                         None
# longitude                                                               -122.18598
# latitude                                                                 37.790318
# listingStatus                                                             FOR_SALE
# zpid                                                                      24776210
# rentZestimate                                                                  NaN
# daysOnZillow                                                                    39
# bathrooms                                                                        3
# livingArea                                                                    1528
# country                                                                        USA
# currency                                                                       USD
# lotAreaUnit                                                                   sqft
# hasImage                                                                      True
# listingSubType.is_FSBA                                                        True
# listingSubType.is_openHouse                                                    NaN
# listingSubType.is_foreclosure                                                  NaN
# listingSubType.is_bankOwned                                                    NaN
# listingSubType.is_forAuction                                                   NaN
# loc                              (4433, Fair Avenue, Oakland, Alameda County, C...
# price2                                                                        1.0M
# Index                                                                           46
# address_price                           46, 4433 Fair Ave, Oakland, CA 94619, 1.0M
# point                               (37.790305000000004, -122.18597580275642, 0.0)
# lat                                                                      37.790305
# lon                                                                    -122.185976
# altitude                                                                       0.0
# Name: 46, dtype: object

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
