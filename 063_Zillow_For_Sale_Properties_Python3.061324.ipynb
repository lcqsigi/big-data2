# %% [markdown]
# <a href="https://colab.research.google.com/github/lcqsigi/big-data2/blob/main/063_Zillow_For_Sale_Properties_Python3.061324.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/' # optional

############
# REQURIED #
############
city = 'briarcliff manor'
state = 'ny'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: briarcliff manor, ny

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %%
rapid_api_key
# Out:
# '8b63d59cecmsha5a796447533ec2p11f828jsnf7fd2c8395a5'

# %%
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

# %%
headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }
import requests
req = requests.request('GET', url, headers=headers)

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Townhomes",
               "minPrice": "500000",
               "maxPrice": "900000",
               "sqftMin": "1000",
               "bedsMin": "2"
               }

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 436,
#    'address': '1 Winterberry Lane, Briarcliff Manor, NY 10510',
#    'variableData': {'text': 'Open: Sat. 11am-1pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ad21d8bfe296c8e800b2ce79bf26666f-p_e.jpg',
#    'price': 859000,
#    'detailUrl': '/homedetails/1-Winterberry-Ln-Briarcliff-Manor-NY-10510/66520041_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -73.825096,
#    'latitude': 41.15719,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '66520041',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 5,
#    'bathrooms': 3,
#    'livingArea': 3112,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 436,
#    'address': '2 Winterberry Lane, Briarcliff Manor, NY 10510',
#    'variableData': {'text': 'Open: Sat. 11am-1pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0aea3b95700b903fb31f7d71fea6e935-p_e.jpg',
#    'price': 899000,
#    'detailUrl': '/homedetails/2-Winterberry-Ln-Briarcliff-Manor-NY-10510/299052974_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -73.82517,
#    'latitude': 41.157627,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '299052974',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': 4,
#    'bathrooms': 4,
#    'livingArea': 3112,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 436,
#    'address': '43 Briarbrook Drive, Briarcliff Manor, NY 10510',
#    'variableData': {'text': '8 days on Zillow', 'type': 'DAYS_ON'},
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/56439cba39a85473cbc0408fc6167fb9-p_e.jpg',
#    'price': 839000,
#    'detailUrl': '/homedetails/43-Briarbrook-Dr-Briarcliff-Manor-NY-10510/299052834_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -73.857796,
#    'latitude': 41.142616,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '299052834',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 8,
#    'bathrooms': 4,
#    'livingArea': 2655,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'TOWNHOUSE',
#    'lotAreaValue': 3485,
#    'address': '12 Jackson Road, Briarcliff Manor, NY 10510',
#    'variableData': {'text': '$25,000 (Jun 7)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -25000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/596f12394f409d7c6249d86cfb428eb6-p_e.jpg',
#    'price': 875000,
#    'detailUrl': '/homedetails/12-Jackson-Rd-Briarcliff-NY-10510/33055040_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -73.82087,
#    'latitude': 41.141403,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '33055040',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': 64,
#    'bathrooms': 4,
#    'livingArea': 2446,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 1,
#  'totalResultCount': 4,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 4
# Num of cols: 27
#   dateSold propertyType  lotAreaValue  \
# 0     None    TOWNHOUSE           436
# 1     None    TOWNHOUSE           436
# 2     None    TOWNHOUSE           436
# 3     None    TOWNHOUSE          3485
#
#                                            address  priceChange zestimate  \
# 0   1 Winterberry Lane, Briarcliff Manor, NY 10510          NaN      None
# 1   2 Winterberry Lane, Briarcliff Manor, NY 10510          NaN      None
# 2  43 Briarbrook Drive, Briarcliff Manor, NY 10510          NaN      None
# 3      12 Jackson Road, Briarcliff Manor, NY 10510     -25000.0      None
#
#                                               imgSrc   price  \
# 0  https://photos.zillowstatic.com/fp/ad21d8bfe29...  859000
# 1  https://photos.zillowstatic.com/fp/0aea3b95700...  899000
# 2  https://photos.zillowstatic.com/fp/56439cba39a...  839000
# 3  https://photos.zillowstatic.com/fp/596f12394f4...  875000
#
#                                            detailUrl  bedrooms  \
# 0  /homedetails/1-Winterberry-Ln-Briarcliff-Manor...         3
# 1  /homedetails/2-Winterberry-Ln-Briarcliff-Manor...         3
# 2  /homedetails/43-Briarbrook-Dr-Briarcliff-Manor...         3
# 3  /homedetails/12-Jackson-Rd-Briarcliff-NY-10510...         4
#
#   contingentListingType  longitude   latitude listingStatus       zpid  \
# 0                  None -73.825096  41.157190      FOR_SALE   66520041
# 1                  None -73.825170  41.157627      FOR_SALE  299052974
# 2                  None -73.857796  41.142616      FOR_SALE  299052834
# 3                  None -73.820870  41.141403      FOR_SALE   33055040
#
#   rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0          None             5          3        3112     USA      USD
# 1          None             4          4        3112     USA      USD
# 2          None             8          4        2655     USA      USD
# 3          None            64          4        2446     USA      USD
#
#   lotAreaUnit  hasImage    variableData.text variableData.type  \
# 0        sqft      True  Open: Sat. 11am-1pm        OPEN_HOUSE
# 1        sqft      True  Open: Sat. 11am-1pm        OPEN_HOUSE
# 2        sqft      True     8 days on Zillow           DAYS_ON
# 3        sqft      True      $25,000 (Jun 7)   PRICE_REDUCTION
#
#    listingSubType.is_FSBA listingSubType.is_openHouse
# 0                    True                        True
# 1                    True                        True
# 2                    True                         NaN
# 3                    True                         NaN

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['66520041', '299052974', '299052834', '33055040']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 4
# Num of cols: 299
#   listingProvider       zpid buildingPermits  propertyTaxRate  \
# 0            None   66520041            None             1.58
# 1            None  299052974            None             1.58
#
#                                   contact_recipients zipcode  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   10510
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   10510
#
#                                    openHouseSchedule  longitude  \
# 0  [{'startTime': '2024-06-15 11:00:00', 'endTime... -73.825096
# 1  [{'startTime': '2024-06-15 11:00:00', 'endTime... -73.825170
#
#   zestimateLowPercent  cityId timeOnZillow  \
# 0                None   28254       5 days
# 1                None   28254       4 days
#
#                                                  url zestimate  \
# 0  /homedetails/1-Winterberry-Ln-Briarcliff-Manor...      None
# 1  /homedetails/2-Winterberry-Ln-Briarcliff-Manor...      None
#
#                                               imgSrc  \
# 0  https://photos.zillowstatic.com/fp/ad21d8bfe29...
# 1  https://photos.zillowstatic.com/fp/0aea3b95700...
#
#                                          description   price  livingAreaValue  \
# 0  Welcome to this stunningly renovated end-unit ...  859000             3112
# 1  Welcome to Wyndcrest, a GDC development in the...  899000             3112
#
#                                           taxHistory brokerId  stateId  \
# 0  [{'time': 1686665045617, 'valueIncreaseRate': ...     None       43
# 1  [{'time': 1686665048251, 'valueIncreaseRate': ...     None       43
#
#         streetAddress solarPotential dateSold  countyId          timeZone  \
# 0  1 Winterberry Lane           None     None      3148  America/New_York
# 1  2 Winterberry Lane           None     None      3148  America/New_York
#
#     homeType livingAreaUnits comingSoonOnMarketDate rentZestimate  bathrooms  \
# 0  TOWNHOUSE            sqft                   None          None          3
# 1  TOWNHOUSE            sqft                   None          None          4
#
#    annualHomeownersInsurance state propertyTypeDimension building  yearBuilt  \
# 0                       3608    NY             Townhouse     None       1998
# 1                       3776    NY             Townhouse     None       1998
#
#             brokerageName  pageViewCount              county  monthlyHoaFee  \
# 0  Houlihan Lawrence Inc.           1461  Westchester County          500.0
# 1  Houlihan Lawrence Inc.           1314  Westchester County          500.0
#
#   homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0   FOR_SALE      None  41.157190  2024-06-08         3
# 1   FOR_SALE      None  41.157627  2024-06-08         3
#
#                                          nearbyHomes  livingArea  \
# 0  [{'livingArea': None, 'livingAreaValue': None,...        3112
# 1  [{'livingArea': None, 'livingAreaValue': None,...        3112
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0.30151515151515, 'date':...             71
# 1  [{'priceChangeRate': 0.28428571428571, 'date':...             66
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/new-yo...                 None
# 1  [{'link': 'https://www.greatschools.org/new-yo...                 None
#
#       mlsid countyFIPS              city providerListingID country currency  \
# 0  H6310561      36119  Briarcliff Manor              None     USA      USD
# 1  H6311789      36119  Briarcliff Manor              None     USA      USD
#
#   isListedByOwner contingentListingType address.community      address.city  \
# 0            None                  None              None  Briarcliff Manor
# 1            None                  None              None  Briarcliff Manor
#
#   address.state address.neighborhood address.subdivision  \
# 0            NY                 None                None
# 1            NY                 None                None
#
#   address.streetAddress address.zipcode  resoFacts.hasAttachedProperty  \
# 0    1 Winterberry Lane           10510                           True
# 1    2 Winterberry Lane           10510                           True
#
#   resoFacts.frontageType resoFacts.poolFeatures  resoFacts.flooring  \
# 0                   None                   None  [Hardwood, Carpet]
# 1                   None                   None  [Hardwood, Carpet]
#
#   resoFacts.builderModel resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0             Fieldstone                            None                 True
# 1              Fieldston                            None                 True
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     True               None                 None
# 1                     True               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
# 1                              None                           False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factValue': 'Condominium, Townhouse', 'fact...
# 1                  None  [{'factValue': 'Condominium, Townhouse', 'fact...
#
#   resoFacts.offerReviewDate resoFacts.horseYN  \
# 0                      None              None
# 1                      None              None
#
#   resoFacts.buyerAgencyCompensationType  \
# 0                                     %
# 1                                     %
#
#                                      resoFacts.rooms  \
# 0  [{'level': None, 'dimensions': None, 'features...
# 1  [{'level': None, 'dimensions': None, 'features...
#
#   resoFacts.belowGradeFinishedArea  \
# 0                             None
# 1                             None
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': None, 'name': None, 'fee': '$500 mo...     Briarcliff Manor
# 1  [{'phone': None, 'name': None, 'fee': '$500 mo...     Briarcliff Manor
#
#   resoFacts.subAgencyCompensation resoFacts.hasPrivatePool  \
# 0                            None                     None
# 1                            None                     None
#
#                     resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0  [Maintenance Grounds, Maintenance Structure, S...              [Public]
# 1  [Maintenance Grounds, Maintenance Structure, S...              [Public]
#
#   resoFacts.carportParkingCapacity  \
# 0                             None
# 1                             None
#
#   resoFacts.transactionBrokerCompensationType resoFacts.hasFireplace  \
# 0                                        None                   True
# 1                                        None                   True
#
#   resoFacts.gas resoFacts.sewer resoFacts.elevationUnits  \
# 0          None  [Public Sewer]                     None
# 1          None  [Public Sewer]                     None
#
#   resoFacts.roadSurfaceType resoFacts.mainLevelBedrooms  \
# 0                      None                        None
# 1                      None                        None
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView  \
# 0                          None                        None
# 1                          None                        None
#
#   resoFacts.bathroomsOneQuarter resoFacts.lotSize  \
# 0                          None          436 sqft
# 1                          None          436 sqft
#
#   resoFacts.subAgencyCompensationType resoFacts.entryLevel  \
# 0                                None                 None
# 1                                None                 None
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.greenWaterConservation  \
# 0                                 None                             None
# 1                                 None                             None
#
#    resoFacts.stories  resoFacts.bathrooms resoFacts.numberOfUnitsInCommunity  \
# 0                3.0                    3                               None
# 1                3.0                    4                               None
#
#   resoFacts.listingTerms resoFacts.otherParking resoFacts.associationFee  \
# 0                   None                   None             $500 monthly
# 1                   None                   None             $500 monthly
#
#   resoFacts.marketingType resoFacts.greenEnergyEfficient  \
# 0                    None                           None
# 1                    None                           None
#
#   resoFacts.greenSustainability          resoFacts.heating  \
# 0                          None  [Natural Gas, Forced Air]
# 1                          None  [Natural Gas, Forced Air]
#
#   resoFacts.associationPhone resoFacts.greenBuildingVerificationType  \
# 0                       None                                    None
# 1                       None                                    None
#
#    resoFacts.hasAttachedGarage  resoFacts.bedrooms  \
# 0                         True                   3
# 1                         True                   3
#
#   resoFacts.architecturalStyle resoFacts.listingId resoFacts.structureType  \
# 0                         None                None               Townhouse
# 1                         None                None               Townhouse
#
#                           resoFacts.interiorFeatures resoFacts.horseAmenities  \
# 0  [Master Downstairs, First Floor Bedroom, Cathe...                     None
# 1  [Master Downstairs, First Floor Bedroom, Eat-i...                     None
#
#   resoFacts.electric              resoFacts.lotFeatures resoFacts.roofType  \
# 0               None  [Near Public Transit, Cul-De-Sac]               None
# 1               None  [Near Public Transit, Cul-De-Sac]               None
#
#   resoFacts.compensationBasedOn resoFacts.greenEnergyGeneration  \
# 0                          None                            None
# 1                          None                            None
#
#    resoFacts.taxAnnualAmount  resoFacts.daysOnZillow resoFacts.listAOR  \
# 0                      13572                       5              None
# 1                      14204                       4              None
#
#    resoFacts.hasHeating resoFacts.elementarySchool  \
# 0                  True     Todd Elementary School
# 1                  True     Todd Elementary School
#
#   resoFacts.constructionMaterials  resoFacts.basementYN resoFacts.hoaFeeTotal  \
# 0                [Shingle Siding]                  True          $500 monthly
# 1                [Shingle Siding]                  True          $500 monthly
#
#                                 resoFacts.appliances resoFacts.virtualTour  \
# 0  [Dishwasher, Dryer, Microwave, Oven, Refrigera...                  None
# 1  [Dishwasher, Dryer, Microwave, Oven, Refrigera...                  None
#
#   resoFacts.bathroomsPartial resoFacts.fencing resoFacts.yearBuiltEffective  \
# 0                       None              None                         None
# 1                       None              None                         None
#
#   resoFacts.buildingName resoFacts.hasAssociation resoFacts.isSeniorCommunity  \
# 0              Wyndcrest                     True                        None
# 1              Wyndcrest                     True                        None
#
#   resoFacts.propertySubType resoFacts.propertyCondition  resoFacts.hasCarport  \
# 0  [Condominium, Townhouse]                        None                 False
# 1  [Condominium, Townhouse]                        None                 False
#
#    resoFacts.canRaiseHorses  resoFacts.hasLandLease  \
# 0                     False                   False
# 1                     False                   False
#
#   resoFacts.communityFeatures        resoFacts.parcelNumber  \
# 0                [Pool, Park]  4201098007000000000004000531
# 1                [Pool, Park]  4201098007000000000004000571
#
#   resoFacts.elevation resoFacts.lotSizeDimensions  \
# 0                None                        None
# 1                None                        None
#
#   resoFacts.buildingAreaSource resoFacts.contingency  resoFacts.yearBuilt  \
# 0                         None                  None                 1998
# 1                         None                  None                 1998
#
#   resoFacts.otherStructures resoFacts.livingArea  resoFacts.bathroomsFull  \
# 0                      None           3,112 sqft                        2
# 1                      None           3,112 sqft                        3
#
#   resoFacts.livingAreaRangeUnits resoFacts.incomeIncludes  \
# 0                           None                     None
# 1                           None                     None
#
#      resoFacts.highSchool resoFacts.aboveGradeFinishedArea  \
# 0  Briarcliff High School                             None
# 1  Briarcliff High School                             None
#
#   resoFacts.isNewConstruction  \
# 0                        None
# 1                        None
#
#                                 resoFacts.inclusions  \
# 0  [Alarm System, Dishwasher, Dryer, Light Fixtur...
# 1  [Dishwasher, Dryer, Light Fixtures, Microwave,...
#
#    resoFacts.hasHomeWarranty resoFacts.additionalFeeInfo  \
# 0                      False                        None
# 1                      False                        None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0            [Skylight(s)]               Condo                 None
# 1            [Skylight(s)]               Condo                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                       Briarcliff Manor                        None
# 1                       Briarcliff Manor                        None
#
#   resoFacts.exteriorFeatures resoFacts.buildingFeatures  \
# 0         [Basketball Court]                       None
# 1                        NaN                       None
#
#   resoFacts.frontageLength resoFacts.buildingArea  \
# 0                     None                  3,112
# 1                     None                  3,112
#
#   resoFacts.associationAmenities  resoFacts.bathroomsHalf  \
# 0                           None                        1
# 1                           None                        1
#
#    resoFacts.hasCooling resoFacts.additionalParcelsDescription  \
# 0                  True                                   None
# 1                  True                                   None
#
#   resoFacts.parkingFeatures resoFacts.foundationArea resoFacts.zoning  \
# 0      [Attached, Driveway]                     None             None
# 1                [Attached]                     None             None
#
#   resoFacts.hoaFee resoFacts.livingAreaRange resoFacts.zoningDescription  \
# 0     $500 monthly                      None                        None
# 1     $500 monthly                      None                        None
#
#   resoFacts.developmentStatus resoFacts.availabilityDate  \
# 0                        None                       None
# 1                        None                       None
#
#   resoFacts.waterfrontFeatures resoFacts.waterBodyName resoFacts.utilities  \
# 0                         None                    None                None
# 1                         None                    None                None
#
#   resoFacts.entryLocation resoFacts.totalActualRent  resoFacts.hasView  \
# 0                     End                      None              False
# 1                    None                      None              False
#
#   resoFacts.subdivisionName resoFacts.securityFeatures resoFacts.attic  \
# 0                 Wyndcrest                       None     See Remarks
# 1                 Wyndcrest                       None     See Remarks
#
#   resoFacts.fireplaceFeatures resoFacts.mainLevelBathrooms  \
# 0                        None                         None
# 1                        None                         None
#
#   resoFacts.doorFeatures resoFacts.ownershipType resoFacts.associationName  \
# 0                   None                    None                      None
# 1                   None                    None                      None
#
#                               resoFacts.associations resoFacts.waterView  \
# 0  [{'feeFrequency': '$500 monthly', 'name': None...                None
# 1  [{'feeFrequency': '$500 monthly', 'name': None...                None
#
#    resoFacts.garageParkingCapacity resoFacts.cropsIncludedYN  \
# 0                              NaN                      None
# 1                              NaN                      None
#
#   resoFacts.laundryFeatures resoFacts.buyerAgencyCompensation  \
# 0                      None                                 2
# 1                      None                                 2
#
#   resoFacts.greenIndoorAirQuality resoFacts.homeType resoFacts.spaFeatures  \
# 0                            None          Townhouse                  None
# 1                            None          Townhouse                  None
#
#   resoFacts.municipality resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  \
# 0                   None                            None             False
# 1                   None                            None             False
#
#               resoFacts.basement resoFacts.associationFee2 resoFacts.cooling  \
# 0  Finished,Full,Walk-Out Access                      None     [Central Air]
# 1       Finished,Walk-Out Access                      None     [Central Air]
#
#   resoFacts.openParkingCapacity resoFacts.associationName2  \
# 0                          None                       None
# 1                          None                       None
#
#   resoFacts.hasRentControl resoFacts.elementarySchoolDistrict  \
# 0                     None                   Briarcliff Manor
# 1                     None                   Briarcliff Manor
#
#   resoFacts.otherEquipment resoFacts.commonWalls  \
# 0                     None       2+ Common Walls
# 1                     None       2+ Common Walls
#
#   resoFacts.specialListingConditions  resoFacts.furnished  \
# 0                               None                False
# 1                               None                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                   [Deck, Patio]
# 1                 None                          [Deck]
#
#    resoFacts.bathroomsFloat resoFacts.builderName  \
# 0                         3                  None
# 1                         4                  None
#
#   resoFacts.highSchoolDistrict resoFacts.transactionBrokerCompensation  \
# 0             Briarcliff Manor                                    None
# 1             Briarcliff Manor                                    None
#
#   resoFacts.storiesTotal resoFacts.cumulativeDaysOnMarket  \
# 0                   None                             None
# 1                   None                             None
#
#    resoFacts.fireplaces resoFacts.irrigationWaterRightsYN  \
# 0                   1.0                              None
# 1                   1.0                              None
#
#   resoFacts.exclusions resoFacts.hasOpenParking resoFacts.landLeaseAmount  \
# 0      [Video Cameras]                     True                      None
# 1                 None                     None                      None
#
#    resoFacts.coveredParkingCapacity resoFacts.middleOrJuniorSchool  \
# 0                               NaN       Briarcliff Middle School
# 1                               NaN       Briarcliff Middle School
#
#   resoFacts.hasElectricOnProperty  resoFacts.onMarketDate  \
# 0                            None           1718150400000
# 1                            None           1717977600000
#
#    resoFacts.pricePerSquareFoot  resoFacts.parkingCapacity resoFacts.levels  \
# 0                           276                          1    Three Or More
# 1                           289                          2    Three Or More
#
#    listingSubType.is_FSBA  listingSubType.is_comingSoon  \
# 0                    True                         False
# 1                    True                         False
#
#    listingSubType.is_newHome  listingSubType.is_pending  \
# 0                      False                      False
# 1                      False                      False
#
#    listingSubType.is_forAuction  listingSubType.is_foreclosure  \
# 0                         False                          False
# 1                         False                          False
#
#    listingSubType.is_bankOwned  listingSubType.is_openHouse  \
# 0                        False                         True
# 1                        False                         True
#
#    listingSubType.is_FSBO  listed_by.agent_reason listed_by.zpro  \
# 0                   False                     3.0          False
# 1                   False                     3.0          False
#
#    listed_by.recent_sales            listed_by.zuid  listed_by.review_count  \
# 0                     0.0  X1-ZU103j795aqyozt_1vfad                    67.0
# 1                     0.0  X1-ZU103j795aqyozt_1vfad                    67.0
#
#   listed_by.display_name                    listed_by.profile_url  \
# 0           Suzan Zeolla  https://www.zillow.com/profile/SZeolla/
# 1           Suzan Zeolla  https://www.zillow.com/profile/SZeolla/
#
#   listed_by.business_name  listed_by.rating_average listed_by.phone.prefix  \
# 0  Houlihan Lawrence Inc.                       5.0                    557
# 1  Houlihan Lawrence Inc.                       5.0                    557
#
#   listed_by.phone.areacode listed_by.phone.number listed_by.badge_type  \
# 0                      914                   1885        Listing Agent
# 1                      914                   1885        Listing Agent
#
#                                  listed_by.image_url  \
# 0  https://photos.zillowstatic.com/h_n/ISpdbnc290...
# 1  https://photos.zillowstatic.com/h_n/ISpdbnc290...
#
#    mortgageRates.thirtyYearFixedRate attributionInfo.buyerAgentName  \
# 0                              6.624                           None
# 1                              6.624                           None
#
#   attributionInfo.mlsName attributionInfo.coAgentLicenseNumber  \
# 0             OneKey® MLS                                 None
# 1             OneKey® MLS                                 None
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated attributionInfo.buyerAgentMemberStateLicense  \
# 0         2024-06-13 00:29:23                                         None
# 1         2024-06-11 06:10:25                                         None
#
#   attributionInfo.brokerName attributionInfo.listingAgreement  \
# 0     Houlihan Lawrence Inc.                             None
# 1     Houlihan Lawrence Inc.                             None
#
#                         attributionInfo.infoString10  \
# 0  The data relating to real estate for sale or l...
# 1  The data relating to real estate for sale or l...
#
#   attributionInfo.trueStatus  \
# 0                       None
# 1                       None
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/4e66a55bd37...
# 1  https://photos.zillowstatic.com/fp/4e66a55bd37...
#
#   attributionInfo.agentEmail attributionInfo.agentName  \
# 0                       None              Suzan Zeolla
# 1                       None              Suzan Zeolla
#
#   attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0                      Listing by:              H6310561
# 1                      Listing by:              H6311789
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1                        None                          None
#
#   attributionInfo.infoString5  \
# 0                914-557-1885
# 1                914-557-1885
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': '30ZE0880173', 'member...
# 1  [{'memberStateLicense': '30ZE0880173', 'member...
#
#   attributionInfo.agentPhoneNumber attributionInfo.agentLicenseNumber  \
# 0                     914-557-1885                               None
# 1                     914-557-1885                               None
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/4e66a55bd37...
# 1  https://photos.zillowstatic.com/fp/4e66a55bd37...
#
#   attributionInfo.infoString16 attributionInfo.buyerBrokerageName  \
# 0                         None                               None
# 1                         None                               None
#
#                        attributionInfo.mlsDisclaimer  \
# 0  The data relating to real estate for sale or l...
# 1  The data relating to real estate for sale or l...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      914-762-7200         2024-06-13 06:57:00
# 1                      914-762-7200         2024-06-13 06:57:00
#
#    listed_by.phone
# 0              NaN
# 1              NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#          streetAddress              city              county zipcode state  \
# 0   1 Winterberry Lane  Briarcliff Manor  Westchester County   10510    NY
# 1   2 Winterberry Lane  Briarcliff Manor  Westchester County   10510    NY
# 2  43 Briarbrook Drive  Briarcliff Manor  Westchester County   10510    NY
# 3      12 Jackson Road        Briarcliff  Westchester County   10510    NY
#
#     price   homeType timeOnZillow zestimate rentZestimate  livingArea  \
# 0  859000  TOWNHOUSE       5 days      None          None        3112
# 1  899000  TOWNHOUSE       4 days      None          None        3112
# 2  839000  TOWNHOUSE       8 days      None          None        2655
# 3  875000  TOWNHOUSE      64 days      None          None        2446
#
#    bedrooms  bathrooms  yearBuilt  \
# 0         3          3       1998
# 1         3          4       1998
# 2         3          4       2002
# 3         4          4       1972
#
#                                          description  \
# 0  Welcome to this stunningly renovated end-unit ...
# 1  Welcome to Wyndcrest, a GDC development in the...
# 2  This meticulously cared-for house offers a con...
# 3  Welcome to this beautiful single family attach...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': 0.30151515151515, 'date':...
# 1  [{'priceChangeRate': 0.28428571428571, 'date':...
# 2  [{'priceChangeRate': 0, 'date': '2024-06-04', ...
# 3  [{'priceChangeRate': -0.027777777777778, 'date...
#
#                                           taxHistory       zpid
# 0  [{'time': 1686665045617, 'valueIncreaseRate': ...   66520041
# 1  [{'time': 1686665048251, 'valueIncreaseRate': ...  299052974
# 2  [{'time': 1686665051231, 'valueIncreaseRate': ...  299052834
# 3  [{'time': 1686665053877, 'valueIncreaseRate': ...   33055040

# %%
# download file
#df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
#files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
df_z_prop_detail_output['streetAddress'].iloc[0]
# Out:
# '1 Winterberry Lane'

# %%
data = """Name,Address
"""

# %%
for x in range (0,len(df_z_prop_detail_output),1):
  # Step 1: Open the file in write mode
  file = open('example.txt', 'a')

  # Step 2: Write text to the file
  if x==0:
    file.write("Name,Address\n")
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" NY"+"\n")
  else:
    file.write("House_"+str(x)+", "+df_z_prop_detail_output['streetAddress'].iloc[x]+"; "+df_z_prop_detail_output['city'].iloc[x]+" NY"+"\n")
  # Step 3: Close the file
file.close()

# %%
import pandas as pd
data=pd.read_csv('./example.txt')

# %%
df=data

# %%
import pandas as pd
import requests
import json
import urllib
import io

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="example app")

# %%
df
# Out:
#       Name                                    Address
# 0  House_0    1 Winterberry Lane; Briarcliff Manor NY
# 1  House_1    2 Winterberry Lane; Briarcliff Manor NY
# 2  House_2   43 Briarbrook Drive; Briarcliff Manor NY
# 3  House_3             12 Jackson Road; Briarcliff NY

# %%
df["loc"] = df["Address"].apply(geolocator.geocode)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+1+Winterberry+Lane%3B+Briarcliff+Manor+NY&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=+43+Briarbrook+Drive%3B+Briarcliff+Manor+NY&format=json&limit=1

# %%
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)

# %%
# import the library and its Marker clusterization service
import folium
from folium.plugins import MarkerCluster
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(location=df[["lat", "lon"]].mean().to_list(), zoom_start=2)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["lat"], r["lon"])
    folium.Marker(location=location,
                      popup = r['Name'],
                      tooltip=r['Name'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fb0e25545bc7765f75dbe97524dab88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fb0e25545bc7765f75dbe97524dab88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fb0e25545bc7765f75dbe97524dab88 = L.map(
#                 &quot;map_1fb0e25545bc7765f75dbe97524dab88&quot;,
#                 {
#                     center: [41.149478625, -73.832196825],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d221173c692e059f6ee244cc86c0bb04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fb0e25545bc7765f75dbe97524dab88);
#
#
#             var marker_cluster_c599cda8c28866aed9f94b22d2b69351 = L.markerClusterGroup(
#                 {}
#             );
#             map_1fb0e25545bc7765f75dbe97524dab88.addLayer(marker_cluster_c599cda8c28866aed9f94b22d2b69351);
#
#
#             var marker_fe025a8799c95842b48d3befe85d6506 = L.marker(
#                 [41.157188, -73.8250991],
#                 {}
#             ).addTo(marker_cluster_c599cda8c28866aed9f94b22d2b69351);
#
#
#         var popup_e884a7636ffc119de74312007e7f0c02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04394240c1614d54236ddb9285cb369c = $(`&lt;div id=&quot;html_04394240c1614d54236ddb9285cb369c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_0&lt;/div&gt;`)[0];
#                 popup_e884a7636ffc119de74312007e7f0c02.setContent(html_04394240c1614d54236ddb9285cb369c);
#
#
#
#         marker_fe025a8799c95842b48d3befe85d6506.bindPopup(popup_e884a7636ffc119de74312007e7f0c02)
#         ;
#
#
#
#
#             marker_fe025a8799c95842b48d3befe85d6506.bindTooltip(
#                 `&lt;div&gt;
#                      House_0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79af09035d4cf064c93e67ca889782d3 = L.marker(
#                 [41.1576259, -73.8251732],
#                 {}
#             ).addTo(marker_cluster_c599cda8c28866aed9f94b22d2b69351);
#
#
#         var popup_244f6d9c8ce3ead40f6145201b81dadc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c1718ba125b1b4bc65110180d6e689d = $(`&lt;div id=&quot;html_0c1718ba125b1b4bc65110180d6e689d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_1&lt;/div&gt;`)[0];
#                 popup_244f6d9c8ce3ead40f6145201b81dadc.setContent(html_0c1718ba125b1b4bc65110180d6e689d);
#
#
#
#         marker_79af09035d4cf064c93e67ca889782d3.bindPopup(popup_244f6d9c8ce3ead40f6145201b81dadc)
#         ;
#
#
#
#
#             marker_79af09035d4cf064c93e67ca889782d3.bindTooltip(
#                 `&lt;div&gt;
#                      House_1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_89c1fb58a97b6385684f6f5b04648a81 = L.marker(
#                 [41.14169, -73.8576397],
#                 {}
#             ).addTo(marker_cluster_c599cda8c28866aed9f94b22d2b69351);
#
#
#         var popup_c0db44572f4f516e71dbc4178018c322 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f5e3e8067c94610c1c250ce64df08d3 = $(`&lt;div id=&quot;html_4f5e3e8067c94610c1c250ce64df08d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House_2&lt;/div&gt;`)[0];
#                 popup_c0db44572f4f516e71dbc4178018c322.setContent(html_4f5e3e8067c94610c1c250ce64df08d3);
#
#
#
#         marker_89c1fb58a97b6385684f6f5b04648a81.bindPopup(popup_c0db44572f4f516e71dbc4178018c322)
#         ;
#
#
#
#
#             marker_89c1fb58a97b6385684f6f5b04648a81.bindTooltip(
#                 `&lt;div&gt;
#                      House_2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9a4a375e2f94bb4e1fe0ba1da9b8b52b = L.marker(
#                 [41.1414106, -73.8208753],
#                 {}
#             ).addTo(marker_cluster_c599cda8c28866aed9f94b22d2b69351);
#
#
#         var popup_811d88ab9a3ce125fa597341d64b00e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quo

# %%
#https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6#5352

# %% [markdown]
# # End Notebook
